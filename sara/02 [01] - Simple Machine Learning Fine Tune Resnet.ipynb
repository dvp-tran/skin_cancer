# %% [markdown]
# # Skin Cancer Classification Challenge

# %% [markdown]
# **Summary : ** skin cancer.

# %% [markdown]
# ## Preliminaries and Imports

# %%
#general & system\n",
import os

#data processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 10, 10  #default setting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#data augmentation
from PIL import Image
from random import choice
import cv2
import numpy as np
#import keras.preprocessing.image as prep

#ML part
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing import image as kimage
from keras.models import Sequential
from keras.layers import GlobalMaxPooling2D, Dense, BatchNormalization, GlobalAveragePooling2D,Dropout,Activation,Flatten
from keras.models import Model
from keras.optimizers import SGD
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

#validation
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score


from sklearn.metrics import precision_recall_curve
from imblearn.over_sampling import SMOTE
from sklearn.utils import resample

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-da9683cee917> in <module>()
#      43
#      44 from sklearn.metrics import precision_recall_curve
# ---> 45 from imblearn.over_sampling import SMOTE
#      46 from sklearn.utils import resample
#      47
#
# ImportError: No module named imblearn.over_sampling

# %% [markdown]
# ## I. Load Data

# %% [markdown]
# - **Rq : ** Datasets are quite light, can be fully loaded in a laptop memory with ease.

# %%
# %%time
meta = pd.read_csv("../data/label_learn.csv", sep = ";")
# Out:
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 5.89 ms

# %%
meta.head()
# Out:
#           name      label
# 0  0000000.jpg     benign
# 1  0000002.jpg  malignant
# 2  0000006.jpg     benign
# 3  0000008.jpg     benign
# 4  0000009.jpg     benign

# %%
# %%time
train_list = os.listdir("../data/resized_train/")
len(train_list) == len(meta.name)
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 4.09 ms

# %%
train_list.sort() == list(meta.name).sort()
# Out:
# True

# %%
# %%time
X_train = np.array([np.array(Image.open("../data/resized_train/"+fname)) for fname in meta.name])
Y_train = [1 if x=="malignant" else 0 for x in meta.label]
Y_train = np.array(Y_train)
# Out:
# CPU times: user 20.9 s, sys: 1.7 s, total: 22.6 s
# Wall time: 22.6 s

# %%
print(X_train.shape)
print(len(Y_train))
X_train.shape[0] == len(meta.name) == len(Y_train)
# Out:
# (8581, 299, 299, 3)
# 8581
# True

# %%
#control
print(meta.name[0:5])
print(Y_train[0:5])
print(meta.label[0:5])
# Out:
# 0    0000000.jpg
# 1    0000002.jpg
# 2    0000006.jpg
# 3    0000008.jpg
# 4    0000009.jpg
# Name: name, dtype: object
# [0 1 0 0 0]
# 0       benign
# 1    malignant
# 2       benign
# 3       benign
# 4       benign
# Name: label, dtype: object

# %% [markdown]
# ## II. Data Preparation

# %% [markdown]
# - **Class weights**

# %%
class_weight_or = class_weight.compute_class_weight('balanced', np.unique(Y_train), Y_train)

# %% [markdown]
# - **Data splitting**

# %%
#data splitting
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train, Y_train, random_state=42, train_size=0.80)
# Out:
# /home/dvp_tran/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# - **Resampling**

# %%
temp = sum(Y_train)
sample_size = temp*1372/(374+254)

# %%
def random_undersampling(X, Y,sample_size = sample_size, n_sample=1):
    """
    X,y : numpy arrays
    return :
    5 random ensemble of indices general_balenced_set:
        general_balenced_set[0] = the shuffeled indices that inssure the class balance
    """
    indices = np.array(range(len(Y)))
    positive_samples = indices[Y==1]
    #print(type(positive_samples))
    negative_samples = indices[Y==0]
    #print(type(negative_samples))
    general_balenced_set = []
    for k in range(n_sample):
        indices_ = np.random.choice(negative_samples, sample_size, replace=False)
        #print(len(indices_))
        # append positive and negative
        balenced_set = np.append(indices_, positive_samples)
        #print(len(balenced_set))
        # shuffle indices
        np.random.shuffle(balenced_set)
        #print(len(balenced_set))
        general_balenced_set.append(balenced_set)
    return general_balenced_set

# %%
general_balenced_set = random_undersampling(X_train,Y_train)
X_train = X_train[general_balenced_set]
Y_train = Y_train[general_balenced_set]

# %% [markdown]
# ## III. Deep Learning with Transfer Learning

# %%
weights_path = '../model/checkpoints/'

if not os.path.exists(weights_path):
    os.makedirs(weights_path)
    
epochs = 500
batch_size = 50

# %% [markdown]
# - **Using RESNET : **

# %%
#load base model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(299,299,3))
base_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
#adding top layers
    #sequentialy
add_model = Sequential()
add_model.add(GlobalAveragePooling2D(input_shape=base_model.output_shape[1:])) #Flatten/GlobalAveragePooling2D
add_model.add(Dense(1024, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(512, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(1, activation='sigmoid'))

model = Model(inputs=base_model.input, outputs=add_model(base_model.output))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1)            2623489     avg_pool[0][0]
# ==================================================================================================
# Total params: 26,211,201
# Trainable params: 26,158,081
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [raw]
# #adding top layers
#     #need to check api to add layers sequentialy
# x = base_model.output
# x = GlobalAveragePooling2D()(x) #Flatten instead?
# x = Dense(1024, activation='relu')(x)
# x = Dropout(0.25)(x)
# x = Dense(512, activation='relu')(x)
# x = Dropout(0.25)(x)
# predictions = Dense(1, activation='sigmoid')(x)
#
# model = Model(inputs=base_model.input, outputs=predictions)
# model.summary()

# %%
from keras import backend as K

def weighted_categorical_crossentropy(weights):
    """
    [w_0, w_1] : weight of 0 class and weight of 1 class
    """
    weights = K.variable(weights)

    def loss(y_true, y_pred):
        # scale predictions so that the class probas of each sample sum to 1
        #y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
        # clip to prevent NaN's and Inf's
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        # calc
        loss = y_true * K.log(y_pred) * weights[1] + (1 - y_true) * K.log(1 - y_pred) * weights[0]
        loss = -K.sum(loss, -1)
        return loss

    return loss

# %%
class_weight_or
# Out:
# array([ 0.54296381,  6.31885125])

# %%
loss1 = weighted_categorical_crossentropy(class_weight_or)

# %%
#freeze lower layers of the model
#for layer in model.layers[:]:
    #layer.trainable = False
for layer in model.layers[0:]:
    layer.trainable = True
    

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())




#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss=loss1, #binary_crossentropy
              metrics=[sensitivity, specificity,"accuracy"])

# %%
# %%time
#Lets define the image transormations that we wan

gen = ImageDataGenerator(horizontal_flip=True,
                         vertical_flip=True,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         zoom_range=0.2,
                         rotation_range=40)

val_datagen = ImageDataGenerator()
# Here is the function that merges our two generators
# We use the exact same generator with the same random seed for both the y and angle arrays
def gen_flow_for_one_input(X1, y):
    genX1 = gen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]

def val_datagen_(X1, y):
    genX1 = val_datagen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]
#Finally create out generator
gen_flow_train = gen_flow_for_one_input(X_train, Y_train)
#gen_flow_val = gen_flow_for_one_input(X_valid, Y_valid)
gen_flow_val = val_datagen_(X_valid, Y_valid)

from keras.callbacks import EarlyStopping, ModelCheckpoint
epochs_to_wait_for_improve = 50
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=epochs_to_wait_for_improve)
checkpoint_callback = ModelCheckpoint(weights_path + 'BestKerasResnet50_flat_2_loss.h5', monitor='val_loss',
                                      verbose=1, save_best_only=True, mode='min')
#fit the model
model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid),
                    steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
                    epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
                    class_weight = class_weight_or)
# Out:
# Epoch 1/500
# 33/34 [============================>.] - ETA: 1s - loss: 1.0234 - sensitivity: 0.9604 - specificity: 0.0581 - acc: 0.3418Epoch 00001: val_loss improved from inf to 0.74196, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 58s 2s/step - loss: 1.0170 - sensitivity: 0.9616 - specificity: 0.0564 - acc: 0.3418 - val_loss: 0.7420 - val_sensitivity: 0.9709 - val_specificity: 0.0025 - val_acc: 0.0827
# Epoch 2/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.7611 - sensitivity: 0.9980 - specificity: 0.0918 - acc: 0.3731Epoch 00002: val_loss improved from 0.74196 to 0.60095, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.7572 - sensitivity: 0.9980 - specificity: 0.0924 - acc: 0.3728 - val_loss: 0.6010 - val_sensitivity: 0.9709 - val_specificity: 0.2476 - val_acc: 0.3087
# Epoch 3/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.6445 - sensitivity: 0.9986 - specificity: 0.3070 - acc: 0.5197Epoch 00003: val_loss improved from 0.60095 to 0.54454, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.6439 - sensitivity: 0.9986 - specificity: 0.3099 - acc: 0.5233 - val_loss: 0.5445 - val_sensitivity: 0.9709 - val_specificity: 0.4714 - val_acc: 0.5143
# Epoch 4/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.5532 - sensitivity: 0.9952 - specificity: 0.4676 - acc: 0.6323Epoch 00004: val_loss improved from 0.54454 to 0.50782, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.5511 - sensitivity: 0.9953 - specificity: 0.4663 - acc: 0.6302 - val_loss: 0.5078 - val_sensitivity: 0.9709 - val_specificity: 0.6106 - val_acc: 0.6418
# Epoch 5/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.5505 - sensitivity: 0.9983 - specificity: 0.5172 - acc: 0.6685Epoch 00005: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.5492 - sensitivity: 0.9984 - specificity: 0.5176 - acc: 0.6683 - val_loss: 0.5261 - val_sensitivity: 0.9505 - val_specificity: 0.4935 - val_acc: 0.5323
# Epoch 6/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4961 - sensitivity: 0.9934 - specificity: 0.6287 - acc: 0.7362Epoch 00006: val_loss improved from 0.50782 to 0.47128, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4936 - sensitivity: 0.9935 - specificity: 0.6302 - acc: 0.7370 - val_loss: 0.4713 - val_sensitivity: 0.9476 - val_specificity: 0.7028 - val_acc: 0.7245
# Epoch 7/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4727 - sensitivity: 0.9952 - specificity: 0.6863 - acc: 0.7812Epoch 00007: val_loss improved from 0.47128 to 0.45373, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4741 - sensitivity: 0.9939 - specificity: 0.6874 - acc: 0.7823 - val_loss: 0.4537 - val_sensitivity: 0.9102 - val_specificity: 0.7696 - val_acc: 0.7839
# Epoch 8/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4485 - sensitivity: 0.9921 - specificity: 0.7115 - acc: 0.7970Epoch 00008: val_loss improved from 0.45373 to 0.42313, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4482 - sensitivity: 0.9923 - specificity: 0.7133 - acc: 0.7983 - val_loss: 0.4231 - val_sensitivity: 0.8976 - val_specificity: 0.7970 - val_acc: 0.8090
# Epoch 9/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4528 - sensitivity: 0.9825 - specificity: 0.7191 - acc: 0.8007Epoch 00009: val_loss improved from 0.42313 to 0.42215, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4518 - sensitivity: 0.9830 - specificity: 0.7188 - acc: 0.8001 - val_loss: 0.4222 - val_sensitivity: 0.9563 - val_specificity: 0.7738 - val_acc: 0.7915
# Epoch 10/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4224 - sensitivity: 0.9867 - specificity: 0.7653 - acc: 0.8310Epoch 00010: val_loss improved from 0.42215 to 0.40489, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4176 - sensitivity: 0.9871 - specificity: 0.7668 - acc: 0.8324 - val_loss: 0.4049 - val_sensitivity: 0.9553 - val_specificity: 0.7795 - val_acc: 0.7967
# Epoch 11/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4196 - sensitivity: 0.9952 - specificity: 0.7368 - acc: 0.8165Epoch 00011: val_loss improved from 0.40489 to 0.38971, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4192 - sensitivity: 0.9954 - specificity: 0.7360 - acc: 0.8166 - val_loss: 0.3897 - val_sensitivity: 0.9553 - val_specificity: 0.7898 - val_acc: 0.8061
# Epoch 12/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4003 - sensitivity: 0.9909 - specificity: 0.7694 - acc: 0.8347Epoch 00012: val_loss improved from 0.38971 to 0.37528, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4030 - sensitivity: 0.9896 - specificity: 0.7705 - acc: 0.8354 - val_loss: 0.3753 - val_sensitivity: 0.9002 - val_specificity: 0.8070 - val_acc: 0.8183
# Epoch 13/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4140 - sensitivity: 0.9898 - specificity: 0.7530 - acc: 0.8251Epoch 00013: val_loss improved from 0.37528 to 0.36667, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4136 - sensitivity: 0.9885 - specificity: 0.7536 - acc: 0.8256 - val_loss: 0.3667 - val_sensitivity: 0.9374 - val_specificity: 0.8053 - val_acc: 0.8183
# Epoch 14/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.4339 - sensitivity: 0.9871 - specificity: 0.7559 - acc: 0.8246Epoch 00014: val_loss improved from 0.36667 to 0.36291, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.4357 - sensitivity: 0.9857 - specificity: 0.7553 - acc: 0.8239 - val_loss: 0.3629 - val_sensitivity: 0.9527 - val_specificity: 0.8004 - val_acc: 0.8154
# Epoch 15/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3768 - sensitivity: 0.9930 - specificity: 0.7752 - acc: 0.8419Epoch 00015: val_loss improved from 0.36291 to 0.33866, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.3749 - sensitivity: 0.9932 - specificity: 0.7750 - acc: 0.8413 - val_loss: 0.3387 - val_sensitivity: 0.9495 - val_specificity: 0.8071 - val_acc: 0.8212
# Epoch 16/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3889 - sensitivity: 0.9951 - specificity: 0.7716 - acc: 0.8396Epoch 00016: val_loss improved from 0.33866 to 0.32750, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.3923 - sensitivity: 0.9952 - specificity: 0.7701 - acc: 0.8379 - val_loss: 0.3275 - val_sensitivity: 0.9495 - val_specificity: 0.8172 - val_acc: 0.8305
# Epoch 17/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3582 - sensitivity: 0.9865 - specificity: 0.7799 - acc: 0.8427Epoch 00017: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3572 - sensitivity: 0.9869 - specificity: 0.7803 - acc: 0.8432 - val_loss: 0.3383 - val_sensitivity: 0.9325 - val_specificity: 0.8026 - val_acc: 0.8160
# Epoch 18/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3713 - sensitivity: 0.9926 - specificity: 0.7712 - acc: 0.8412Epoch 00018: val_loss improved from 0.32750 to 0.32376, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.3701 - sensitivity: 0.9928 - specificity: 0.7719 - acc: 0.8423 - val_loss: 0.3238 - val_sensitivity: 0.9495 - val_specificity: 0.8180 - val_acc: 0.8305
# Epoch 19/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3876 - sensitivity: 0.9842 - specificity: 0.7583 - acc: 0.8278Epoch 00019: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.3850 - sensitivity: 0.9847 - specificity: 0.7589 - acc: 0.8288 - val_loss: 0.3249 - val_sensitivity: 0.9495 - val_specificity: 0.8084 - val_acc: 0.8224
# Epoch 20/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3729 - sensitivity: 0.9930 - specificity: 0.7692 - acc: 0.8357Epoch 00020: val_loss improved from 0.32376 to 0.31237, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.3747 - sensitivity: 0.9932 - specificity: 0.7644 - acc: 0.8329 - val_loss: 0.3124 - val_sensitivity: 0.9269 - val_specificity: 0.8179 - val_acc: 0.8288
# Epoch 21/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3456 - sensitivity: 0.9899 - specificity: 0.7908 - acc: 0.8518Epoch 00021: val_loss improved from 0.31237 to 0.30997, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.3455 - sensitivity: 0.9902 - specificity: 0.7871 - acc: 0.8491 - val_loss: 0.3100 - val_sensitivity: 0.9123 - val_specificity: 0.8209 - val_acc: 0.8323
# Epoch 22/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3479 - sensitivity: 0.9957 - specificity: 0.7700 - acc: 0.8402Epoch 00022: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3459 - sensitivity: 0.9958 - specificity: 0.7708 - acc: 0.8409 - val_loss: 0.3173 - val_sensitivity: 0.9495 - val_specificity: 0.8084 - val_acc: 0.8224
# Epoch 23/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3292 - sensitivity: 0.9956 - specificity: 0.7866 - acc: 0.8536Epoch 00023: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.3257 - sensitivity: 0.9957 - specificity: 0.7907 - acc: 0.8567 - val_loss: 0.3239 - val_sensitivity: 0.9553 - val_specificity: 0.7995 - val_acc: 0.8148
# Epoch 24/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3855 - sensitivity: 0.9861 - specificity: 0.7727 - acc: 0.8380Epoch 00024: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3846 - sensitivity: 0.9865 - specificity: 0.7738 - acc: 0.8392 - val_loss: 0.3358 - val_sensitivity: 0.9481 - val_specificity: 0.7903 - val_acc: 0.8061
# Epoch 25/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3377 - sensitivity: 0.9930 - specificity: 0.7808 - acc: 0.8454Epoch 00025: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3385 - sensitivity: 0.9932 - specificity: 0.7791 - acc: 0.8435 - val_loss: 0.3168 - val_sensitivity: 0.9495 - val_specificity: 0.8052 - val_acc: 0.8195
# Epoch 26/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3251 - sensitivity: 0.9925 - specificity: 0.7846 - acc: 0.8515Epoch 00026: val_loss improved from 0.30997 to 0.30484, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.3270 - sensitivity: 0.9927 - specificity: 0.7843 - acc: 0.8517 - val_loss: 0.3048 - val_sensitivity: 0.9398 - val_specificity: 0.8139 - val_acc: 0.8270
# Epoch 27/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3519 - sensitivity: 0.9922 - specificity: 0.7684 - acc: 0.8358Epoch 00027: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.3594 - sensitivity: 0.9889 - specificity: 0.7680 - acc: 0.8346 - val_loss: 0.3158 - val_sensitivity: 0.9350 - val_specificity: 0.8077 - val_acc: 0.8206
# Epoch 28/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3048 - sensitivity: 0.9980 - specificity: 0.8037 - acc: 0.8631Epoch 00028: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.3086 - sensitivity: 0.9980 - specificity: 0.8002 - acc: 0.8601 - val_loss: 0.3515 - val_sensitivity: 0.9466 - val_specificity: 0.7913 - val_acc: 0.8066
# Epoch 29/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3143 - sensitivity: 0.9927 - specificity: 0.8061 - acc: 0.8645Epoch 00029: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3139 - sensitivity: 0.9929 - specificity: 0.8052 - acc: 0.8632 - val_loss: 0.3240 - val_sensitivity: 0.9466 - val_specificity: 0.7996 - val_acc: 0.8142
# Epoch 30/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3435 - sensitivity: 0.9963 - specificity: 0.7714 - acc: 0.8412Epoch 00030: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.3395 - sensitivity: 0.9964 - specificity: 0.7731 - acc: 0.8423 - val_loss: 0.3486 - val_sensitivity: 0.9612 - val_specificity: 0.7874 - val_acc: 0.8043
# Epoch 31/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3423 - sensitivity: 0.9876 - specificity: 0.7996 - acc: 0.8550Epoch 00031: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3395 - sensitivity: 0.9880 - specificity: 0.7993 - acc: 0.8551 - val_loss: 0.3477 - val_sensitivity: 0.9651 - val_specificity: 0.7876 - val_acc: 0.8043
# Epoch 32/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3421 - sensitivity: 0.9950 - specificity: 0.7702 - acc: 0.8374Epoch 00032: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3398 - sensitivity: 0.9951 - specificity: 0.7698 - acc: 0.8363 - val_loss: 0.3450 - val_sensitivity: 0.9466 - val_specificity: 0.7841 - val_acc: 0.8002
# Epoch 33/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3245 - sensitivity: 0.9986 - specificity: 0.7867 - acc: 0.8540Epoch 00033: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3297 - sensitivity: 0.9974 - specificity: 0.7862 - acc: 0.8542 - val_loss: 0.3147 - val_sensitivity: 0.9408 - val_specificity: 0.8077 - val_acc: 0.8212
# Epoch 34/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3251 - sensitivity: 0.9935 - specificity: 0.7766 - acc: 0.8415Epoch 00034: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3273 - sensitivity: 0.9936 - specificity: 0.7763 - acc: 0.8420 - val_loss: 0.3155 - val_sensitivity: 0.9408 - val_specificity: 0.8121 - val_acc: 0.8253
# Epoch 35/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2877 - sensitivity: 1.0000 - specificity: 0.7896 - acc: 0.8545Epoch 00035: val_loss improved from 0.30484 to 0.29210, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 36s 1s/step - loss: 0.2843 - sensitivity: 1.0000 - specificity: 0.7937 - acc: 0.8574 - val_loss: 0.2921 - val_sensitivity: 0.7709 - val_specificity: 0.8179 - val_acc: 0.8299
# Epoch 36/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3009 - sensitivity: 0.9916 - specificity: 0.7962 - acc: 0.8570Epoch 00036: val_loss did not improve
# 34/34 [==============================] - 33s 983ms/step - loss: 0.2991 - sensitivity: 0.9918 - specificity: 0.7982 - acc: 0.8582 - val_loss: 0.3063 - val_sensitivity: 0.9466 - val_specificity: 0.8101 - val_acc: 0.8241
# Epoch 37/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3000 - sensitivity: 0.9931 - specificity: 0.7936 - acc: 0.8539Epoch 00037: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.3022 - sensitivity: 0.9933 - specificity: 0.7899 - acc: 0.8517 - val_loss: 0.3089 - val_sensitivity: 0.9466 - val_specificity: 0.8063 - val_acc: 0.8206
# Epoch 38/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2952 - sensitivity: 0.9971 - specificity: 0.7983 - acc: 0.8599Epoch 00038: val_loss improved from 0.29210 to 0.28123, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.2952 - sensitivity: 0.9972 - specificity: 0.7982 - acc: 0.8606 - val_loss: 0.2812 - val_sensitivity: 0.9196 - val_specificity: 0.8249 - val_acc: 0.8346
# Epoch 39/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2960 - sensitivity: 0.9937 - specificity: 0.8027 - acc: 0.8609Epoch 00039: val_loss improved from 0.28123 to 0.27399, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.2933 - sensitivity: 0.9939 - specificity: 0.8036 - acc: 0.8614 - val_loss: 0.2740 - val_sensitivity: 0.9002 - val_specificity: 0.8297 - val_acc: 0.8381
# Epoch 40/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3047 - sensitivity: 0.9939 - specificity: 0.8007 - acc: 0.8580Epoch 00040: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3010 - sensitivity: 0.9941 - specificity: 0.8021 - acc: 0.8592 - val_loss: 0.2794 - val_sensitivity: 0.9099 - val_specificity: 0.8302 - val_acc: 0.8398
# Epoch 41/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2763 - sensitivity: 0.9966 - specificity: 0.8076 - acc: 0.8654Epoch 00041: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.2793 - sensitivity: 0.9967 - specificity: 0.8063 - acc: 0.8641 - val_loss: 0.2746 - val_sensitivity: 0.8798 - val_specificity: 0.8436 - val_acc: 0.8497
# Epoch 42/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2812 - sensitivity: 0.9984 - specificity: 0.8009 - acc: 0.8613Epoch 00042: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.2836 - sensitivity: 0.9985 - specificity: 0.8005 - acc: 0.8613 - val_loss: 0.2753 - val_sensitivity: 0.8691 - val_specificity: 0.8518 - val_acc: 0.8561
# Epoch 43/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.3130 - sensitivity: 0.9888 - specificity: 0.7855 - acc: 0.8478Epoch 00043: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.3100 - sensitivity: 0.9891 - specificity: 0.7875 - acc: 0.8494 - val_loss: 0.3000 - val_sensitivity: 0.9335 - val_specificity: 0.8171 - val_acc: 0.8294
# Epoch 44/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2618 - sensitivity: 0.9986 - specificity: 0.8017 - acc: 0.8610Epoch 00044: val_loss did not improve
# 34/34 [==============================] - 33s 974ms/step - loss: 0.2612 - sensitivity: 0.9987 - specificity: 0.8034 - acc: 0.8627 - val_loss: 0.3143 - val_sensitivity: 0.9335 - val_specificity: 0.8121 - val_acc: 0.8247
# Epoch 45/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2846 - sensitivity: 0.9986 - specificity: 0.8066 - acc: 0.8663Epoch 00045: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.2880 - sensitivity: 0.9986 - specificity: 0.8058 - acc: 0.8661 - val_loss: 0.3188 - val_sensitivity: 0.9408 - val_specificity: 0.8095 - val_acc: 0.8229
# Epoch 46/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2703 - sensitivity: 0.9965 - specificity: 0.8052 - acc: 0.8631Epoch 00046: val_loss improved from 0.27399 to 0.27300, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.2711 - sensitivity: 0.9966 - specificity: 0.8038 - acc: 0.8625 - val_loss: 0.2730 - val_sensitivity: 0.9408 - val_specificity: 0.8266 - val_acc: 0.8387
# Epoch 47/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2733 - sensitivity: 0.9968 - specificity: 0.8074 - acc: 0.8689Epoch 00047: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.2716 - sensitivity: 0.9969 - specificity: 0.8082 - acc: 0.8692 - val_loss: 0.2829 - val_sensitivity: 0.9408 - val_specificity: 0.8172 - val_acc: 0.8299
# Epoch 48/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2900 - sensitivity: 0.9920 - specificity: 0.7998 - acc: 0.8554Epoch 00048: val_loss improved from 0.27300 to 0.26848, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.2937 - sensitivity: 0.9906 - specificity: 0.7990 - acc: 0.8549 - val_loss: 0.2685 - val_sensitivity: 0.9327 - val_specificity: 0.8290 - val_acc: 0.8398
# Epoch 49/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2553 - sensitivity: 1.0000 - specificity: 0.8160 - acc: 0.8718Epoch 00049: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.2555 - sensitivity: 1.0000 - specificity: 0.8170 - acc: 0.8726 - val_loss: 0.3344 - val_sensitivity: 0.9466 - val_specificity: 0.8043 - val_acc: 0.8189
# Epoch 50/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2835 - sensitivity: 0.9943 - specificity: 0.7936 - acc: 0.8537Epoch 00050: val_loss improved from 0.26848 to 0.26803, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.2851 - sensitivity: 0.9945 - specificity: 0.7940 - acc: 0.8545 - val_loss: 0.2680 - val_sensitivity: 0.9359 - val_specificity: 0.8375 - val_acc: 0.8480
# Epoch 51/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2775 - sensitivity: 0.9987 - specificity: 0.8114 - acc: 0.8686Epoch 00051: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.2755 - sensitivity: 0.9987 - specificity: 0.8130 - acc: 0.8695 - val_loss: 0.3009 - val_sensitivity: 0.9466 - val_specificity: 0.8159 - val_acc: 0.8294
# Epoch 52/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2780 - sensitivity: 0.9955 - specificity: 0.7969 - acc: 0.8566Epoch 00052: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.2823 - sensitivity: 0.9939 - specificity: 0.7974 - acc: 0.8567 - val_loss: 0.3265 - val_sensitivity: 0.9408 - val_specificity: 0.8107 - val_acc: 0.8241
# Epoch 53/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2661 - sensitivity: 0.9918 - specificity: 0.8185 - acc: 0.8722Epoch 00053: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.2687 - sensitivity: 0.9921 - specificity: 0.8164 - acc: 0.8701 - val_loss: 0.3155 - val_sensitivity: 0.9189 - val_specificity: 0.8152 - val_acc: 0.8270
# Epoch 54/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2688 - sensitivity: 0.9953 - specificity: 0.8052 - acc: 0.8642Epoch 00054: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.2695 - sensitivity: 0.9954 - specificity: 0.8049 - acc: 0.8635 - val_loss: 0.2706 - val_sensitivity: 0.9072 - val_specificity: 0.8298 - val_acc: 0.8387
# Epoch 55/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2523 - sensitivity: 0.9981 - specificity: 0.8239 - acc: 0.8751Epoch 00055: val_loss did not improve
# 34/34 [==============================] - 33s 972ms/step - loss: 0.2518 - sensitivity: 0.9982 - specificity: 0.8232 - acc: 0.8747 - val_loss: 0.2686 - val_sensitivity: 0.8553 - val_specificity: 0.8554 - val_acc: 0.8596
# Epoch 56/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2690 - sensitivity: 0.9952 - specificity: 0.8190 - acc: 0.8738Epoch 00056: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.2675 - sensitivity: 0.9953 - specificity: 0.8184 - acc: 0.8733 - val_loss: 0.2729 - val_sensitivity: 0.9208 - val_specificity: 0.8310 - val_acc: 0.8404
# Epoch 57/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2541 - sensitivity: 0.9983 - specificity: 0.8138 - acc: 0.8718Epoch 00057: val_loss did not improve
# 34/34 [==============================] - 33s 978ms/step - loss: 0.2531 - sensitivity: 0.9984 - specificity: 0.8135 - acc: 0.8714 - val_loss: 0.2908 - val_sensitivity: 0.9299 - val_specificity: 0.8200 - val_acc: 0.8317
# Epoch 58/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2438 - sensitivity: 0.9944 - specificity: 0.8309 - acc: 0.8801Epoch 00058: val_loss improved from 0.26803 to 0.26429, saving model to ../model/checkpoints/BestKerasResnet50_flat_2_loss.h5
# 34/34 [==============================] - 35s 1s/step - loss: 0.2474 - sensitivity: 0.9946 - specificity: 0.8320 - acc: 0.8813 - val_loss: 0.2643 - val_sensitivity: 0.9169 - val_specificity: 0.8395 - val_acc: 0.8480
# Epoch 59/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2434 - sensitivity: 0.9977 - specificity: 0.8243 - acc: 0.8777Epoch 00059: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.2456 - sensitivity: 0.9977 - specificity: 0.8241 - acc: 0.8778 - val_loss: 0.2650 - val_sensitivity: 0.9218 - val_specificity: 0.8466 - val_acc: 0.8550
# Epoch 60/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2436 - sensitivity: 0.9969 - specificity: 0.8164 - acc: 0.8739Epoch 00060: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.2439 - sensitivity: 0.9970 - specificity: 0.8145 - acc: 0.8723 - val_loss: 0.2765 - val_sensitivity: 0.9254 - val_specificity: 0.8384 - val_acc: 0.8480
# Epoch 61/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2665 - sensitivity: 0.9955 - specificity: 0.8165 - acc: 0.8674Epoch 00061: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.2638 - sensitivity: 0.9957 - specificity: 0.8179 - acc: 0.8683 - val_loss: 0.2809 - val_sensitivity: 0.8713 - val_specificity: 0.8658 - val_acc: 0.8690
# Epoch 62/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2403 - sensitivity: 0.9946 - specificity: 0.8195 - acc: 0.8757Epoch 00062: val_loss did not improve
# 34/34 [==============================] - 33s 974ms/step - loss: 0.2373 - sensitivity: 0.9948 - specificity: 0.8216 - acc: 0.8770 - val_loss: 0.2844 - val_sensitivity: 0.8771 - val_specificity: 0.8473 - val_acc: 0.8526
# Epoch 63/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2613 - sensitivity: 0.9956 - specificity: 0.8080 - acc: 0.8669Epoch 00063: val_loss did not improve
# 34/34 [==============================] - 33s 974ms/step - loss: 0.2630 - sensitivity: 0.9957 - specificity: 0.8085 - acc: 0.8673 - val_loss: 0.2710 - val_sensitivity: 0.9014 - val_specificity: 0.8588 - val_acc: 0.8649
# Epoch 64/500
# 33/34 [============================>.] - ETA: 0s - loss: 0.2504 - sensitivity: 0.9964 - specificity: 0.8200 - acc: 0.8736Epoch 00064: val_loss did not improve
# 34/34 [==============================] - 33s 973ms/step - loss: 0.2499 - sensitivity: 0.9965 - specificity: 0.8183 - acc: 0.8720 - val_loss: 0.2962 - val_sensitivity: 0.9335 - val_specificity: 0.8240 - val_acc: 0.8358
# Epoch 65/500
# 27/34 [======================>.......] - ETA: 4s - loss: 0.2477 - sensitivity: 0.9957 - specificity: 0.8236 - acc: 0.8785

# %% [raw]
# model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid) #gen_flow_val,  #(X_valid, Y_valid),
#                     steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
#                     #validation_steps=int(np.ceil(len(X_valid)/batch_size)),
#                     epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
#                     class_weight = class_weight)
#                     #class_weights = class_weight

# %% [markdown]
# ## IV. Visualize  TSNE

# %%
# %matplotlib inline
import numpy as np
# visualize the points' distribution of train data using features built from base_model
import matplotlib.pyplot as plt
# dimension reduction
from sklearn.manifold import TSNE 
import numpy as np

def t_sne_vis(name, base_model, x_processed_images, random_state, labels):
    """
    :param name: the name of the cnn model used to build features
    :param base_model: the model obj
    :param x_processed_images: the input images for our model
    :param random_state: for fixing the results
    :param labels: 0/1 classification labels
    :return:
    the graph of image distribution based on features extracted from the model and the t-sne features
    """
    # convert data to images
    print('Converting data points to composite image')
    X_train = x_processed_images
    print('we got %d different images of shape %dx%d ' % (len(X_train), X_train.shape[1], X_train.shape[1]))
    print('build usefull features from the selected model')
    features = base_model.predict(X_train)
    x_data1 = np.asarray(features).astype('float64')
    x_data1 = x_data1.reshape((x_data1.shape[0], -1))
    # perform t-SNE embedding
    print('performing t-sne reduction')
    vis_data = TSNE(perplexity=100, random_state=random_state).fit_transform(x_data1)
    # plot the result
    fig = plt.figure(figsize=(15, 15))
    vis_x = vis_data[:, 0]
    vis_y = vis_data[:, 1]
    plt.scatter(vis_x, vis_y, c=labels, cmap=plt.cm.get_cmap("winter", 2))
    plt.colorbar(ticks=range(2))
    plt.clim(0, 1)
    plt.title(name)
    plt.grid()
    plt.show()
    fig.savefig('tsne_vis_'+name+'.png')
    return vis_data

# %%
model.summary()

# %%
name = 'Resnet'
print('visualizing for %s' %name)
base_model_ = Model(input=model.input, output=model.get_layer('avg_pool').output)
tsne_feats = t_sne_vis(name, base_model_, X_valid, np.random.RandomState(42), Y_valid)

# %% [markdown]
# ## V. Evaluate Model

# %%
model = load_model(weights_path+"BestKerasResnet50_flat_2_loss.h5", custom_objects={'sensitivity': sensitivity,
                                                                             "specificity":specificity,
                                                                              "loss1":loss1})
score = model.evaluate(X_valid, Y_valid, verbose=1)
print('Test loss:', score[0])
print('Test sensitivity:', score[1])
print('Test specificity:', score[2])
print('Test acc:', score[3])

# %%
#compute metrics
pred = model.predict(X_valid)
average_precision = average_precision_score(Y_valid, pred)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))

# %%
precision, recall, _ = precision_recall_curve(Y_valid, pred)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))

# %%
def generate_results(y_test, y_score):
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.show()
    print('AUC: %f' % roc_auc)

# %%
generate_results

# %% [markdown]
# #compute log loss
# pred = model.predict(X_valid)
# log_loss(Y_valid,pred)

# %% [markdown]
# ## VI. Retrain on full dataset

# %% [raw]
# #Generate the training data
# #Create 3 bands having HH, HV and avg of both
# X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
# X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
# X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],
#                           ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)

# %% [raw]
# #parse corrupted notebook file
# t = ["#Generate the training data\n",
#     "#Create 3 bands having HH, HV and avg of both\n",
#     "X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_1\"]])\n",
#     "X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_2\"]])\n",
#     "X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],\n",
#     "                          ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)"]
# #t.remove("\n")
# t=[x.replace("\n",'') for x in t]
# for x in t:
#     print(x)
