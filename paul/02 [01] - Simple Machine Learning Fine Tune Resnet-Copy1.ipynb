# %% [markdown]
# # Skin Cancer Classification Challenge

# %% [markdown]
# **Summary : ** skin cancer.

# %% [markdown]
# ## Preliminaries and Imports

# %%
#general & system\n",
import os

#data processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 10, 10  #default setting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#data augmentation
from PIL import Image
from random import choice
import cv2
import numpy as np
#import keras.preprocessing.image as prep

#ML part
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing import image as kimage
from keras.models import Sequential
from keras.layers import GlobalMaxPooling2D, Dense, BatchNormalization, GlobalAveragePooling2D,Dropout,Activation,Flatten
from keras.models import Model
from keras.optimizers import SGD
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

#validation
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score


from sklearn.metrics import precision_recall_curve
from imblearn.over_sampling import SMOTE
from sklearn.utils import resample

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## I. Load Data

# %% [markdown]
# - **Rq : ** Datasets are quite light, can be fully loaded in a laptop memory with ease.

# %%
# %%time
meta = pd.read_csv("../data/label_learn.csv", sep = ";")
# Out:
# CPU times: user 4 ms, sys: 4 ms, total: 8 ms
# Wall time: 5.79 ms

# %%
meta.head()
# Out:
#           name      label
# 0  0000000.jpg     benign
# 1  0000002.jpg  malignant
# 2  0000006.jpg     benign
# 3  0000008.jpg     benign
# 4  0000009.jpg     benign

# %%
# %%time
train_list = os.listdir("../data/resized_train/")
len(train_list) == len(meta.name)
# Out:
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 3.82 ms

# %%
train_list.sort() == list(meta.name).sort()
# Out:
# True

# %%
# %%time
X_train = np.array([np.array(Image.open("../data/resized_train/"+fname)) for fname in meta.name])
Y_train = [1 if x=="malignant" else 0 for x in meta.label]
Y_train = np.array(Y_train)
# Out:
# CPU times: user 22.3 s, sys: 1.82 s, total: 24.1 s
# Wall time: 24.1 s

# %%
print(X_train.shape)
print(len(Y_train))
X_train.shape[0] == len(meta.name) == len(Y_train)
# Out:
# (8581, 299, 299, 3)
# 8581
# True

# %%
#control
print(meta.name[0:5])
print(Y_train[0:5])
print(meta.label[0:5])
# Out:
# 0    0000000.jpg
# 1    0000002.jpg
# 2    0000006.jpg
# 3    0000008.jpg
# 4    0000009.jpg
# Name: name, dtype: object
# [0 1 0 0 0]
# 0       benign
# 1    malignant
# 2       benign
# 3       benign
# 4       benign
# Name: label, dtype: object

# %% [markdown]
# ## II. Data Preparation

# %% [markdown]
# - **Class weights**

# %%
class_weight_or = class_weight.compute_class_weight('balanced', np.unique(Y_train), Y_train)

# %% [markdown]
# - **Data splitting**

# %%
#data splitting
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train, Y_train, random_state=42, train_size=0.80)
# Out:
# /home/dvp_tran/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# - **Resampling**

# %%
temp = sum(Y_train)
sample_size = temp*2700/(374+254)  #1372
sample_size
# Out:
# 2325

# %%
def random_undersampling(X, Y,sample_size = sample_size, n_sample=1):
    """
    X,y : numpy arrays
    return :
    5 random ensemble of indices general_balenced_set:
        general_balenced_set[0] = the shuffeled indices that inssure the class balance
    """
    indices = np.array(range(len(Y)))
    positive_samples = indices[Y==1]
    #print(type(positive_samples))
    negative_samples = indices[Y==0]
    #print(type(negative_samples))
    general_balenced_set = []
    for k in range(n_sample):
        indices_ = np.random.choice(negative_samples, sample_size, replace=False)
        #print(len(indices_))
        # append positive and negative
        balenced_set = np.append(indices_, positive_samples)
        #print(len(balenced_set))
        # shuffle indices
        np.random.shuffle(balenced_set)
        #print(len(balenced_set))
        general_balenced_set.append(balenced_set)
    return general_balenced_set

# %%
general_balenced_set = random_undersampling(X_train,Y_train)
X_train = X_train[general_balenced_set]
Y_train = Y_train[general_balenced_set]

# %% [markdown]
# ## III. Deep Learning with Transfer Learning

# %%
weights_path = '../model/checkpoints/'

if not os.path.exists(weights_path):
    os.makedirs(weights_path)
    
epochs = 500
batch_size = 50

# %% [markdown]
# - **Using RESNET : **

# %%
#load base model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(299,299,3))
base_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
#adding top layers
    #sequentialy
add_model = Sequential()
add_model.add(GlobalAveragePooling2D(input_shape=base_model.output_shape[1:])) #Flatten/GlobalAveragePooling2D
add_model.add(Dense(1024, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(512, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(1, activation='sigmoid'))

model = Model(inputs=base_model.input, outputs=add_model(base_model.output))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1)            2623489     avg_pool[0][0]
# ==================================================================================================
# Total params: 26,211,201
# Trainable params: 26,158,081
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [raw]
# #adding top layers
#     #need to check api to add layers sequentialy
# x = base_model.output
# x = GlobalAveragePooling2D()(x) #Flatten instead?
# x = Dense(1024, activation='relu')(x)
# x = Dropout(0.25)(x)
# x = Dense(512, activation='relu')(x)
# x = Dropout(0.25)(x)
# predictions = Dense(1, activation='sigmoid')(x)
#
# model = Model(inputs=base_model.input, outputs=predictions)
# model.summary()

# %%
from keras import backend as K

def weighted_categorical_crossentropy(weights):
    """
    [w_0, w_1] : weight of 0 class and weight of 1 class
    """
    weights = K.variable(weights)

    def loss(y_true, y_pred):
        # scale predictions so that the class probas of each sample sum to 1
        #y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
        # clip to prevent NaN's and Inf's
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        # calc
        loss = y_true * K.log(y_pred) * weights[1] + (1 - y_true) * K.log(1 - y_pred) * weights[0]
        loss = -K.sum(loss, -1)
        return loss

    return loss

# %%
class_weight_or
# Out:
# array([ 0.54296381,  6.31885125])

# %%
loss1 = weighted_categorical_crossentropy(np.array([0.8,4]))

# %%
#freeze lower layers of the model
#for layer in model.layers[:]:
    #layer.trainable = False
for layer in model.layers[0:]:
    layer.trainable = True
    

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())




#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss=loss1, #binary_crossentropy
              metrics=[sensitivity, specificity,"accuracy"])

# %%
# %%time
#Lets define the image transormations that we wan

gen = ImageDataGenerator(horizontal_flip=True,
                         vertical_flip=True,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         zoom_range=0.2,
                         rotation_range=40)

val_datagen = ImageDataGenerator()
# Here is the function that merges our two generators
# We use the exact same generator with the same random seed for both the y and angle arrays
def gen_flow_for_one_input(X1, y):
    genX1 = gen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]

def val_datagen_(X1, y):
    genX1 = val_datagen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]
#Finally create out generator
gen_flow_train = gen_flow_for_one_input(X_train, Y_train)
#gen_flow_val = gen_flow_for_one_input(X_valid, Y_valid)
gen_flow_val = val_datagen_(X_valid, Y_valid)

from keras.callbacks import EarlyStopping, ModelCheckpoint
epochs_to_wait_for_improve = 30
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=epochs_to_wait_for_improve)
checkpoint_callback = ModelCheckpoint(weights_path + 'BestKerasResnet50_flat_3_loss.h5', monitor='val_loss',
                                      verbose=1, save_best_only=True, mode='min')
#fit the model
model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid),
                    steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
                    epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
                    class_weight = class_weight_or)
# Out:
# Epoch 1/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.8346 - sensitivity: 0.7124 - specificity: 0.6391 - acc: 0.6550Epoch 00001: val_loss improved from inf to 0.59485, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 75s 1s/step - loss: 0.8343 - sensitivity: 0.7139 - specificity: 0.6397 - acc: 0.6558 - val_loss: 0.5949 - val_sensitivity: 0.7380 - val_specificity: 0.8233 - val_acc: 0.8183
# Epoch 2/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.6243 - sensitivity: 0.8947 - specificity: 0.7503 - acc: 0.7740Epoch 00002: val_loss improved from 0.59485 to 0.46550, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 52s 905ms/step - loss: 0.6274 - sensitivity: 0.8953 - specificity: 0.7509 - acc: 0.7748 - val_loss: 0.4655 - val_sensitivity: 0.7352 - val_specificity: 0.8769 - val_acc: 0.8695
# Epoch 3/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.5101 - sensitivity: 0.9157 - specificity: 0.8166 - acc: 0.8330Epoch 00003: val_loss improved from 0.46550 to 0.39800, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.5102 - sensitivity: 0.9150 - specificity: 0.8161 - acc: 0.8324 - val_loss: 0.3980 - val_sensitivity: 0.6597 - val_specificity: 0.9032 - val_acc: 0.8864
# Epoch 4/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.4867 - sensitivity: 0.9169 - specificity: 0.8214 - acc: 0.8355Epoch 00004: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.4888 - sensitivity: 0.9149 - specificity: 0.8224 - acc: 0.8360 - val_loss: 0.4023 - val_sensitivity: 0.6681 - val_specificity: 0.9135 - val_acc: 0.8969
# Epoch 5/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.4499 - sensitivity: 0.9049 - specificity: 0.8440 - acc: 0.8527Epoch 00005: val_loss improved from 0.39800 to 0.37763, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.4491 - sensitivity: 0.9066 - specificity: 0.8444 - acc: 0.8536 - val_loss: 0.3776 - val_sensitivity: 0.6977 - val_specificity: 0.9121 - val_acc: 0.8987
# Epoch 6/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.4142 - sensitivity: 0.9323 - specificity: 0.8424 - acc: 0.8592Epoch 00006: val_loss improved from 0.37763 to 0.35112, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.4127 - sensitivity: 0.9335 - specificity: 0.8426 - acc: 0.8596 - val_loss: 0.3511 - val_sensitivity: 0.7077 - val_specificity: 0.8982 - val_acc: 0.8870
# Epoch 7/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3917 - sensitivity: 0.9298 - specificity: 0.8412 - acc: 0.8560Epoch 00007: val_loss improved from 0.35112 to 0.33598, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3925 - sensitivity: 0.9296 - specificity: 0.8431 - acc: 0.8575 - val_loss: 0.3360 - val_sensitivity: 0.7239 - val_specificity: 0.9044 - val_acc: 0.8940
# Epoch 8/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3788 - sensitivity: 0.9467 - specificity: 0.8478 - acc: 0.8638Epoch 00008: val_loss improved from 0.33598 to 0.33028, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3853 - sensitivity: 0.9450 - specificity: 0.8481 - acc: 0.8637 - val_loss: 0.3303 - val_sensitivity: 0.7366 - val_specificity: 0.9000 - val_acc: 0.8917
# Epoch 9/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3910 - sensitivity: 0.9358 - specificity: 0.8400 - acc: 0.8574Epoch 00009: val_loss improved from 0.33028 to 0.31271, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3876 - sensitivity: 0.9370 - specificity: 0.8408 - acc: 0.8582 - val_loss: 0.3127 - val_sensitivity: 0.7682 - val_specificity: 0.8791 - val_acc: 0.8748
# Epoch 10/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3878 - sensitivity: 0.9305 - specificity: 0.8593 - acc: 0.8707Epoch 00010: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3892 - sensitivity: 0.9303 - specificity: 0.8595 - acc: 0.8708 - val_loss: 0.3138 - val_sensitivity: 0.7628 - val_specificity: 0.8814 - val_acc: 0.8771
# Epoch 11/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3871 - sensitivity: 0.9462 - specificity: 0.8353 - acc: 0.8532Epoch 00011: val_loss improved from 0.31271 to 0.29385, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.3830 - sensitivity: 0.9472 - specificity: 0.8373 - acc: 0.8550 - val_loss: 0.2938 - val_sensitivity: 0.8146 - val_specificity: 0.8829 - val_acc: 0.8812
# Epoch 12/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3367 - sensitivity: 0.9537 - specificity: 0.8647 - acc: 0.8796Epoch 00012: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3415 - sensitivity: 0.9505 - specificity: 0.8646 - acc: 0.8789 - val_loss: 0.2951 - val_sensitivity: 0.8327 - val_specificity: 0.8698 - val_acc: 0.8701
# Epoch 13/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3581 - sensitivity: 0.9363 - specificity: 0.8572 - acc: 0.8706Epoch 00013: val_loss improved from 0.29385 to 0.28619, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3600 - sensitivity: 0.9374 - specificity: 0.8552 - acc: 0.8690 - val_loss: 0.2862 - val_sensitivity: 0.8301 - val_specificity: 0.8754 - val_acc: 0.8754
# Epoch 14/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3667 - sensitivity: 0.9283 - specificity: 0.8513 - acc: 0.8642Epoch 00014: val_loss improved from 0.28619 to 0.28463, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3664 - sensitivity: 0.9261 - specificity: 0.8508 - acc: 0.8634 - val_loss: 0.2846 - val_sensitivity: 0.7978 - val_specificity: 0.8772 - val_acc: 0.8748
# Epoch 15/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3374 - sensitivity: 0.9465 - specificity: 0.8639 - acc: 0.8759Epoch 00015: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3383 - sensitivity: 0.9474 - specificity: 0.8626 - acc: 0.8750 - val_loss: 0.2883 - val_sensitivity: 0.8519 - val_specificity: 0.8595 - val_acc: 0.8631
# Epoch 16/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3357 - sensitivity: 0.9431 - specificity: 0.8487 - acc: 0.8650Epoch 00016: val_loss improved from 0.28463 to 0.28408, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.3343 - sensitivity: 0.9441 - specificity: 0.8489 - acc: 0.8652 - val_loss: 0.2841 - val_sensitivity: 0.8533 - val_specificity: 0.8640 - val_acc: 0.8666
# Epoch 17/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3515 - sensitivity: 0.9319 - specificity: 0.8519 - acc: 0.8649Epoch 00017: val_loss improved from 0.28408 to 0.28313, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.3549 - sensitivity: 0.9317 - specificity: 0.8517 - acc: 0.8648 - val_loss: 0.2831 - val_sensitivity: 0.7643 - val_specificity: 0.8859 - val_acc: 0.8818
# Epoch 18/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3277 - sensitivity: 0.9553 - specificity: 0.8556 - acc: 0.8724Epoch 00018: val_loss improved from 0.28313 to 0.27600, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.3295 - sensitivity: 0.9529 - specificity: 0.8563 - acc: 0.8725 - val_loss: 0.2760 - val_sensitivity: 0.8941 - val_specificity: 0.8615 - val_acc: 0.8660
# Epoch 19/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3302 - sensitivity: 0.9529 - specificity: 0.8555 - acc: 0.8724Epoch 00019: val_loss improved from 0.27600 to 0.27130, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3289 - sensitivity: 0.9517 - specificity: 0.8559 - acc: 0.8725 - val_loss: 0.2713 - val_sensitivity: 0.8203 - val_specificity: 0.8717 - val_acc: 0.8725
# Epoch 20/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3151 - sensitivity: 0.9577 - specificity: 0.8540 - acc: 0.8721Epoch 00020: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3159 - sensitivity: 0.9570 - specificity: 0.8543 - acc: 0.8722 - val_loss: 0.3071 - val_sensitivity: 0.8767 - val_specificity: 0.8507 - val_acc: 0.8573
# Epoch 21/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3347 - sensitivity: 0.9432 - specificity: 0.8640 - acc: 0.8777Epoch 00021: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3325 - sensitivity: 0.9442 - specificity: 0.8651 - acc: 0.8788 - val_loss: 0.2903 - val_sensitivity: 0.8786 - val_specificity: 0.8587 - val_acc: 0.8637
# Epoch 22/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3011 - sensitivity: 0.9648 - specificity: 0.8673 - acc: 0.8846Epoch 00022: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3026 - sensitivity: 0.9634 - specificity: 0.8662 - acc: 0.8834 - val_loss: 0.2928 - val_sensitivity: 0.8640 - val_specificity: 0.8563 - val_acc: 0.8608
# Epoch 23/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3343 - sensitivity: 0.9517 - specificity: 0.8490 - acc: 0.8652Epoch 00023: val_loss improved from 0.27130 to 0.26143, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3409 - sensitivity: 0.9494 - specificity: 0.8476 - acc: 0.8637 - val_loss: 0.2614 - val_sensitivity: 0.8834 - val_specificity: 0.8761 - val_acc: 0.8789
# Epoch 24/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2861 - sensitivity: 0.9626 - specificity: 0.8704 - acc: 0.8859Epoch 00024: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2863 - sensitivity: 0.9607 - specificity: 0.8719 - acc: 0.8869 - val_loss: 0.2815 - val_sensitivity: 0.8906 - val_specificity: 0.8642 - val_acc: 0.8684
# Epoch 25/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3067 - sensitivity: 0.9548 - specificity: 0.8652 - acc: 0.8821Epoch 00025: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3083 - sensitivity: 0.9533 - specificity: 0.8661 - acc: 0.8824 - val_loss: 0.2766 - val_sensitivity: 0.8796 - val_specificity: 0.8674 - val_acc: 0.8701
# Epoch 26/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2888 - sensitivity: 0.9707 - specificity: 0.8640 - acc: 0.8817Epoch 00026: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2905 - sensitivity: 0.9699 - specificity: 0.8640 - acc: 0.8816 - val_loss: 0.2704 - val_sensitivity: 0.8796 - val_specificity: 0.8711 - val_acc: 0.8736
# Epoch 27/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3121 - sensitivity: 0.9356 - specificity: 0.8665 - acc: 0.8781Epoch 00027: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3113 - sensitivity: 0.9367 - specificity: 0.8666 - acc: 0.8785 - val_loss: 0.2644 - val_sensitivity: 0.8388 - val_specificity: 0.8926 - val_acc: 0.8917
# Epoch 28/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3020 - sensitivity: 0.9482 - specificity: 0.8705 - acc: 0.8810Epoch 00028: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.3015 - sensitivity: 0.9461 - specificity: 0.8712 - acc: 0.8813 - val_loss: 0.2723 - val_sensitivity: 0.8339 - val_specificity: 0.8736 - val_acc: 0.8748
# Epoch 29/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2893 - sensitivity: 0.9652 - specificity: 0.8684 - acc: 0.8842Epoch 00029: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2891 - sensitivity: 0.9659 - specificity: 0.8680 - acc: 0.8838 - val_loss: 0.2792 - val_sensitivity: 0.8436 - val_specificity: 0.8735 - val_acc: 0.8754
# Epoch 30/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3065 - sensitivity: 0.9530 - specificity: 0.8719 - acc: 0.8850Epoch 00030: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.3045 - sensitivity: 0.9538 - specificity: 0.8718 - acc: 0.8852 - val_loss: 0.2831 - val_sensitivity: 0.8398 - val_specificity: 0.8629 - val_acc: 0.8655
# Epoch 31/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2862 - sensitivity: 0.9604 - specificity: 0.8711 - acc: 0.8863Epoch 00031: val_loss improved from 0.26143 to 0.26073, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2856 - sensitivity: 0.9595 - specificity: 0.8720 - acc: 0.8869 - val_loss: 0.2607 - val_sensitivity: 0.8446 - val_specificity: 0.8840 - val_acc: 0.8847
# Epoch 32/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2788 - sensitivity: 0.9620 - specificity: 0.8777 - acc: 0.8910Epoch 00032: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2774 - sensitivity: 0.9611 - specificity: 0.8784 - acc: 0.8915 - val_loss: 0.2724 - val_sensitivity: 0.8818 - val_specificity: 0.8756 - val_acc: 0.8794
# Epoch 33/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2863 - sensitivity: 0.9491 - specificity: 0.8662 - acc: 0.8807Epoch 00033: val_loss improved from 0.26073 to 0.25411, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 897ms/step - loss: 0.2848 - sensitivity: 0.9500 - specificity: 0.8672 - acc: 0.8817 - val_loss: 0.2541 - val_sensitivity: 0.8068 - val_specificity: 0.8954 - val_acc: 0.8917
# Epoch 34/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2938 - sensitivity: 0.9527 - specificity: 0.8685 - acc: 0.8821Epoch 00034: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2942 - sensitivity: 0.9535 - specificity: 0.8673 - acc: 0.8813 - val_loss: 0.2889 - val_sensitivity: 0.8624 - val_specificity: 0.8705 - val_acc: 0.8736
# Epoch 35/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2721 - sensitivity: 0.9511 - specificity: 0.8742 - acc: 0.8860Epoch 00035: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2705 - sensitivity: 0.9520 - specificity: 0.8743 - acc: 0.8863 - val_loss: 0.2614 - val_sensitivity: 0.8349 - val_specificity: 0.8834 - val_acc: 0.8835
# Epoch 36/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2848 - sensitivity: 0.9528 - specificity: 0.8729 - acc: 0.8860Epoch 00036: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2857 - sensitivity: 0.9536 - specificity: 0.8718 - acc: 0.8852 - val_loss: 0.2624 - val_sensitivity: 0.8868 - val_specificity: 0.8698 - val_acc: 0.8742
# Epoch 37/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2657 - sensitivity: 0.9436 - specificity: 0.8827 - acc: 0.8932Epoch 00037: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2678 - sensitivity: 0.9446 - specificity: 0.8818 - acc: 0.8926 - val_loss: 0.2938 - val_sensitivity: 0.8940 - val_specificity: 0.8634 - val_acc: 0.8695
# Epoch 38/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2723 - sensitivity: 0.9556 - specificity: 0.8807 - acc: 0.8935Epoch 00038: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2706 - sensitivity: 0.9564 - specificity: 0.8811 - acc: 0.8940 - val_loss: 0.2898 - val_sensitivity: 0.8965 - val_specificity: 0.8685 - val_acc: 0.8742
# Epoch 39/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2659 - sensitivity: 0.9499 - specificity: 0.8787 - acc: 0.8895Epoch 00039: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2659 - sensitivity: 0.9508 - specificity: 0.8786 - acc: 0.8897 - val_loss: 0.2571 - val_sensitivity: 0.8084 - val_specificity: 0.8974 - val_acc: 0.8934
# Epoch 40/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2715 - sensitivity: 0.9455 - specificity: 0.8756 - acc: 0.8877Epoch 00040: val_loss improved from 0.25411 to 0.25176, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2722 - sensitivity: 0.9464 - specificity: 0.8742 - acc: 0.8866 - val_loss: 0.2518 - val_sensitivity: 0.8009 - val_specificity: 0.9068 - val_acc: 0.9022
# Epoch 41/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2520 - sensitivity: 0.9601 - specificity: 0.8940 - acc: 0.9046Epoch 00041: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2517 - sensitivity: 0.9608 - specificity: 0.8930 - acc: 0.9038 - val_loss: 0.3157 - val_sensitivity: 0.8760 - val_specificity: 0.8691 - val_acc: 0.8730
# Epoch 42/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2619 - sensitivity: 0.9489 - specificity: 0.8774 - acc: 0.8920Epoch 00042: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2640 - sensitivity: 0.9485 - specificity: 0.8764 - acc: 0.8911 - val_loss: 0.2566 - val_sensitivity: 0.7841 - val_specificity: 0.9309 - val_acc: 0.9214
# Epoch 43/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2491 - sensitivity: 0.9582 - specificity: 0.8834 - acc: 0.8949Epoch 00043: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.2512 - sensitivity: 0.9551 - specificity: 0.8829 - acc: 0.8940 - val_loss: 0.2769 - val_sensitivity: 0.7001 - val_specificity: 0.9400 - val_acc: 0.9249
# Epoch 44/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2367 - sensitivity: 0.9614 - specificity: 0.8989 - acc: 0.9104Epoch 00044: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2362 - sensitivity: 0.9621 - specificity: 0.8994 - acc: 0.9109 - val_loss: 0.2578 - val_sensitivity: 0.8128 - val_specificity: 0.9125 - val_acc: 0.9074
# Epoch 45/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2408 - sensitivity: 0.9596 - specificity: 0.8923 - acc: 0.9036Epoch 00045: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2400 - sensitivity: 0.9603 - specificity: 0.8926 - acc: 0.9038 - val_loss: 0.2625 - val_sensitivity: 0.8359 - val_specificity: 0.9112 - val_acc: 0.9068
# Epoch 46/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2309 - sensitivity: 0.9697 - specificity: 0.9004 - acc: 0.9124Epoch 00046: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2295 - sensitivity: 0.9703 - specificity: 0.9002 - acc: 0.9122 - val_loss: 0.2722 - val_sensitivity: 0.8692 - val_specificity: 0.8896 - val_acc: 0.8899
# Epoch 47/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2352 - sensitivity: 0.9647 - specificity: 0.8984 - acc: 0.9096Epoch 00047: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2356 - sensitivity: 0.9653 - specificity: 0.8971 - acc: 0.9087 - val_loss: 0.2692 - val_sensitivity: 0.8777 - val_specificity: 0.8917 - val_acc: 0.8923
# Epoch 48/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2356 - sensitivity: 0.9366 - specificity: 0.8926 - acc: 0.9032Epoch 00048: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2359 - sensitivity: 0.9379 - specificity: 0.8913 - acc: 0.9024 - val_loss: 0.2784 - val_sensitivity: 0.8806 - val_specificity: 0.8922 - val_acc: 0.8928
# Epoch 49/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2357 - sensitivity: 0.9575 - specificity: 0.8959 - acc: 0.9063Epoch 00049: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2358 - sensitivity: 0.9566 - specificity: 0.8968 - acc: 0.9069 - val_loss: 0.2774 - val_sensitivity: 0.6932 - val_specificity: 0.9397 - val_acc: 0.9249
# Epoch 50/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2360 - sensitivity: 0.9687 - specificity: 0.8998 - acc: 0.9099Epoch 00050: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2375 - sensitivity: 0.9693 - specificity: 0.8986 - acc: 0.9090 - val_loss: 0.2683 - val_sensitivity: 0.8235 - val_specificity: 0.9073 - val_acc: 0.9039
# Epoch 51/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2544 - sensitivity: 0.9554 - specificity: 0.8959 - acc: 0.9036Epoch 00051: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2525 - sensitivity: 0.9561 - specificity: 0.8960 - acc: 0.9038 - val_loss: 0.2683 - val_sensitivity: 0.8028 - val_specificity: 0.9131 - val_acc: 0.9068
# Epoch 52/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2332 - sensitivity: 0.9760 - specificity: 0.9009 - acc: 0.9146Epoch 00052: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2321 - sensitivity: 0.9764 - specificity: 0.9009 - acc: 0.9147 - val_loss: 0.2605 - val_sensitivity: 0.8441 - val_specificity: 0.9008 - val_acc: 0.8998
# Epoch 53/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2309 - sensitivity: 0.9583 - specificity: 0.8991 - acc: 0.9079Epoch 00053: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2308 - sensitivity: 0.9590 - specificity: 0.8995 - acc: 0.9084 - val_loss: 0.2610 - val_sensitivity: 0.7877 - val_specificity: 0.9236 - val_acc: 0.9156
# Epoch 54/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2120 - sensitivity: 0.9787 - specificity: 0.9052 - acc: 0.9175Epoch 00054: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2109 - sensitivity: 0.9791 - specificity: 0.9051 - acc: 0.9175 - val_loss: 0.2770 - val_sensitivity: 0.8070 - val_specificity: 0.9311 - val_acc: 0.9220
# Epoch 55/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2102 - sensitivity: 0.9618 - specificity: 0.9046 - acc: 0.9142Epoch 00055: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2084 - sensitivity: 0.9624 - specificity: 0.9054 - acc: 0.9150 - val_loss: 0.2679 - val_sensitivity: 0.8074 - val_specificity: 0.9287 - val_acc: 0.9196
# Epoch 56/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2275 - sensitivity: 0.9564 - specificity: 0.9074 - acc: 0.9136Epoch 00056: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2264 - sensitivity: 0.9572 - specificity: 0.9070 - acc: 0.9133 - val_loss: 0.2540 - val_sensitivity: 0.7821 - val_specificity: 0.9303 - val_acc: 0.9202
# Epoch 57/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2250 - sensitivity: 0.9549 - specificity: 0.9090 - acc: 0.9150Epoch 00057: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2238 - sensitivity: 0.9557 - specificity: 0.9090 - acc: 0.9150 - val_loss: 0.2607 - val_sensitivity: 0.8742 - val_specificity: 0.9001 - val_acc: 0.9004
# Epoch 58/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2093 - sensitivity: 0.9786 - specificity: 0.9018 - acc: 0.9143Epoch 00058: val_loss did not improve
# 57/57 [==============================] - 49s 868ms/step - loss: 0.2060 - sensitivity: 0.9790 - specificity: 0.9035 - acc: 0.9158 - val_loss: 0.2605 - val_sensitivity: 0.5467 - val_specificity: 0.9411 - val_acc: 0.9272
# Epoch 59/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2063 - sensitivity: 0.9707 - specificity: 0.9166 - acc: 0.9257Epoch 00059: val_loss did not improve
# 57/57 [==============================] - 50s 871ms/step - loss: 0.2079 - sensitivity: 0.9693 - specificity: 0.9155 - acc: 0.9246 - val_loss: 0.2741 - val_sensitivity: 0.8645 - val_specificity: 0.9083 - val_acc: 0.9074
# Epoch 60/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1994 - sensitivity: 0.9741 - specificity: 0.9150 - acc: 0.9239Epoch 00060: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1983 - sensitivity: 0.9746 - specificity: 0.9161 - acc: 0.9249 - val_loss: 0.2679 - val_sensitivity: 0.8487 - val_specificity: 0.9071 - val_acc: 0.9045
# Epoch 61/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2140 - sensitivity: 0.9630 - specificity: 0.9105 - acc: 0.9178Epoch 00061: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2137 - sensitivity: 0.9624 - specificity: 0.9111 - acc: 0.9182 - val_loss: 0.2648 - val_sensitivity: 0.7501 - val_specificity: 0.9497 - val_acc: 0.9348
# Epoch 62/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2211 - sensitivity: 0.9677 - specificity: 0.9139 - acc: 0.9225Epoch 00062: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2224 - sensitivity: 0.9661 - specificity: 0.9133 - acc: 0.9217 - val_loss: 0.2753 - val_sensitivity: 0.7981 - val_specificity: 0.9234 - val_acc: 0.9150
# Epoch 63/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2002 - sensitivity: 0.9788 - specificity: 0.9168 - acc: 0.9261Epoch 00063: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2008 - sensitivity: 0.9770 - specificity: 0.9165 - acc: 0.9256 - val_loss: 0.2756 - val_sensitivity: 0.7996 - val_specificity: 0.9146 - val_acc: 0.9068
# Epoch 64/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2097 - sensitivity: 0.9682 - specificity: 0.9063 - acc: 0.9163Epoch 00064: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2089 - sensitivity: 0.9688 - specificity: 0.9050 - acc: 0.9154 - val_loss: 0.2777 - val_sensitivity: 0.6902 - val_specificity: 0.9501 - val_acc: 0.9330
# Epoch 65/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1953 - sensitivity: 0.9639 - specificity: 0.9218 - acc: 0.9285Epoch 00065: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1971 - sensitivity: 0.9645 - specificity: 0.9207 - acc: 0.9277 - val_loss: 0.2748 - val_sensitivity: 0.7380 - val_specificity: 0.9392 - val_acc: 0.9255
# Epoch 66/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1887 - sensitivity: 0.9663 - specificity: 0.9182 - acc: 0.9252Epoch 00066: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1866 - sensitivity: 0.9668 - specificity: 0.9192 - acc: 0.9262 - val_loss: 0.3023 - val_sensitivity: 0.7778 - val_specificity: 0.9286 - val_acc: 0.9196
# Epoch 67/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2082 - sensitivity: 0.9647 - specificity: 0.9132 - acc: 0.9200Epoch 00067: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2075 - sensitivity: 0.9653 - specificity: 0.9139 - acc: 0.9207 - val_loss: 0.3031 - val_sensitivity: 0.6726 - val_specificity: 0.9544 - val_acc: 0.9359
# Epoch 68/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1997 - sensitivity: 0.9759 - specificity: 0.9188 - acc: 0.9286Epoch 00068: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1984 - sensitivity: 0.9763 - specificity: 0.9186 - acc: 0.9284 - val_loss: 0.2689 - val_sensitivity: 0.7819 - val_specificity: 0.9416 - val_acc: 0.9307
# Epoch 69/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1787 - sensitivity: 0.9802 - specificity: 0.9305 - acc: 0.9385Epoch 00069: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1796 - sensitivity: 0.9806 - specificity: 0.9293 - acc: 0.9375 - val_loss: 0.2718 - val_sensitivity: 0.6729 - val_specificity: 0.9591 - val_acc: 0.9388
# Epoch 70/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1889 - sensitivity: 0.9749 - specificity: 0.9252 - acc: 0.9335Epoch 00070: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1891 - sensitivity: 0.9735 - specificity: 0.9257 - acc: 0.9336 - val_loss: 0.2797 - val_sensitivity: 0.7907 - val_specificity: 0.9419 - val_acc: 0.9301
# Epoch 71/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1712 - sensitivity: 0.9769 - specificity: 0.9264 - acc: 0.9336Epoch 00071: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1715 - sensitivity: 0.9773 - specificity: 0.9259 - acc: 0.9333 - val_loss: 0.3536 - val_sensitivity: 0.7977 - val_specificity: 0.9129 - val_acc: 0.9068
# Epoch 72/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1796 - sensitivity: 0.9731 - specificity: 0.9275 - acc: 0.9346Epoch 00072: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1812 - sensitivity: 0.9736 - specificity: 0.9267 - acc: 0.9340 - val_loss: 0.2650 - val_sensitivity: 0.7997 - val_specificity: 0.9299 - val_acc: 0.9220
# Epoch 73/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1862 - sensitivity: 0.9645 - specificity: 0.9242 - acc: 0.9300Epoch 00073: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1889 - sensitivity: 0.9652 - specificity: 0.9223 - acc: 0.9284 - val_loss: 0.2890 - val_sensitivity: 0.7948 - val_specificity: 0.9307 - val_acc: 0.9202
# Epoch 74/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1761 - sensitivity: 0.9753 - specificity: 0.9307 - acc: 0.9378Epoch 00074: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1768 - sensitivity: 0.9741 - specificity: 0.9310 - acc: 0.9378 - val_loss: 0.3143 - val_sensitivity: 0.7913 - val_specificity: 0.9322 - val_acc: 0.9220
# Epoch 75/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1577 - sensitivity: 0.9800 - specificity: 0.9332 - acc: 0.9404

# %% [raw]
# model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid) #gen_flow_val,  #(X_valid, Y_valid),
#                     steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
#                     #validation_steps=int(np.ceil(len(X_valid)/batch_size)),
#                     epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
#                     class_weight = class_weight)
#                     #class_weights = class_weight

# %% [markdown]
# ## IV. Visualize  TSNE

# %%
# %matplotlib inline
import numpy as np
# visualize the points' distribution of train data using features built from base_model
import matplotlib.pyplot as plt
# dimension reduction
from sklearn.manifold import TSNE 
import numpy as np

def t_sne_vis(name, base_model, x_processed_images, random_state, labels,perplexity = 30):
    """
    :param name: the name of the cnn model used to build features
    :param base_model: the model obj
    :param x_processed_images: the input images for our model
    :param random_state: for fixing the results
    :param labels: 0/1 classification labels
    :return:
    the graph of image distribution based on features extracted from the model and the t-sne features
    """
    # convert data to images
    print('Converting data points to composite image')
    X_train = x_processed_images
    print('we got %d different images of shape %dx%d ' % (len(X_train), X_train.shape[1], X_train.shape[1]))
    print('build usefull features from the selected model')
    features = base_model.predict(X_train)
    x_data1 = np.asarray(features).astype('float64')
    x_data1 = x_data1.reshape((x_data1.shape[0], -1))
    # perform t-SNE embedding
    print('performing t-sne reduction')
    vis_data = TSNE(perplexity=perplexity, random_state=random_state).fit_transform(x_data1)
    # plot the result
    fig = plt.figure(figsize=(15, 15))
    vis_x = vis_data[:, 0]
    vis_y = vis_data[:, 1]
    plt.scatter(vis_x, vis_y, c=labels, cmap=plt.cm.get_cmap("winter", 2))
    plt.colorbar(ticks=range(2))
    plt.clim(0, 1)
    plt.title(name)
    plt.grid()
    plt.show()
    fig.savefig('tsne_vis_'+name+'.png')
    return vis_data

# %%
model.summary()

# %%
name = 'Resnet'
print('visualizing for %s' %name)
base_model_ = Model(input=model.input, output=model.get_layer('avg_pool').output)
tsne_feats = t_sne_vis(name, base_model_, X_valid, np.random.RandomState(42), Y_valid,perplexity=30)

# %% [markdown]
# ## V. Evaluate Model

# %%
model = load_model(weights_path+"BestKerasResnet50_flat_3_loss.h5", custom_objects={'sensitivity': sensitivity,
                                                                             "specificity":specificity,
                                                                              "loss":loss1})
score = model.evaluate(X_valid, Y_valid, verbose=1)
print('Test loss:', score[0])
print('Test sensitivity:', score[1])
print('Test specificity:', score[2])
print('Test acc:', score[3])

# %%
#compute metrics
pred = model.predict(X_valid)
average_precision = average_precision_score(Y_valid, pred)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))

# %%
precision, recall, _ = precision_recall_curve(Y_valid, pred)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))

# %%
def generate_results(y_test, y_score):
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.show()
    print('AUC: %f' % roc_auc)

# %%
generate_results

# %% [markdown]
# #compute log loss
# pred = model.predict(X_valid)
# log_loss(Y_valid,pred)

# %% [markdown]
# ## VI. Retrain on full dataset

# %% [raw]
# #Generate the training data
# #Create 3 bands having HH, HV and avg of both
# X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
# X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
# X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],
#                           ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)

# %% [raw]
# #parse corrupted notebook file
# t = ["#Generate the training data\n",
#     "#Create 3 bands having HH, HV and avg of both\n",
#     "X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_1\"]])\n",
#     "X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_2\"]])\n",
#     "X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],\n",
#     "                          ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)"]
# #t.remove("\n")
# t=[x.replace("\n",'') for x in t]
# for x in t:
#     print(x)
