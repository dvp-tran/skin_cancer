# %% [markdown]
# # Skin Cancer Classification Challenge

# %% [markdown]
# **Summary : ** skin cancer.

# %% [markdown]
# ## Preliminaries and Imports

# %%
#general & system\n",
import os

#data processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 10, 10  #default setting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#data augmentation
from PIL import Image
from random import choice
import cv2
import numpy as np
#import keras.preprocessing.image as prep

#ML part
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing import image as kimage
from keras.models import Sequential
from keras.layers import GlobalMaxPooling2D, Dense, BatchNormalization, GlobalAveragePooling2D,Dropout,Activation,Flatten
from keras.models import Model
from keras.optimizers import SGD
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

#validation
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score


from sklearn.metrics import precision_recall_curve
from imblearn.over_sampling import SMOTE
from sklearn.utils import resample

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## I. Load Data

# %% [markdown]
# - **Rq : ** Datasets are quite light, can be fully loaded in a laptop memory with ease.

# %%
# %%time
meta = pd.read_csv("../data/label_learn.csv", sep = ";")
# Out:
# CPU times: user 4 ms, sys: 4 ms, total: 8 ms
# Wall time: 5.49 ms

# %%
meta.head()
# Out:
#           name      label
# 0  0000000.jpg     benign
# 1  0000002.jpg  malignant
# 2  0000006.jpg     benign
# 3  0000008.jpg     benign
# 4  0000009.jpg     benign

# %%
# %%time
train_list = os.listdir("../data/resized_train/")
len(train_list) == len(meta.name)
# Out:
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 4.05 ms

# %%
train_list.sort() == list(meta.name).sort()
# Out:
# True

# %%
# %%time
X_train = np.array([np.array(Image.open("../data/resized_train/"+fname)) for fname in meta.name])
Y_train = [1 if x=="malignant" else 0 for x in meta.label]
Y_train = np.array(Y_train)
# Out:
# CPU times: user 23 s, sys: 1.62 s, total: 24.6 s
# Wall time: 24.6 s

# %%
print(X_train.shape)
print(len(Y_train))
X_train.shape[0] == len(meta.name) == len(Y_train)
# Out:
# (8581, 299, 299, 3)
# 8581
# True

# %%
#control
print(meta.name[0:5])
print(Y_train[0:5])
print(meta.label[0:5])
# Out:
# 0    0000000.jpg
# 1    0000002.jpg
# 2    0000006.jpg
# 3    0000008.jpg
# 4    0000009.jpg
# Name: name, dtype: object
# [0 1 0 0 0]
# 0       benign
# 1    malignant
# 2       benign
# 3       benign
# 4       benign
# Name: label, dtype: object

# %% [markdown]
# ## II. Data Preparation

# %% [markdown]
# - **Class weights**

# %%
class_weight_or = class_weight.compute_class_weight('balanced', np.unique(Y_train), Y_train)

# %% [markdown]
# - **Data splitting**

# %%
#data splitting
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train, Y_train, random_state=42, train_size=0.80)
# Out:
# /home/dvp_tran/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# - **Resampling**

# %%
temp = sum(Y_train)
sample_size = temp*2700/(374+254)  #1372
sample_size
# Out:
# 2325

# %%
def random_undersampling(X, Y,sample_size = sample_size, n_sample=1):
    """
    X,y : numpy arrays
    return :
    5 random ensemble of indices general_balenced_set:
        general_balenced_set[0] = the shuffeled indices that inssure the class balance
    """
    indices = np.array(range(len(Y)))
    positive_samples = indices[Y==1]
    #print(type(positive_samples))
    negative_samples = indices[Y==0]
    #print(type(negative_samples))
    general_balenced_set = []
    for k in range(n_sample):
        indices_ = np.random.choice(negative_samples, sample_size, replace=False)
        #print(len(indices_))
        # append positive and negative
        balenced_set = np.append(indices_, positive_samples)
        #print(len(balenced_set))
        # shuffle indices
        np.random.shuffle(balenced_set)
        #print(len(balenced_set))
        general_balenced_set.append(balenced_set)
    return general_balenced_set

# %%
general_balenced_set = random_undersampling(X_train,Y_train)
X_train = X_train[general_balenced_set]
Y_train = Y_train[general_balenced_set]

# %% [markdown]
# ## III. Deep Learning with Transfer Learning

# %%
weights_path = '../model/checkpoints/'

if not os.path.exists(weights_path):
    os.makedirs(weights_path)
    
epochs = 500
batch_size = 50

# %% [markdown]
# - **Using RESNET : **

# %%
#load base model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(299,299,3))
base_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
#adding top layers
    #sequentialy
add_model = Sequential()
add_model.add(GlobalAveragePooling2D(input_shape=base_model.output_shape[1:])) #Flatten/GlobalAveragePooling2D
add_model.add(Dense(1024, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(512, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(1, activation='sigmoid'))

model = Model(inputs=base_model.input, outputs=add_model(base_model.output))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1)            2623489     avg_pool[0][0]
# ==================================================================================================
# Total params: 26,211,201
# Trainable params: 26,158,081
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [raw]
# #adding top layers
#     #need to check api to add layers sequentialy
# x = base_model.output
# x = GlobalAveragePooling2D()(x) #Flatten instead?
# x = Dense(1024, activation='relu')(x)
# x = Dropout(0.25)(x)
# x = Dense(512, activation='relu')(x)
# x = Dropout(0.25)(x)
# predictions = Dense(1, activation='sigmoid')(x)
#
# model = Model(inputs=base_model.input, outputs=predictions)
# model.summary()

# %%
from keras import backend as K

def weighted_categorical_crossentropy(weights):
    """
    [w_0, w_1] : weight of 0 class and weight of 1 class
    """
    weights = K.variable(weights)

    def loss(y_true, y_pred):
        # scale predictions so that the class probas of each sample sum to 1
        #y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
        # clip to prevent NaN's and Inf's
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        # calc
        loss = y_true * K.log(y_pred) * weights[1] + (1 - y_true) * K.log(1 - y_pred) * weights[0]
        loss = -K.sum(loss, -1)
        return loss

    return loss

# %%
class_weight_or
# Out:
# array([ 0.54296381,  6.31885125])

# %%
loss1 = weighted_categorical_crossentropy(class_weight_or) #(np.array([0.8,4]))

# %%
#freeze lower layers of the model
#for layer in model.layers[:]:
    #layer.trainable = False
for layer in model.layers[0:]:
    layer.trainable = True
    

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())




#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss="binary_crossentropy", #binary_crossentropy
              metrics=[sensitivity, specificity,"accuracy"])

# %%
# %%time
#Lets define the image transormations that we wan

gen = ImageDataGenerator(horizontal_flip=True,
                         vertical_flip=True,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         zoom_range=0.2,
                         rotation_range=40)

val_datagen = ImageDataGenerator()
# Here is the function that merges our two generators
# We use the exact same generator with the same random seed for both the y and angle arrays
def gen_flow_for_one_input(X1, y):
    genX1 = gen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]

def val_datagen_(X1, y):
    genX1 = val_datagen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]
#Finally create out generator
gen_flow_train = gen_flow_for_one_input(X_train, Y_train)
#gen_flow_val = gen_flow_for_one_input(X_valid, Y_valid)
gen_flow_val = val_datagen_(X_valid, Y_valid)

from keras.callbacks import EarlyStopping, ModelCheckpoint
epochs_to_wait_for_improve = 30
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=epochs_to_wait_for_improve)
checkpoint_callback = ModelCheckpoint(weights_path + 'BestKerasResnet50_flat_3_loss_no_weight.h5', monitor='val_loss',
                                      verbose=1, save_best_only=True, mode='min')
#fit the model
model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid),
                    steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
                    epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
                    class_weight = class_weight_or)
# Out:
# Epoch 1/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.5397 - sensitivity: 0.1485 - specificity: 0.8855 - acc: 0.7457Epoch 00001: val_loss improved from inf to 0.42712, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 75s 1s/step - loss: 0.5369 - sensitivity: 0.1459 - specificity: 0.8876 - acc: 0.7477 - val_loss: 0.4271 - val_sensitivity: 0.0000e+00 - val_specificity: 0.9955 - val_acc: 0.9156
# Epoch 2/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.4059 - sensitivity: 0.1200 - specificity: 0.9864 - acc: 0.8194Epoch 00002: val_loss improved from 0.42712 to 0.32137, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.4069 - sensitivity: 0.1220 - specificity: 0.9862 - acc: 0.8188 - val_loss: 0.3214 - val_sensitivity: 0.0326 - val_specificity: 0.9962 - val_acc: 0.9190
# Epoch 3/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3476 - sensitivity: 0.2629 - specificity: 0.9780 - acc: 0.8417Epoch 00003: val_loss improved from 0.32137 to 0.26200, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.3463 - sensitivity: 0.2701 - specificity: 0.9780 - acc: 0.8434 - val_loss: 0.2620 - val_sensitivity: 0.1921 - val_specificity: 0.9879 - val_acc: 0.9237
# Epoch 4/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3012 - sensitivity: 0.4118 - specificity: 0.9710 - acc: 0.8639Epoch 00004: val_loss improved from 0.26200 to 0.22235, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.3020 - sensitivity: 0.4113 - specificity: 0.9715 - acc: 0.8634 - val_loss: 0.2223 - val_sensitivity: 0.2624 - val_specificity: 0.9809 - val_acc: 0.9243
# Epoch 5/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2906 - sensitivity: 0.4879 - specificity: 0.9566 - acc: 0.8642Epoch 00005: val_loss improved from 0.22235 to 0.20671, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 903ms/step - loss: 0.2905 - sensitivity: 0.4869 - specificity: 0.9566 - acc: 0.8644 - val_loss: 0.2067 - val_sensitivity: 0.4141 - val_specificity: 0.9706 - val_acc: 0.9272
# Epoch 6/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2688 - sensitivity: 0.5132 - specificity: 0.9548 - acc: 0.8707Epoch 00006: val_loss improved from 0.20671 to 0.19350, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2675 - sensitivity: 0.5216 - specificity: 0.9544 - acc: 0.8719 - val_loss: 0.1935 - val_sensitivity: 0.4741 - val_specificity: 0.9604 - val_acc: 0.9220
# Epoch 7/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2712 - sensitivity: 0.5926 - specificity: 0.9481 - acc: 0.8759Epoch 00007: val_loss improved from 0.19350 to 0.19071, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.2701 - sensitivity: 0.5932 - specificity: 0.9482 - acc: 0.8764 - val_loss: 0.1907 - val_sensitivity: 0.5083 - val_specificity: 0.9529 - val_acc: 0.9185
# Epoch 8/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2616 - sensitivity: 0.6151 - specificity: 0.9489 - acc: 0.8791Epoch 00008: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2615 - sensitivity: 0.6175 - specificity: 0.9493 - acc: 0.8799 - val_loss: 0.1963 - val_sensitivity: 0.4867 - val_specificity: 0.9573 - val_acc: 0.9220
# Epoch 9/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2451 - sensitivity: 0.6504 - specificity: 0.9426 - acc: 0.8864Epoch 00009: val_loss improved from 0.19071 to 0.18509, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2475 - sensitivity: 0.6459 - specificity: 0.9431 - acc: 0.8849 - val_loss: 0.1851 - val_sensitivity: 0.5027 - val_specificity: 0.9591 - val_acc: 0.9249
# Epoch 10/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2472 - sensitivity: 0.6656 - specificity: 0.9403 - acc: 0.8841Epoch 00010: val_loss improved from 0.18509 to 0.17922, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 902ms/step - loss: 0.2467 - sensitivity: 0.6646 - specificity: 0.9401 - acc: 0.8837 - val_loss: 0.1792 - val_sensitivity: 0.5105 - val_specificity: 0.9598 - val_acc: 0.9266
# Epoch 11/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2419 - sensitivity: 0.6797 - specificity: 0.9407 - acc: 0.8870Epoch 00011: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2427 - sensitivity: 0.6765 - specificity: 0.9408 - acc: 0.8862 - val_loss: 0.1800 - val_sensitivity: 0.4812 - val_specificity: 0.9664 - val_acc: 0.9295
# Epoch 12/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2262 - sensitivity: 0.7277 - specificity: 0.9395 - acc: 0.8932Epoch 00012: val_loss improved from 0.17922 to 0.16582, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.2243 - sensitivity: 0.7292 - specificity: 0.9406 - acc: 0.8944 - val_loss: 0.1658 - val_sensitivity: 0.5692 - val_specificity: 0.9541 - val_acc: 0.9249
# Epoch 13/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2286 - sensitivity: 0.6653 - specificity: 0.9458 - acc: 0.8918Epoch 00013: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2280 - sensitivity: 0.6698 - specificity: 0.9463 - acc: 0.8930 - val_loss: 0.1684 - val_sensitivity: 0.6108 - val_specificity: 0.9430 - val_acc: 0.9196
# Epoch 14/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2155 - sensitivity: 0.7476 - specificity: 0.9467 - acc: 0.9067Epoch 00014: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2163 - sensitivity: 0.7472 - specificity: 0.9467 - acc: 0.9066 - val_loss: 0.1693 - val_sensitivity: 0.6278 - val_specificity: 0.9386 - val_acc: 0.9167
# Epoch 15/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2260 - sensitivity: 0.7004 - specificity: 0.9409 - acc: 0.8911Epoch 00015: val_loss improved from 0.16582 to 0.16308, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2272 - sensitivity: 0.7002 - specificity: 0.9415 - acc: 0.8912 - val_loss: 0.1631 - val_sensitivity: 0.6149 - val_specificity: 0.9483 - val_acc: 0.9237
# Epoch 16/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2123 - sensitivity: 0.7277 - specificity: 0.9467 - acc: 0.9011Epoch 00016: val_loss improved from 0.16308 to 0.15831, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.2115 - sensitivity: 0.7304 - specificity: 0.9468 - acc: 0.9017 - val_loss: 0.1583 - val_sensitivity: 0.6052 - val_specificity: 0.9592 - val_acc: 0.9330
# Epoch 17/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2149 - sensitivity: 0.7260 - specificity: 0.9412 - acc: 0.8981Epoch 00017: val_loss improved from 0.15831 to 0.15576, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2155 - sensitivity: 0.7264 - specificity: 0.9410 - acc: 0.8982 - val_loss: 0.1558 - val_sensitivity: 0.5966 - val_specificity: 0.9599 - val_acc: 0.9324
# Epoch 18/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2124 - sensitivity: 0.7510 - specificity: 0.9431 - acc: 0.9002Epoch 00018: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2118 - sensitivity: 0.7503 - specificity: 0.9429 - acc: 0.9002 - val_loss: 0.1560 - val_sensitivity: 0.5981 - val_specificity: 0.9568 - val_acc: 0.9301
# Epoch 19/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2038 - sensitivity: 0.7503 - specificity: 0.9481 - acc: 0.9060Epoch 00019: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2043 - sensitivity: 0.7494 - specificity: 0.9477 - acc: 0.9055 - val_loss: 0.1566 - val_sensitivity: 0.6171 - val_specificity: 0.9536 - val_acc: 0.9289
# Epoch 20/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2079 - sensitivity: 0.7466 - specificity: 0.9467 - acc: 0.9068Epoch 00020: val_loss improved from 0.15576 to 0.15555, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.2073 - sensitivity: 0.7484 - specificity: 0.9460 - acc: 0.9066 - val_loss: 0.1555 - val_sensitivity: 0.6436 - val_specificity: 0.9501 - val_acc: 0.9289
# Epoch 21/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2094 - sensitivity: 0.7665 - specificity: 0.9449 - acc: 0.9071Epoch 00021: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2106 - sensitivity: 0.7609 - specificity: 0.9445 - acc: 0.9059 - val_loss: 0.1589 - val_sensitivity: 0.6373 - val_specificity: 0.9439 - val_acc: 0.9231
# Epoch 22/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2058 - sensitivity: 0.7477 - specificity: 0.9499 - acc: 0.9071Epoch 00022: val_loss improved from 0.15555 to 0.15323, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2043 - sensitivity: 0.7486 - specificity: 0.9500 - acc: 0.9076 - val_loss: 0.1532 - val_sensitivity: 0.5937 - val_specificity: 0.9534 - val_acc: 0.9272
# Epoch 23/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2017 - sensitivity: 0.7428 - specificity: 0.9446 - acc: 0.9035Epoch 00023: val_loss improved from 0.15323 to 0.15037, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2010 - sensitivity: 0.7424 - specificity: 0.9439 - acc: 0.9031 - val_loss: 0.1504 - val_sensitivity: 0.6155 - val_specificity: 0.9555 - val_acc: 0.9307
# Epoch 24/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2135 - sensitivity: 0.7404 - specificity: 0.9469 - acc: 0.9031Epoch 00024: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2124 - sensitivity: 0.7406 - specificity: 0.9466 - acc: 0.9030 - val_loss: 0.1506 - val_sensitivity: 0.6214 - val_specificity: 0.9535 - val_acc: 0.9295
# Epoch 25/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1959 - sensitivity: 0.7839 - specificity: 0.9532 - acc: 0.9167Epoch 00025: val_loss improved from 0.15037 to 0.14506, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.1979 - sensitivity: 0.7848 - specificity: 0.9520 - acc: 0.9161 - val_loss: 0.1451 - val_sensitivity: 0.5820 - val_specificity: 0.9626 - val_acc: 0.9342
# Epoch 26/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2033 - sensitivity: 0.7327 - specificity: 0.9453 - acc: 0.9010Epoch 00026: val_loss improved from 0.14506 to 0.14157, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2027 - sensitivity: 0.7352 - specificity: 0.9454 - acc: 0.9017 - val_loss: 0.1416 - val_sensitivity: 0.5722 - val_specificity: 0.9657 - val_acc: 0.9359
# Epoch 27/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1980 - sensitivity: 0.7274 - specificity: 0.9460 - acc: 0.9014Epoch 00027: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.1988 - sensitivity: 0.7263 - specificity: 0.9469 - acc: 0.9014 - val_loss: 0.1562 - val_sensitivity: 0.6611 - val_specificity: 0.9417 - val_acc: 0.9231
# Epoch 28/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2074 - sensitivity: 0.7496 - specificity: 0.9371 - acc: 0.8998Epoch 00028: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2055 - sensitivity: 0.7540 - specificity: 0.9371 - acc: 0.9006 - val_loss: 0.1428 - val_sensitivity: 0.6087 - val_specificity: 0.9585 - val_acc: 0.9336
# Epoch 29/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1873 - sensitivity: 0.7756 - specificity: 0.9521 - acc: 0.9153Epoch 00029: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1879 - sensitivity: 0.7768 - specificity: 0.9515 - acc: 0.9150 - val_loss: 0.1438 - val_sensitivity: 0.6109 - val_specificity: 0.9592 - val_acc: 0.9342
# Epoch 30/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1839 - sensitivity: 0.7846 - specificity: 0.9534 - acc: 0.9192Epoch 00030: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1838 - sensitivity: 0.7834 - specificity: 0.9542 - acc: 0.9192 - val_loss: 0.1464 - val_sensitivity: 0.6463 - val_specificity: 0.9529 - val_acc: 0.9313
# Epoch 31/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1969 - sensitivity: 0.7617 - specificity: 0.9511 - acc: 0.9102Epoch 00031: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1969 - sensitivity: 0.7593 - specificity: 0.9503 - acc: 0.9094 - val_loss: 0.1420 - val_sensitivity: 0.6167 - val_specificity: 0.9567 - val_acc: 0.9324
# Epoch 32/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1807 - sensitivity: 0.7869 - specificity: 0.9534 - acc: 0.9174Epoch 00032: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1822 - sensitivity: 0.7848 - specificity: 0.9529 - acc: 0.9164 - val_loss: 0.1480 - val_sensitivity: 0.6611 - val_specificity: 0.9503 - val_acc: 0.9313
# Epoch 33/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1969 - sensitivity: 0.7681 - specificity: 0.9469 - acc: 0.9096Epoch 00033: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1984 - sensitivity: 0.7657 - specificity: 0.9460 - acc: 0.9084 - val_loss: 0.1459 - val_sensitivity: 0.6167 - val_specificity: 0.9541 - val_acc: 0.9301
# Epoch 34/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1793 - sensitivity: 0.7727 - specificity: 0.9548 - acc: 0.9185Epoch 00034: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1805 - sensitivity: 0.7709 - specificity: 0.9543 - acc: 0.9175 - val_loss: 0.1581 - val_sensitivity: 0.7228 - val_specificity: 0.9376 - val_acc: 0.9231
# Epoch 35/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1942 - sensitivity: 0.7553 - specificity: 0.9486 - acc: 0.9096Epoch 00035: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1934 - sensitivity: 0.7563 - specificity: 0.9491 - acc: 0.9102 - val_loss: 0.1443 - val_sensitivity: 0.6158 - val_specificity: 0.9573 - val_acc: 0.9324
# Epoch 36/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1800 - sensitivity: 0.8142 - specificity: 0.9506 - acc: 0.9203Epoch 00036: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1789 - sensitivity: 0.8156 - specificity: 0.9510 - acc: 0.9210 - val_loss: 0.1531 - val_sensitivity: 0.6553 - val_specificity: 0.9453 - val_acc: 0.9260
# Epoch 37/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1886 - sensitivity: 0.7575 - specificity: 0.9455 - acc: 0.9074Epoch 00037: val_loss improved from 0.14157 to 0.14028, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1896 - sensitivity: 0.7535 - specificity: 0.9465 - acc: 0.9066 - val_loss: 0.1403 - val_sensitivity: 0.6061 - val_specificity: 0.9605 - val_acc: 0.9354
# Epoch 38/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1910 - sensitivity: 0.7620 - specificity: 0.9545 - acc: 0.9125Epoch 00038: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1907 - sensitivity: 0.7661 - specificity: 0.9545 - acc: 0.9133 - val_loss: 0.1406 - val_sensitivity: 0.6289 - val_specificity: 0.9579 - val_acc: 0.9342
# Epoch 39/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1778 - sensitivity: 0.7741 - specificity: 0.9511 - acc: 0.9153Epoch 00039: val_loss improved from 0.14028 to 0.13609, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.1781 - sensitivity: 0.7732 - specificity: 0.9506 - acc: 0.9147 - val_loss: 0.1361 - val_sensitivity: 0.5949 - val_specificity: 0.9676 - val_acc: 0.9394
# Epoch 40/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1910 - sensitivity: 0.7807 - specificity: 0.9406 - acc: 0.9059Epoch 00040: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1899 - sensitivity: 0.7802 - specificity: 0.9416 - acc: 0.9065 - val_loss: 0.1375 - val_sensitivity: 0.6240 - val_specificity: 0.9631 - val_acc: 0.9388
# Epoch 41/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1892 - sensitivity: 0.7743 - specificity: 0.9494 - acc: 0.9131Epoch 00041: val_loss did not improve
# 57/57 [==============================] - 49s 861ms/step - loss: 0.1898 - sensitivity: 0.7694 - specificity: 0.9499 - acc: 0.9126 - val_loss: 0.1365 - val_sensitivity: 0.6143 - val_specificity: 0.9637 - val_acc: 0.9388
# Epoch 42/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1781 - sensitivity: 0.7821 - specificity: 0.9481 - acc: 0.9149Epoch 00042: val_loss improved from 0.13609 to 0.13573, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.1779 - sensitivity: 0.7790 - specificity: 0.9490 - acc: 0.9157 - val_loss: 0.1357 - val_sensitivity: 0.6007 - val_specificity: 0.9637 - val_acc: 0.9371
# Epoch 43/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1754 - sensitivity: 0.7782 - specificity: 0.9543 - acc: 0.9178Epoch 00043: val_loss improved from 0.13573 to 0.13554, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.1742 - sensitivity: 0.7820 - specificity: 0.9543 - acc: 0.9185 - val_loss: 0.1355 - val_sensitivity: 0.6089 - val_specificity: 0.9656 - val_acc: 0.9394
# Epoch 44/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1869 - sensitivity: 0.7638 - specificity: 0.9495 - acc: 0.9105Epoch 00044: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1860 - sensitivity: 0.7666 - specificity: 0.9500 - acc: 0.9114 - val_loss: 0.1446 - val_sensitivity: 0.6808 - val_specificity: 0.9528 - val_acc: 0.9330
# Epoch 45/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1778 - sensitivity: 0.7936 - specificity: 0.9500 - acc: 0.9175Epoch 00045: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1772 - sensitivity: 0.7954 - specificity: 0.9500 - acc: 0.9178 - val_loss: 0.1412 - val_sensitivity: 0.6493 - val_specificity: 0.9546 - val_acc: 0.9330
# Epoch 46/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1812 - sensitivity: 0.7727 - specificity: 0.9534 - acc: 0.9136Epoch 00046: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1803 - sensitivity: 0.7745 - specificity: 0.9530 - acc: 0.9137 - val_loss: 0.1441 - val_sensitivity: 0.6704 - val_specificity: 0.9522 - val_acc: 0.9319
# Epoch 47/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1673 - sensitivity: 0.7791 - specificity: 0.9520 - acc: 0.9188Epoch 00047: val_loss improved from 0.13554 to 0.13368, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1656 - sensitivity: 0.7805 - specificity: 0.9528 - acc: 0.9199 - val_loss: 0.1337 - val_sensitivity: 0.5876 - val_specificity: 0.9656 - val_acc: 0.9377
# Epoch 48/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1813 - sensitivity: 0.7697 - specificity: 0.9533 - acc: 0.9145Epoch 00048: val_loss improved from 0.13368 to 0.13200, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.1802 - sensitivity: 0.7717 - specificity: 0.9537 - acc: 0.9153 - val_loss: 0.1320 - val_sensitivity: 0.5656 - val_specificity: 0.9746 - val_acc: 0.9435
# Epoch 49/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1705 - sensitivity: 0.7805 - specificity: 0.9604 - acc: 0.9254Epoch 00049: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1690 - sensitivity: 0.7845 - specificity: 0.9607 - acc: 0.9263 - val_loss: 0.1324 - val_sensitivity: 0.5729 - val_specificity: 0.9696 - val_acc: 0.9394
# Epoch 50/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1608 - sensitivity: 0.7953 - specificity: 0.9616 - acc: 0.9275Epoch 00050: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1630 - sensitivity: 0.7930 - specificity: 0.9606 - acc: 0.9263 - val_loss: 0.1352 - val_sensitivity: 0.5975 - val_specificity: 0.9669 - val_acc: 0.9388
# Epoch 51/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1631 - sensitivity: 0.7914 - specificity: 0.9615 - acc: 0.9271Epoch 00051: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1628 - sensitivity: 0.7925 - specificity: 0.9613 - acc: 0.9273 - val_loss: 0.1336 - val_sensitivity: 0.5929 - val_specificity: 0.9682 - val_acc: 0.9406
# Epoch 52/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1694 - sensitivity: 0.8031 - specificity: 0.9562 - acc: 0.9229Epoch 00052: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1686 - sensitivity: 0.8030 - specificity: 0.9570 - acc: 0.9235 - val_loss: 0.1324 - val_sensitivity: 0.5787 - val_specificity: 0.9727 - val_acc: 0.9429
# Epoch 53/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1717 - sensitivity: 0.7880 - specificity: 0.9581 - acc: 0.9217Epoch 00053: val_loss improved from 0.13200 to 0.12994, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1725 - sensitivity: 0.7882 - specificity: 0.9573 - acc: 0.9213 - val_loss: 0.1299 - val_sensitivity: 0.6227 - val_specificity: 0.9688 - val_acc: 0.9435
# Epoch 54/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1764 - sensitivity: 0.7766 - specificity: 0.9600 - acc: 0.9221Epoch 00054: val_loss improved from 0.12994 to 0.12785, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 62s 1s/step - loss: 0.1778 - sensitivity: 0.7805 - specificity: 0.9588 - acc: 0.9217 - val_loss: 0.1278 - val_sensitivity: 0.5401 - val_specificity: 0.9765 - val_acc: 0.9429
# Epoch 55/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1662 - sensitivity: 0.7885 - specificity: 0.9602 - acc: 0.9228Epoch 00055: val_loss did not improve
# 57/57 [==============================] - 67s 1s/step - loss: 0.1666 - sensitivity: 0.7883 - specificity: 0.9600 - acc: 0.9228 - val_loss: 0.1298 - val_sensitivity: 0.5882 - val_specificity: 0.9725 - val_acc: 0.9429
# Epoch 56/500
# 56/57 [============================>.] - ETA: 1s - loss: 0.1737 - sensitivity: 0.7838 - specificity: 0.9603 - acc: 0.9221Epoch 00056: val_loss did not improve
# 57/57 [==============================] - 72s 1s/step - loss: 0.1747 - sensitivity: 0.7832 - specificity: 0.9597 - acc: 0.9217 - val_loss: 0.1320 - val_sensitivity: 0.5940 - val_specificity: 0.9681 - val_acc: 0.9394
# Epoch 57/500
# 56/57 [============================>.] - ETA: 1s - loss: 0.1648 - sensitivity: 0.8130 - specificity: 0.9635 - acc: 0.9307Epoch 00057: val_loss did not improve
# 57/57 [==============================] - 73s 1s/step - loss: 0.1660 - sensitivity: 0.8075 - specificity: 0.9632 - acc: 0.9291 - val_loss: 0.1328 - val_sensitivity: 0.6202 - val_specificity: 0.9680 - val_acc: 0.9412
# Epoch 58/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1641 - sensitivity: 0.7864 - specificity: 0.9589 - acc: 0.9229Epoch 00058: val_loss did not improve
# 57/57 [==============================] - 59s 1s/step - loss: 0.1622 - sensitivity: 0.7901 - specificity: 0.9596 - acc: 0.9242 - val_loss: 0.1355 - val_sensitivity: 0.4902 - val_specificity: 0.9634 - val_acc: 0.9406
# Epoch 59/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1600 - sensitivity: 0.7900 - specificity: 0.9604 - acc: 0.9246Epoch 00059: val_loss did not improve
# 57/57 [==============================] - 50s 869ms/step - loss: 0.1593 - sensitivity: 0.7898 - specificity: 0.9602 - acc: 0.9246 - val_loss: 0.1469 - val_sensitivity: 0.6842 - val_specificity: 0.9510 - val_acc: 0.9324
# Epoch 60/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1575 - sensitivity: 0.7978 - specificity: 0.9652 - acc: 0.9296Epoch 00060: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1566 - sensitivity: 0.8014 - specificity: 0.9649 - acc: 0.9301 - val_loss: 0.1346 - val_sensitivity: 0.6224 - val_specificity: 0.9657 - val_acc: 0.9388
# Epoch 61/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1577 - sensitivity: 0.8119 - specificity: 0.9605 - acc: 0.9292Epoch 00061: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1589 - sensitivity: 0.8099 - specificity: 0.9608 - acc: 0.9290 - val_loss: 0.1378 - val_sensitivity: 0.6584 - val_specificity: 0.9599 - val_acc: 0.9377
# Epoch 62/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1544 - sensitivity: 0.8032 - specificity: 0.9664 - acc: 0.9335Epoch 00062: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1542 - sensitivity: 0.8031 - specificity: 0.9662 - acc: 0.9333 - val_loss: 0.1315 - val_sensitivity: 0.6217 - val_specificity: 0.9689 - val_acc: 0.9418
# Epoch 63/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1611 - sensitivity: 0.7938 - specificity: 0.9618 - acc: 0.9282Epoch 00063: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1615 - sensitivity: 0.7916 - specificity: 0.9617 - acc: 0.9280 - val_loss: 0.1322 - val_sensitivity: 0.6161 - val_specificity: 0.9670 - val_acc: 0.9394
# Epoch 64/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1494 - sensitivity: 0.8095 - specificity: 0.9636 - acc: 0.9317Epoch 00064: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1505 - sensitivity: 0.8093 - specificity: 0.9627 - acc: 0.9312 - val_loss: 0.1328 - val_sensitivity: 0.6241 - val_specificity: 0.9676 - val_acc: 0.9406
# Epoch 65/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1580 - sensitivity: 0.7867 - specificity: 0.9604 - acc: 0.9259Epoch 00065: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1593 - sensitivity: 0.7847 - specificity: 0.9606 - acc: 0.9255 - val_loss: 0.1302 - val_sensitivity: 0.5678 - val_specificity: 0.9757 - val_acc: 0.9441
# Epoch 66/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1495 - sensitivity: 0.8381 - specificity: 0.9639 - acc: 0.9363Epoch 00066: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1486 - sensitivity: 0.8389 - specificity: 0.9641 - acc: 0.9368 - val_loss: 0.1327 - val_sensitivity: 0.6069 - val_specificity: 0.9682 - val_acc: 0.9400
# Epoch 67/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1538 - sensitivity: 0.8023 - specificity: 0.9630 - acc: 0.9314Epoch 00071: val_loss did not improve
# 57/57 [==============================] - 49s 867ms/step - loss: 0.1546 - sensitivity: 0.8009 - specificity: 0.9637 - acc: 0.9315 - val_loss: 0.1423 - val_sensitivity: 0.6921 - val_specificity: 0.9580 - val_acc: 0.9383
# Epoch 72/500
# 56/57 [============================>.] - ETA: 1s - loss: 0.1457 - sensitivity: 0.7868 - specificity: 0.9704 - acc: 0.9324Epoch 00072: val_loss did not improve
# 57/57 [==============================] - 68s 1s/step - loss: 0.1464 - sensitivity: 0.7881 - specificity: 0.9697 - acc: 0.9322 - val_loss: 0.1364 - val_sensitivity: 0.6702 - val_specificity: 0.9630 - val_acc: 0.9412
# Epoch 73/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1432 - sensitivity: 0.8084 - specificity: 0.9658 - acc: 0.9336Epoch 00073: val_loss did not improve
# 57/57 [==============================] - 67s 1s/step - loss: 0.1428 - sensitivity: 0.8118 - specificity: 0.9660 - acc: 0.9344 - val_loss: 0.1329 - val_sensitivity: 0.6649 - val_specificity: 0.9662 - val_acc: 0.9435
# Epoch 74/500
# 56/57 [============================>.] - ETA: 1s - loss: 0.1427 - sensitivity: 0.8345 - specificity: 0.9685 - acc: 0.9389Epoch 00074: val_loss did not improve
# 57/57 [==============================] - 70s 1s/step - loss: 0.1414 - sensitivity: 0.8375 - specificity: 0.9691 - acc: 0.9400 - val_loss: 0.1309 - val_sensitivity: 0.6619 - val_specificity: 0.9669 - val_acc: 0.9435
# Epoch 75/500
# 56/57 [============================>.] - ETA: 1s - loss: 0.1497 - sensitivity: 0.8130 - specificity: 0.9725 - acc: 0.9381Epoch 00075: val_loss did not improve
# 57/57 [==============================] - 72s 1s/step - loss: 0.1483 - sensitivity: 0.8147 - specificity: 0.9730 - acc: 0.9388 - val_loss: 0.1393 - val_sensitivity: 0.6924 - val_specificity: 0.9599 - val_acc: 0.9400
# Epoch 76/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1541 - sensitivity: 0.8320 - specificity: 0.9643 - acc: 0.9353Epoch 00076: val_loss did not improve
# 57/57 [==============================] - 49s 866ms/step - loss: 0.1530 - sensitivity: 0.8321 - specificity: 0.9649 - acc: 0.9357 - val_loss: 0.1276 - val_sensitivity: 0.6117 - val_specificity: 0.9701 - val_acc: 0.9423
# Epoch 77/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1475 - sensitivity: 0.8126 - specificity: 0.9665 - acc: 0.9328Epoch 00077: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1466 - sensitivity: 0.8130 - specificity: 0.9671 - acc: 0.9333 - val_loss: 0.1450 - val_sensitivity: 0.7337 - val_specificity: 0.9562 - val_acc: 0.9400
# Epoch 78/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1382 - sensitivity: 0.8304 - specificity: 0.9669 - acc: 0.9392Epoch 00078: val_loss did not improve
# 57/57 [==============================] - 49s 867ms/step - loss: 0.1370 - sensitivity: 0.8334 - specificity: 0.9670 - acc: 0.9400 - val_loss: 0.1351 - val_sensitivity: 0.6644 - val_specificity: 0.9643 - val_acc: 0.9418
# Epoch 79/500
# 56/57 [============================>.] - ETA: 1s - loss: 0.1511 - sensitivity: 0.7801 - specificity: 0.9683 - acc: 0.9328Epoch 00079: val_loss did not improve
# 57/57 [==============================] - 69s 1s/step - loss: 0.1502 - sensitivity: 0.7822 - specificity: 0.9684 - acc: 0.9333 - val_loss: 0.1308 - val_sensitivity: 0.6307 - val_specificity: 0.9706 - val_acc: 0.9447
# Epoch 80/500
# 56/57 [============================>.] - ETA: 1s - loss: 0.1292 - sensitivity: 0.8493 - specificity: 0.9749 - acc: 0.9486Epoch 00080: val_loss did not improve
# 57/57 [==============================] - 69s 1s/step - loss: 0.1285 - sensitivity: 0.8494 - specificity: 0.9745 - acc: 0.9484 - val_loss: 0.1413 - val_sensitivity: 0.7284 - val_specificity: 0.9617 - val_acc: 0.9453
# Epoch 81/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1338 - sensitivity: 0.8058 - specificity: 0.9677 - acc: 0.9342Epoch 00081: val_loss did not improve
# 57/57 [==============================] - 49s 861ms/step - loss: 0.1349 - sensitivity: 0.8004 - specificity: 0.9678 - acc: 0.9336 - val_loss: 0.1323 - val_sensitivity: 0.6535 - val_specificity: 0.9675 - val_acc: 0.9435
# Epoch 82/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1326 - sensitivity: 0.8387 - specificity: 0.9721 - acc: 0.9450Epoch 00082: val_loss did not improve
# 57/57 [==============================] - 56s 981ms/step - loss: 0.1329 - sensitivity: 0.8374 - specificity: 0.9726 - acc: 0.9449 - val_loss: 0.1451 - val_sensitivity: 0.7218 - val_specificity: 0.9554 - val_acc: 0.9388
# Epoch 83/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1475 - sensitivity: 0.8190 - specificity: 0.9643 - acc: 0.9332Epoch 00083: val_loss did not improve
# 57/57 [==============================] - 66s 1s/step - loss: 0.1483 - sensitivity: 0.8182 - specificity: 0.9640 - acc: 0.9330 - val_loss: 0.1333 - val_sensitivity: 0.6729 - val_specificity: 0.9649 - val_acc: 0.9423
# Epoch 84/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1308 - sensitivity: 0.8314 - specificity: 0.9704 - acc: 0.9407Epoch 00084: val_loss did not improve
# 57/57 [==============================] - 51s 887ms/step - loss: 0.1308 - sensitivity: 0.8308 - specificity: 0.9704 - acc: 0.9403 - val_loss: 0.1357 - val_sensitivity: 0.6768 - val_specificity: 0.9663 - val_acc: 0.9447
# Epoch 85/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1435 - sensitivity: 0.8151 - specificity: 0.9697 - acc: 0.9379Epoch 00085: val_loss did not improve
# 57/57 [==============================] - 49s 861ms/step - loss: 0.1426 - sensitivity: 0.8139 - specificity: 0.9702 - acc: 0.9382 - val_loss: 0.1348 - val_sensitivity: 0.6733 - val_specificity: 0.9636 - val_acc: 0.9412
# Epoch 86/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1277 - sensitivity: 0.8350 - specificity: 0.9711 - acc: 0.9425Epoch 00086: val_loss improved from 0.12747 to 0.12703, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 897ms/step - loss: 0.1267 - sensitivity: 0.8356 - specificity: 0.9712 - acc: 0.9428 - val_loss: 0.1270 - val_sensitivity: 0.5539 - val_specificity: 0.9757 - val_acc: 0.9435
# Epoch 87/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1393 - sensitivity: 0.8142 - specificity: 0.9693 - acc: 0.9360Epoch 00087: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1384 - sensitivity: 0.8143 - specificity: 0.9698 - acc: 0.9364 - val_loss: 0.1300 - val_sensitivity: 0.5401 - val_specificity: 0.9757 - val_acc: 0.9435
# Epoch 88/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1446 - sensitivity: 0.8140 - specificity: 0.9688 - acc: 0.9341Epoch 00088: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1446 - sensitivity: 0.8136 - specificity: 0.9689 - acc: 0.9339 - val_loss: 0.1293 - val_sensitivity: 0.5913 - val_specificity: 0.9738 - val_acc: 0.9441
# Epoch 89/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1345 - sensitivity: 0.8076 - specificity: 0.9697 - acc: 0.9368Epoch 00089: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1348 - sensitivity: 0.8066 - specificity: 0.9698 - acc: 0.9365 - val_loss: 0.1463 - val_sensitivity: 0.6382 - val_specificity: 0.9644 - val_acc: 0.9394
# Epoch 90/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1197 - sensitivity: 0.8467 - specificity: 0.9696 - acc: 0.9464Epoch 00090: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1203 - sensitivity: 0.8480 - specificity: 0.9697 - acc: 0.9466 - val_loss: 0.1371 - val_sensitivity: 0.6527 - val_specificity: 0.9689 - val_acc: 0.9441
# Epoch 91/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1356 - sensitivity: 0.8248 - specificity: 0.9723 - acc: 0.9403Epoch 00091: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1382 - sensitivity: 0.8211 - specificity: 0.9714 - acc: 0.9386 - val_loss: 0.1329 - val_sensitivity: 0.6370 - val_specificity: 0.9732 - val_acc: 0.9476
# Epoch 92/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1259 - sensitivity: 0.8518 - specificity: 0.9696 - acc: 0.9450Epoch 00092: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1255 - sensitivity: 0.8522 - specificity: 0.9697 - acc: 0.9452 - val_loss: 0.1304 - val_sensitivity: 0.4731 - val_specificity: 0.9848 - val_acc: 0.9447
# Epoch 93/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1227 - sensitivity: 0.8237 - specificity: 0.9766 - acc: 0.9454Epoch 00093: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1226 - sensitivity: 0.8228 - specificity: 0.9766 - acc: 0.9453 - val_loss: 0.1312 - val_sensitivity: 0.5421 - val_specificity: 0.9790 - val_acc: 0.9458
# Epoch 94/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1346 - sensitivity: 0.8305 - specificity: 0.9745 - acc: 0.9450Epoch 00094: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1340 - sensitivity: 0.8299 - specificity: 0.9745 - acc: 0.9449 - val_loss: 0.1290 - val_sensitivity: 0.6426 - val_specificity: 0.9746 - val_acc: 0.9487
# Epoch 95/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1158 - sensitivity: 0.8780 - specificity: 0.9702 - acc: 0.9507Epoch 00095: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1149 - sensitivity: 0.8781 - specificity: 0.9707 - acc: 0.9512 - val_loss: 0.1306 - val_sensitivity: 0.6675 - val_specificity: 0.9727 - val_acc: 0.9487
# Epoch 96/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1419 - sensitivity: 0.8149 - specificity: 0.9733 - acc: 0.9378Epoch 00096: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1415 - sensitivity: 0.8147 - specificity: 0.9733 - acc: 0.9378 - val_loss: 0.1375 - val_sensitivity: 0.6911 - val_specificity: 0.9630 - val_acc: 0.9429
# Epoch 97/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1176 - sensitivity: 0.8629 - specificity: 0.9734 - acc: 0.9507

# %% [raw]
# model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid) #gen_flow_val,  #(X_valid, Y_valid),
#                     steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
#                     #validation_steps=int(np.ceil(len(X_valid)/batch_size)),
#                     epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
#                     class_weight = class_weight)
#                     #class_weights = class_weight

# %% [markdown]
# ## IV. Visualize  TSNE

# %%
# %matplotlib inline
import numpy as np
# visualize the points' distribution of train data using features built from base_model
import matplotlib.pyplot as plt
# dimension reduction
from sklearn.manifold import TSNE 
import numpy as np

def t_sne_vis(name, base_model, x_processed_images, random_state, labels,perplexity = 30):
    """
    :param name: the name of the cnn model used to build features
    :param base_model: the model obj
    :param x_processed_images: the input images for our model
    :param random_state: for fixing the results
    :param labels: 0/1 classification labels
    :return:
    the graph of image distribution based on features extracted from the model and the t-sne features
    """
    # convert data to images
    print('Converting data points to composite image')
    X_train = x_processed_images
    print('we got %d different images of shape %dx%d ' % (len(X_train), X_train.shape[1], X_train.shape[1]))
    print('build usefull features from the selected model')
    features = base_model.predict(X_train)
    x_data1 = np.asarray(features).astype('float64')
    x_data1 = x_data1.reshape((x_data1.shape[0], -1))
    # perform t-SNE embedding
    print('performing t-sne reduction')
    vis_data = TSNE(perplexity=perplexity, random_state=random_state).fit_transform(x_data1)
    # plot the result
    fig = plt.figure(figsize=(15, 15))
    vis_x = vis_data[:, 0]
    vis_y = vis_data[:, 1]
    plt.scatter(vis_x, vis_y, c=labels, cmap=plt.cm.get_cmap("winter", 2))
    plt.colorbar(ticks=range(2))
    plt.clim(0, 1)
    plt.title(name)
    plt.grid()
    plt.show()
    fig.savefig('tsne_vis_'+name+'.png')
    return vis_data

# %%
model.summary()

# %%
name = 'Resnet'
print('visualizing for %s' %name)
base_model_ = Model(input=model.input, output=model.get_layer('avg_pool').output)
tsne_feats = t_sne_vis(name, base_model_, X_valid, np.random.RandomState(42), Y_valid,perplexity=30)

# %% [markdown]
# ## V. Evaluate Model

# %%
model = load_model(weights_path+"BestKerasResnet50_flat_3_loss_no_weight.h5", custom_objects={'sensitivity': sensitivity,
                                                                             "specificity":specificity})
score = model.evaluate(X_valid, Y_valid, verbose=1)
print('Test loss:', score[0])
print('Test sensitivity:', score[1])
print('Test specificity:', score[2])
print('Test acc:', score[3])

# %%
#compute metrics
pred = model.predict(X_valid)
average_precision = average_precision_score(Y_valid, pred)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))

# %%
precision, recall, _ = precision_recall_curve(Y_valid, pred)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))

# %%
def generate_results(y_test, y_score):
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.show()
    print('AUC: %f' % roc_auc)

# %%
generate_results

# %% [markdown]
# #compute log loss
# pred = model.predict(X_valid)
# log_loss(Y_valid,pred)

# %% [markdown]
# ## VI. Retrain on full dataset

# %% [raw]
# #Generate the training data
# #Create 3 bands having HH, HV and avg of both
# X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
# X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
# X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],
#                           ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)

# %% [raw]
# #parse corrupted notebook file
# t = ["#Generate the training data\n",
#     "#Create 3 bands having HH, HV and avg of both\n",
#     "X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_1\"]])\n",
#     "X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_2\"]])\n",
#     "X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],\n",
#     "                          ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)"]
# #t.remove("\n")
# t=[x.replace("\n",'') for x in t]
# for x in t:
#     print(x)
