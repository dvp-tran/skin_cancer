# %% [markdown]
# # Skin Cancer Classification Challenge

# %% [markdown]
# **Summary : ** skin cancer.

# %% [markdown]
# ## Preliminaries and Imports

# %%
#general & system\n",
import os

#data processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 10, 10  #default setting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#data augmentation
from PIL import Image
from random import choice
import cv2
import numpy as np
#import keras.preprocessing.image as prep

#ML part
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing import image as kimage
from keras.models import Sequential
from keras.layers import GlobalMaxPooling2D, Dense, BatchNormalization, GlobalAveragePooling2D,Dropout,Activation,Flatten
from keras.models import Model
from keras.optimizers import SGD
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

#validation
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score


from sklearn.metrics import precision_recall_curve
from imblearn.over_sampling import SMOTE
from sklearn.utils import resample

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## I. Load Data

# %% [markdown]
# - **Rq : ** Datasets are quite light, can be fully loaded in a laptop memory with ease.

# %%
# %%time
meta = pd.read_csv("../data/label_learn.csv", sep = ";")
# Out:
# CPU times: user 4 ms, sys: 4 ms, total: 8 ms
# Wall time: 5.17 ms

# %%
meta.head()
# Out:
#           name      label
# 0  0000000.jpg     benign
# 1  0000002.jpg  malignant
# 2  0000006.jpg     benign
# 3  0000008.jpg     benign
# 4  0000009.jpg     benign

# %%
# %%time
train_list = os.listdir("../data/resized_train/")
len(train_list) == len(meta.name)
# Out:
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 3.7 ms

# %%
train_list.sort() == list(meta.name).sort()
# Out:
# True

# %%
# %%time
X_train = np.array([np.array(Image.open("../data/resized_train/"+fname)) for fname in meta.name])
Y_train = [1 if x=="malignant" else 0 for x in meta.label]
Y_train = np.array(Y_train)
# Out:
# CPU times: user 21.8 s, sys: 1.71 s, total: 23.5 s
# Wall time: 23.5 s

# %%
print(X_train.shape)
print(len(Y_train))
X_train.shape[0] == len(meta.name) == len(Y_train)
# Out:
# (8581, 299, 299, 3)
# 8581
# True

# %%
#control
print(meta.name[0:5])
print(Y_train[0:5])
print(meta.label[0:5])
# Out:
# 0    0000000.jpg
# 1    0000002.jpg
# 2    0000006.jpg
# 3    0000008.jpg
# 4    0000009.jpg
# Name: name, dtype: object
# [0 1 0 0 0]
# 0       benign
# 1    malignant
# 2       benign
# 3       benign
# 4       benign
# Name: label, dtype: object

# %% [markdown]
# ## II. Data Preparation

# %% [markdown]
# - **Class weights**

# %%
class_weight_or = class_weight.compute_class_weight('balanced', np.unique(Y_train), Y_train)

# %% [markdown]
# - **Data splitting**

# %%
#data splitting
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train, Y_train, random_state=42, train_size=0.80)
# Out:
# /home/dvp_tran/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# - **Resampling**

# %%
temp = sum(Y_train)
sample_size = temp*2700/(374+254)  #1372
sample_size
# Out:
# 2325

# %%
def random_undersampling(X, Y,sample_size = sample_size, n_sample=1):
    """
    X,y : numpy arrays
    return :
    5 random ensemble of indices general_balenced_set:
        general_balenced_set[0] = the shuffeled indices that inssure the class balance
    """
    indices = np.array(range(len(Y)))
    positive_samples = indices[Y==1]
    #print(type(positive_samples))
    negative_samples = indices[Y==0]
    #print(type(negative_samples))
    general_balenced_set = []
    for k in range(n_sample):
        indices_ = np.random.choice(negative_samples, sample_size, replace=False)
        #print(len(indices_))
        # append positive and negative
        balenced_set = np.append(indices_, positive_samples)
        #print(len(balenced_set))
        # shuffle indices
        np.random.shuffle(balenced_set)
        #print(len(balenced_set))
        general_balenced_set.append(balenced_set)
    return general_balenced_set

# %%
general_balenced_set = random_undersampling(X_train,Y_train)
X_train = X_train[general_balenced_set]
Y_train = Y_train[general_balenced_set]

# %% [markdown]
# ## III. Deep Learning with Transfer Learning

# %%
weights_path = '../model/checkpoints/'

if not os.path.exists(weights_path):
    os.makedirs(weights_path)
    
epochs = 500
batch_size = 50

# %% [markdown]
# - **Using RESNET : **

# %%
#load base model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(299,299,3))
base_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
#adding top layers
    #sequentialy
add_model = Sequential()
add_model.add(GlobalAveragePooling2D(input_shape=base_model.output_shape[1:])) #Flatten/GlobalAveragePooling2D
add_model.add(Dense(1024, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(512, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(1, activation='sigmoid'))

model = Model(inputs=base_model.input, outputs=add_model(base_model.output))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1)            2623489     avg_pool[0][0]
# ==================================================================================================
# Total params: 26,211,201
# Trainable params: 26,158,081
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [raw]
# #adding top layers
#     #need to check api to add layers sequentialy
# x = base_model.output
# x = GlobalAveragePooling2D()(x) #Flatten instead?
# x = Dense(1024, activation='relu')(x)
# x = Dropout(0.25)(x)
# x = Dense(512, activation='relu')(x)
# x = Dropout(0.25)(x)
# predictions = Dense(1, activation='sigmoid')(x)
#
# model = Model(inputs=base_model.input, outputs=predictions)
# model.summary()

# %%
from keras import backend as K

def weighted_categorical_crossentropy(weights):
    """
    [w_0, w_1] : weight of 0 class and weight of 1 class
    """
    weights = K.variable(weights)

    def loss(y_true, y_pred):
        # scale predictions so that the class probas of each sample sum to 1
        #y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
        # clip to prevent NaN's and Inf's
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        # calc
        loss = y_true * K.log(y_pred) * weights[1] + (1 - y_true) * K.log(1 - y_pred) * weights[0]
        loss = -K.sum(loss, -1)
        return loss

    return loss

# %%
class_weight_or
# Out:
# array([ 0.54296381,  6.31885125])

# %%
loss1 = weighted_categorical_crossentropy(class_weight_or) #(np.array([0.8,4]))

# %%
#freeze lower layers of the model
#for layer in model.layers[:]:
    #layer.trainable = False
for layer in model.layers[0:]:
    layer.trainable = True
    

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())




#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss="binary_crossentropy", #binary_crossentropy
              metrics=[sensitivity, specificity,"accuracy"])

# %%
# %%time
#Lets define the image transormations that we wan

gen = ImageDataGenerator(horizontal_flip=True,
                         vertical_flip=True,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         zoom_range=0.2,
                         rotation_range=40)

val_datagen = ImageDataGenerator()
# Here is the function that merges our two generators
# We use the exact same generator with the same random seed for both the y and angle arrays
def gen_flow_for_one_input(X1, y):
    genX1 = gen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]

def val_datagen_(X1, y):
    genX1 = val_datagen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]
#Finally create out generator
gen_flow_train = gen_flow_for_one_input(X_train, Y_train)
#gen_flow_val = gen_flow_for_one_input(X_valid, Y_valid)
gen_flow_val = val_datagen_(X_valid, Y_valid)

from keras.callbacks import EarlyStopping, ModelCheckpoint
epochs_to_wait_for_improve = 30
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=epochs_to_wait_for_improve)
checkpoint_callback = ModelCheckpoint(weights_path + 'BestKerasResnet50_flat_3_loss_no_weight_raw.h5', monitor='val_loss',
                                      verbose=1, save_best_only=True, mode='min')
#fit the model
model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid),
                    steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
                    epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
                    class_weight = class_weight_or)
# Out:
# Epoch 1/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.5191 - sensitivity: 0.0935 - specificity: 0.9267 - acc: 0.7689Epoch 00001: val_loss improved from inf to 0.40603, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 73s 1s/step - loss: 0.5170 - sensitivity: 0.0971 - specificity: 0.9275 - acc: 0.7702 - val_loss: 0.4060 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - val_acc: 0.9196
# Epoch 2/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3934 - sensitivity: 0.1242 - specificity: 0.9843 - acc: 0.8261Epoch 00002: val_loss improved from 0.40603 to 0.32208, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 52s 905ms/step - loss: 0.3936 - sensitivity: 0.1220 - specificity: 0.9846 - acc: 0.8249 - val_loss: 0.3221 - val_sensitivity: 0.0251 - val_specificity: 0.9974 - val_acc: 0.9196
# Epoch 3/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3599 - sensitivity: 0.2483 - specificity: 0.9675 - acc: 0.8287Epoch 00003: val_loss improved from 0.32208 to 0.26319, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.3588 - sensitivity: 0.2540 - specificity: 0.9668 - acc: 0.8296 - val_loss: 0.2632 - val_sensitivity: 0.1746 - val_specificity: 0.9875 - val_acc: 0.9208
# Epoch 4/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3149 - sensitivity: 0.3820 - specificity: 0.9635 - acc: 0.8478Epoch 00004: val_loss improved from 0.26319 to 0.23747, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3156 - sensitivity: 0.3787 - specificity: 0.9630 - acc: 0.8480 - val_loss: 0.2375 - val_sensitivity: 0.2631 - val_specificity: 0.9759 - val_acc: 0.9196
# Epoch 5/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3154 - sensitivity: 0.4136 - specificity: 0.9506 - acc: 0.8445Epoch 00005: val_loss improved from 0.23747 to 0.22135, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.3142 - sensitivity: 0.4161 - specificity: 0.9502 - acc: 0.8448 - val_loss: 0.2213 - val_sensitivity: 0.3107 - val_specificity: 0.9658 - val_acc: 0.9144
# Epoch 6/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2835 - sensitivity: 0.4953 - specificity: 0.9532 - acc: 0.8627Epoch 00006: val_loss improved from 0.22135 to 0.20651, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2836 - sensitivity: 0.4963 - specificity: 0.9526 - acc: 0.8623 - val_loss: 0.2065 - val_sensitivity: 0.3945 - val_specificity: 0.9631 - val_acc: 0.9190
# Epoch 7/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2656 - sensitivity: 0.5425 - specificity: 0.9457 - acc: 0.8656Epoch 00007: val_loss improved from 0.20651 to 0.19872, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2642 - sensitivity: 0.5466 - specificity: 0.9462 - acc: 0.8669 - val_loss: 0.1987 - val_sensitivity: 0.4601 - val_specificity: 0.9580 - val_acc: 0.9208
# Epoch 8/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2728 - sensitivity: 0.5899 - specificity: 0.9415 - acc: 0.8696Epoch 00008: val_loss improved from 0.19872 to 0.19026, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2719 - sensitivity: 0.5853 - specificity: 0.9416 - acc: 0.8691 - val_loss: 0.1903 - val_sensitivity: 0.4592 - val_specificity: 0.9591 - val_acc: 0.9220
# Epoch 9/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2552 - sensitivity: 0.6456 - specificity: 0.9382 - acc: 0.8800Epoch 00009: val_loss improved from 0.19026 to 0.17801, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2581 - sensitivity: 0.6436 - specificity: 0.9373 - acc: 0.8782 - val_loss: 0.1780 - val_sensitivity: 0.4412 - val_specificity: 0.9623 - val_acc: 0.9237
# Epoch 10/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2525 - sensitivity: 0.6254 - specificity: 0.9378 - acc: 0.8725Epoch 00010: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.2514 - sensitivity: 0.6290 - specificity: 0.9381 - acc: 0.8737 - val_loss: 0.1794 - val_sensitivity: 0.5109 - val_specificity: 0.9483 - val_acc: 0.9167
# Epoch 11/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2530 - sensitivity: 0.6818 - specificity: 0.9404 - acc: 0.8878Epoch 00011: val_loss improved from 0.17801 to 0.17327, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2534 - sensitivity: 0.6794 - specificity: 0.9405 - acc: 0.8873 - val_loss: 0.1733 - val_sensitivity: 0.5172 - val_specificity: 0.9521 - val_acc: 0.9214
# Epoch 12/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2425 - sensitivity: 0.6655 - specificity: 0.9335 - acc: 0.8767Epoch 00012: val_loss improved from 0.17327 to 0.17306, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 902ms/step - loss: 0.2420 - sensitivity: 0.6656 - specificity: 0.9338 - acc: 0.8775 - val_loss: 0.1731 - val_sensitivity: 0.5538 - val_specificity: 0.9560 - val_acc: 0.9249
# Epoch 13/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2306 - sensitivity: 0.6986 - specificity: 0.9385 - acc: 0.8918Epoch 00013: val_loss improved from 0.17306 to 0.16867, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2297 - sensitivity: 0.7003 - specificity: 0.9391 - acc: 0.8926 - val_loss: 0.1687 - val_sensitivity: 0.5145 - val_specificity: 0.9547 - val_acc: 0.9225
# Epoch 14/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2436 - sensitivity: 0.6422 - specificity: 0.9318 - acc: 0.8731Epoch 00014: val_loss improved from 0.16867 to 0.16411, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2425 - sensitivity: 0.6435 - specificity: 0.9325 - acc: 0.8743 - val_loss: 0.1641 - val_sensitivity: 0.5448 - val_specificity: 0.9566 - val_acc: 0.9255
# Epoch 15/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2276 - sensitivity: 0.7143 - specificity: 0.9394 - acc: 0.8942Epoch 00015: val_loss improved from 0.16411 to 0.16397, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2283 - sensitivity: 0.7106 - specificity: 0.9387 - acc: 0.8929 - val_loss: 0.1640 - val_sensitivity: 0.5514 - val_specificity: 0.9547 - val_acc: 0.9249
# Epoch 16/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2431 - sensitivity: 0.6928 - specificity: 0.9359 - acc: 0.8808Epoch 00016: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2438 - sensitivity: 0.6910 - specificity: 0.9366 - acc: 0.8809 - val_loss: 0.1661 - val_sensitivity: 0.5625 - val_specificity: 0.9547 - val_acc: 0.9255
# Epoch 17/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2283 - sensitivity: 0.7065 - specificity: 0.9348 - acc: 0.8875Epoch 00017: val_loss improved from 0.16397 to 0.16389, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.2273 - sensitivity: 0.7087 - specificity: 0.9347 - acc: 0.8880 - val_loss: 0.1639 - val_sensitivity: 0.5747 - val_specificity: 0.9542 - val_acc: 0.9266
# Epoch 18/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2272 - sensitivity: 0.7273 - specificity: 0.9394 - acc: 0.8942Epoch 00018: val_loss improved from 0.16389 to 0.16001, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2280 - sensitivity: 0.7255 - specificity: 0.9392 - acc: 0.8940 - val_loss: 0.1600 - val_sensitivity: 0.5633 - val_specificity: 0.9560 - val_acc: 0.9266
# Epoch 19/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2239 - sensitivity: 0.7469 - specificity: 0.9377 - acc: 0.8975Epoch 00019: val_loss improved from 0.16001 to 0.15588, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2221 - sensitivity: 0.7494 - specificity: 0.9388 - acc: 0.8989 - val_loss: 0.1559 - val_sensitivity: 0.5560 - val_specificity: 0.9573 - val_acc: 0.9272
# Epoch 20/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2311 - sensitivity: 0.7481 - specificity: 0.9342 - acc: 0.8931Epoch 00020: val_loss improved from 0.15588 to 0.15373, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2315 - sensitivity: 0.7438 - specificity: 0.9345 - acc: 0.8922 - val_loss: 0.1537 - val_sensitivity: 0.5516 - val_specificity: 0.9586 - val_acc: 0.9278
# Epoch 21/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2247 - sensitivity: 0.7410 - specificity: 0.9338 - acc: 0.8920Epoch 00021: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2246 - sensitivity: 0.7424 - specificity: 0.9345 - acc: 0.8929 - val_loss: 0.1598 - val_sensitivity: 0.5790 - val_specificity: 0.9502 - val_acc: 0.9237
# Epoch 22/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2111 - sensitivity: 0.7291 - specificity: 0.9435 - acc: 0.9009Epoch 00022: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2119 - sensitivity: 0.7281 - specificity: 0.9425 - acc: 0.9002 - val_loss: 0.1601 - val_sensitivity: 0.5849 - val_specificity: 0.9471 - val_acc: 0.9214
# Epoch 23/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2162 - sensitivity: 0.7404 - specificity: 0.9398 - acc: 0.8982Epoch 00023: val_loss improved from 0.15373 to 0.15243, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2163 - sensitivity: 0.7415 - specificity: 0.9391 - acc: 0.8978 - val_loss: 0.1524 - val_sensitivity: 0.5608 - val_specificity: 0.9555 - val_acc: 0.9260
# Epoch 24/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2188 - sensitivity: 0.7279 - specificity: 0.9376 - acc: 0.8903Epoch 00024: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2184 - sensitivity: 0.7306 - specificity: 0.9379 - acc: 0.8912 - val_loss: 0.1545 - val_sensitivity: 0.5827 - val_specificity: 0.9509 - val_acc: 0.9243
# Epoch 25/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2197 - sensitivity: 0.7282 - specificity: 0.9406 - acc: 0.8958Epoch 00025: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2198 - sensitivity: 0.7331 - specificity: 0.9391 - acc: 0.8952 - val_loss: 0.1534 - val_sensitivity: 0.6060 - val_specificity: 0.9562 - val_acc: 0.9289
# Epoch 26/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2088 - sensitivity: 0.7806 - specificity: 0.9362 - acc: 0.9017Epoch 00026: val_loss improved from 0.15243 to 0.15059, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2105 - sensitivity: 0.7757 - specificity: 0.9368 - acc: 0.9006 - val_loss: 0.1506 - val_sensitivity: 0.5710 - val_specificity: 0.9593 - val_acc: 0.9307
# Epoch 27/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1959 - sensitivity: 0.7751 - specificity: 0.9425 - acc: 0.9103Epoch 00027: val_loss improved from 0.15059 to 0.14882, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1968 - sensitivity: 0.7717 - specificity: 0.9426 - acc: 0.9094 - val_loss: 0.1488 - val_sensitivity: 0.5630 - val_specificity: 0.9568 - val_acc: 0.9278
# Epoch 28/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2278 - sensitivity: 0.7232 - specificity: 0.9334 - acc: 0.8873Epoch 00028: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2271 - sensitivity: 0.7206 - specificity: 0.9333 - acc: 0.8872 - val_loss: 0.1548 - val_sensitivity: 0.6407 - val_specificity: 0.9493 - val_acc: 0.9255
# Epoch 29/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2054 - sensitivity: 0.7860 - specificity: 0.9418 - acc: 0.9089Epoch 00029: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2058 - sensitivity: 0.7824 - specificity: 0.9415 - acc: 0.9077 - val_loss: 0.1518 - val_sensitivity: 0.6038 - val_specificity: 0.9542 - val_acc: 0.9272
# Epoch 30/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2120 - sensitivity: 0.7568 - specificity: 0.9389 - acc: 0.9000Epoch 00030: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2119 - sensitivity: 0.7547 - specificity: 0.9399 - acc: 0.9000 - val_loss: 0.1493 - val_sensitivity: 0.6130 - val_specificity: 0.9535 - val_acc: 0.9278
# Epoch 31/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2016 - sensitivity: 0.7623 - specificity: 0.9415 - acc: 0.9053Epoch 00031: val_loss improved from 0.14882 to 0.14635, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2005 - sensitivity: 0.7621 - specificity: 0.9421 - acc: 0.9059 - val_loss: 0.1463 - val_sensitivity: 0.5710 - val_specificity: 0.9581 - val_acc: 0.9295
# Epoch 32/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2104 - sensitivity: 0.7455 - specificity: 0.9421 - acc: 0.9021Epoch 00032: val_loss improved from 0.14635 to 0.14493, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2104 - sensitivity: 0.7449 - specificity: 0.9415 - acc: 0.9017 - val_loss: 0.1449 - val_sensitivity: 0.5652 - val_specificity: 0.9606 - val_acc: 0.9313
# Epoch 33/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1999 - sensitivity: 0.7505 - specificity: 0.9414 - acc: 0.9064Epoch 00033: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1983 - sensitivity: 0.7507 - specificity: 0.9420 - acc: 0.9070 - val_loss: 0.1472 - val_sensitivity: 0.5652 - val_specificity: 0.9588 - val_acc: 0.9295
# Epoch 34/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1947 - sensitivity: 0.7735 - specificity: 0.9494 - acc: 0.9118Epoch 00034: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1970 - sensitivity: 0.7704 - specificity: 0.9494 - acc: 0.9112 - val_loss: 0.1483 - val_sensitivity: 0.6480 - val_specificity: 0.9530 - val_acc: 0.9295
# Epoch 35/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1966 - sensitivity: 0.7706 - specificity: 0.9434 - acc: 0.9078Epoch 00035: val_loss improved from 0.14493 to 0.14485, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.1965 - sensitivity: 0.7718 - specificity: 0.9424 - acc: 0.9073 - val_loss: 0.1448 - val_sensitivity: 0.5929 - val_specificity: 0.9588 - val_acc: 0.9319
# Epoch 36/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1952 - sensitivity: 0.7746 - specificity: 0.9438 - acc: 0.9085Epoch 00036: val_loss improved from 0.14485 to 0.14082, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.1943 - sensitivity: 0.7785 - specificity: 0.9443 - acc: 0.9098 - val_loss: 0.1408 - val_sensitivity: 0.5638 - val_specificity: 0.9594 - val_acc: 0.9295
# Epoch 37/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1955 - sensitivity: 0.7598 - specificity: 0.9454 - acc: 0.9085Epoch 00037: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1960 - sensitivity: 0.7590 - specificity: 0.9459 - acc: 0.9084 - val_loss: 0.1450 - val_sensitivity: 0.6276 - val_specificity: 0.9549 - val_acc: 0.9301
# Epoch 38/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1997 - sensitivity: 0.7725 - specificity: 0.9395 - acc: 0.9057Epoch 00038: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1992 - sensitivity: 0.7706 - specificity: 0.9394 - acc: 0.9056 - val_loss: 0.1501 - val_sensitivity: 0.6407 - val_specificity: 0.9460 - val_acc: 0.9231
# Epoch 39/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1977 - sensitivity: 0.7662 - specificity: 0.9447 - acc: 0.9060Epoch 00039: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1964 - sensitivity: 0.7680 - specificity: 0.9449 - acc: 0.9066 - val_loss: 0.1495 - val_sensitivity: 0.6856 - val_specificity: 0.9493 - val_acc: 0.9289
# Epoch 40/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1912 - sensitivity: 0.7828 - specificity: 0.9464 - acc: 0.9113Epoch 00040: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1905 - sensitivity: 0.7834 - specificity: 0.9464 - acc: 0.9115 - val_loss: 0.1564 - val_sensitivity: 0.6659 - val_specificity: 0.9377 - val_acc: 0.9173
# Epoch 41/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1878 - sensitivity: 0.7842 - specificity: 0.9474 - acc: 0.9142Epoch 00041: val_loss improved from 0.14082 to 0.13940, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.1875 - sensitivity: 0.7881 - specificity: 0.9472 - acc: 0.9147 - val_loss: 0.1394 - val_sensitivity: 0.6094 - val_specificity: 0.9685 - val_acc: 0.9400
# Epoch 42/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1931 - sensitivity: 0.7556 - specificity: 0.9463 - acc: 0.9071Epoch 00042: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1933 - sensitivity: 0.7564 - specificity: 0.9459 - acc: 0.9069 - val_loss: 0.1429 - val_sensitivity: 0.6477 - val_specificity: 0.9570 - val_acc: 0.9336
# Epoch 43/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1856 - sensitivity: 0.7711 - specificity: 0.9531 - acc: 0.9135Epoch 00043: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1838 - sensitivity: 0.7751 - specificity: 0.9535 - acc: 0.9147 - val_loss: 0.1429 - val_sensitivity: 0.6681 - val_specificity: 0.9551 - val_acc: 0.9330
# Epoch 44/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1816 - sensitivity: 0.8009 - specificity: 0.9511 - acc: 0.9206Epoch 00044: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1815 - sensitivity: 0.8003 - specificity: 0.9515 - acc: 0.9206 - val_loss: 0.1426 - val_sensitivity: 0.6535 - val_specificity: 0.9570 - val_acc: 0.9342
# Epoch 45/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1772 - sensitivity: 0.7937 - specificity: 0.9461 - acc: 0.9184Epoch 00045: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1791 - sensitivity: 0.7925 - specificity: 0.9450 - acc: 0.9174 - val_loss: 0.1419 - val_sensitivity: 0.6499 - val_specificity: 0.9563 - val_acc: 0.9330
# Epoch 46/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2025 - sensitivity: 0.7313 - specificity: 0.9530 - acc: 0.9056Epoch 00046: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2018 - sensitivity: 0.7347 - specificity: 0.9529 - acc: 0.9062 - val_loss: 0.1403 - val_sensitivity: 0.6125 - val_specificity: 0.9582 - val_acc: 0.9336
# Epoch 47/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1784 - sensitivity: 0.7874 - specificity: 0.9440 - acc: 0.9132Epoch 00047: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1790 - sensitivity: 0.7857 - specificity: 0.9449 - acc: 0.9133 - val_loss: 0.1414 - val_sensitivity: 0.5965 - val_specificity: 0.9595 - val_acc: 0.9330
# Epoch 48/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1883 - sensitivity: 0.7634 - specificity: 0.9487 - acc: 0.9107Epoch 00048: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1884 - sensitivity: 0.7632 - specificity: 0.9487 - acc: 0.9105 - val_loss: 0.1483 - val_sensitivity: 0.6623 - val_specificity: 0.9454 - val_acc: 0.9249
# Epoch 49/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1773 - sensitivity: 0.8003 - specificity: 0.9510 - acc: 0.9214Epoch 00049: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1755 - sensitivity: 0.8037 - specificity: 0.9515 - acc: 0.9224 - val_loss: 0.1509 - val_sensitivity: 0.6116 - val_specificity: 0.9517 - val_acc: 0.9266
# Epoch 50/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1753 - sensitivity: 0.7902 - specificity: 0.9488 - acc: 0.9171Epoch 00050: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1755 - sensitivity: 0.7863 - specificity: 0.9489 - acc: 0.9168 - val_loss: 0.1421 - val_sensitivity: 0.6506 - val_specificity: 0.9542 - val_acc: 0.9313
# Epoch 51/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1814 - sensitivity: 0.7706 - specificity: 0.9503 - acc: 0.9127Epoch 00051: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1823 - sensitivity: 0.7658 - specificity: 0.9499 - acc: 0.9115 - val_loss: 0.1407 - val_sensitivity: 0.6458 - val_specificity: 0.9536 - val_acc: 0.9301
# Epoch 52/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1807 - sensitivity: 0.8022 - specificity: 0.9452 - acc: 0.9154Epoch 00052: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1800 - sensitivity: 0.8013 - specificity: 0.9458 - acc: 0.9158 - val_loss: 0.1425 - val_sensitivity: 0.6681 - val_specificity: 0.9537 - val_acc: 0.9330
# Epoch 53/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1766 - sensitivity: 0.7938 - specificity: 0.9548 - acc: 0.9196Epoch 00053: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.1767 - sensitivity: 0.7939 - specificity: 0.9545 - acc: 0.9196 - val_loss: 0.1445 - val_sensitivity: 0.6477 - val_specificity: 0.9539 - val_acc: 0.9313
# Epoch 54/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1808 - sensitivity: 0.7701 - specificity: 0.9548 - acc: 0.9175Epoch 00054: val_loss improved from 0.13940 to 0.13462, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.1799 - sensitivity: 0.7706 - specificity: 0.9547 - acc: 0.9175 - val_loss: 0.1346 - val_sensitivity: 0.6116 - val_specificity: 0.9684 - val_acc: 0.9429
# Epoch 55/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1820 - sensitivity: 0.7698 - specificity: 0.9522 - acc: 0.9160Epoch 00055: val_loss improved from 0.13462 to 0.12815, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1816 - sensitivity: 0.7663 - specificity: 0.9530 - acc: 0.9154 - val_loss: 0.1282 - val_sensitivity: 0.5865 - val_specificity: 0.9746 - val_acc: 0.9441
# Epoch 56/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1695 - sensitivity: 0.7850 - specificity: 0.9557 - acc: 0.9221Epoch 00056: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1694 - sensitivity: 0.7837 - specificity: 0.9560 - acc: 0.9224 - val_loss: 0.1287 - val_sensitivity: 0.4770 - val_specificity: 0.9836 - val_acc: 0.9458
# Epoch 57/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1724 - sensitivity: 0.8065 - specificity: 0.9559 - acc: 0.9243Epoch 00057: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1719 - sensitivity: 0.8077 - specificity: 0.9554 - acc: 0.9242 - val_loss: 0.1319 - val_sensitivity: 0.6265 - val_specificity: 0.9708 - val_acc: 0.9441
# Epoch 58/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1724 - sensitivity: 0.7990 - specificity: 0.9560 - acc: 0.9236Epoch 00058: val_loss did not improve
# 57/57 [==============================] - 49s 868ms/step - loss: 0.1723 - sensitivity: 0.7967 - specificity: 0.9554 - acc: 0.9227 - val_loss: 0.1361 - val_sensitivity: 0.4863 - val_specificity: 0.9634 - val_acc: 0.9400
# Epoch 59/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1761 - sensitivity: 0.7788 - specificity: 0.9526 - acc: 0.9161Epoch 00059: val_loss did not improve
# 57/57 [==============================] - 50s 871ms/step - loss: 0.1756 - sensitivity: 0.7783 - specificity: 0.9530 - acc: 0.9165 - val_loss: 0.1419 - val_sensitivity: 0.6761 - val_specificity: 0.9574 - val_acc: 0.9348
# Epoch 60/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1757 - sensitivity: 0.7927 - specificity: 0.9523 - acc: 0.9221Epoch 00060: val_loss improved from 0.12815 to 0.12813, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1746 - sensitivity: 0.7928 - specificity: 0.9532 - acc: 0.9227 - val_loss: 0.1281 - val_sensitivity: 0.4976 - val_specificity: 0.9772 - val_acc: 0.9423
# Epoch 61/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1638 - sensitivity: 0.8061 - specificity: 0.9577 - acc: 0.9250Epoch 00061: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.1627 - sensitivity: 0.8063 - specificity: 0.9584 - acc: 0.9256 - val_loss: 0.1417 - val_sensitivity: 0.6542 - val_specificity: 0.9575 - val_acc: 0.9354
# Epoch 62/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1732 - sensitivity: 0.7762 - specificity: 0.9531 - acc: 0.9196Epoch 00062: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1726 - sensitivity: 0.7785 - specificity: 0.9535 - acc: 0.9203 - val_loss: 0.1355 - val_sensitivity: 0.6168 - val_specificity: 0.9659 - val_acc: 0.9388
# Epoch 63/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1621 - sensitivity: 0.8186 - specificity: 0.9541 - acc: 0.9246Epoch 00063: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1635 - sensitivity: 0.8137 - specificity: 0.9540 - acc: 0.9231 - val_loss: 0.1405 - val_sensitivity: 0.6399 - val_specificity: 0.9568 - val_acc: 0.9330
# Epoch 64/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1739 - sensitivity: 0.8008 - specificity: 0.9536 - acc: 0.9203Epoch 00064: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1725 - sensitivity: 0.8025 - specificity: 0.9540 - acc: 0.9210 - val_loss: 0.1388 - val_sensitivity: 0.6156 - val_specificity: 0.9594 - val_acc: 0.9330
# Epoch 65/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1652 - sensitivity: 0.7833 - specificity: 0.9593 - acc: 0.9235Epoch 00065: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1645 - sensitivity: 0.7839 - specificity: 0.9595 - acc: 0.9238 - val_loss: 0.1326 - val_sensitivity: 0.5661 - val_specificity: 0.9728 - val_acc: 0.9406
# Epoch 66/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1708 - sensitivity: 0.7892 - specificity: 0.9588 - acc: 0.9237Epoch 00066: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1705 - sensitivity: 0.7907 - specificity: 0.9582 - acc: 0.9237 - val_loss: 0.1344 - val_sensitivity: 0.6251 - val_specificity: 0.9646 - val_acc: 0.9388
# Epoch 67/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1680 - sensitivity: 0.8307 - specificity: 0.9531 - acc: 0.9270Epoch 00067: val_loss improved from 0.12813 to 0.12808, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.1692 - sensitivity: 0.8274 - specificity: 0.9540 - acc: 0.9266 - val_loss: 0.1281 - val_sensitivity: 0.5690 - val_specificity: 0.9739 - val_acc: 0.9429
# Epoch 68/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1641 - sensitivity: 0.8076 - specificity: 0.9571 - acc: 0.9257Epoch 00068: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.1626 - sensitivity: 0.8110 - specificity: 0.9579 - acc: 0.9270 - val_loss: 0.1336 - val_sensitivity: 0.5964 - val_specificity: 0.9691 - val_acc: 0.9400
# Epoch 69/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1629 - sensitivity: 0.7877 - specificity: 0.9583 - acc: 0.9239Epoch 00069: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1624 - sensitivity: 0.7898 - specificity: 0.9578 - acc: 0.9238 - val_loss: 0.1526 - val_sensitivity: 0.6344 - val_specificity: 0.9531 - val_acc: 0.9301
# Epoch 70/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1609 - sensitivity: 0.8229 - specificity: 0.9630 - acc: 0.9309Epoch 00070: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1604 - sensitivity: 0.8221 - specificity: 0.9632 - acc: 0.9311 - val_loss: 0.1418 - val_sensitivity: 0.6291 - val_specificity: 0.9602 - val_acc: 0.9354
# Epoch 71/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1711 - sensitivity: 0.8233 - specificity: 0.9594 - acc: 0.9299Epoch 00071: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1690 - sensitivity: 0.8264 - specificity: 0.9601 - acc: 0.9312 - val_loss: 0.1330 - val_sensitivity: 0.6574 - val_specificity: 0.9671 - val_acc: 0.9435
# Epoch 72/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1633 - sensitivity: 0.7807 - specificity: 0.9569 - acc: 0.9253Epoch 00072: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1630 - sensitivity: 0.7803 - specificity: 0.9569 - acc: 0.9252 - val_loss: 0.1316 - val_sensitivity: 0.6039 - val_specificity: 0.9695 - val_acc: 0.9412
# Epoch 73/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1435 - sensitivity: 0.8322 - specificity: 0.9669 - acc: 0.9382Epoch 00073: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1450 - sensitivity: 0.8316 - specificity: 0.9659 - acc: 0.9375 - val_loss: 0.1286 - val_sensitivity: 0.4613 - val_specificity: 0.9834 - val_acc: 0.9447
# Epoch 74/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1622 - sensitivity: 0.8133 - specificity: 0.9595 - acc: 0.9300Epoch 00074: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1624 - sensitivity: 0.8152 - specificity: 0.9592 - acc: 0.9301 - val_loss: 0.1291 - val_sensitivity: 0.4862 - val_specificity: 0.9809 - val_acc: 0.9447
# Epoch 75/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1617 - sensitivity: 0.8054 - specificity: 0.9626 - acc: 0.9288Epoch 00075: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1619 - sensitivity: 0.8030 - specificity: 0.9624 - acc: 0.9280 - val_loss: 0.1328 - val_sensitivity: 0.6196 - val_specificity: 0.9669 - val_acc: 0.9400
# Epoch 76/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1538 - sensitivity: 0.8220 - specificity: 0.9591 - acc: 0.9317Epoch 00076: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.1532 - sensitivity: 0.8251 - specificity: 0.9590 - acc: 0.9322 - val_loss: 0.1318 - val_sensitivity: 0.5573 - val_specificity: 0.9701 - val_acc: 0.9406
# Epoch 77/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1534 - sensitivity: 0.7994 - specificity: 0.9661 - acc: 0.9321Epoch 00077: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1536 - sensitivity: 0.7960 - specificity: 0.9658 - acc: 0.9312 - val_loss: 0.1354 - val_sensitivity: 0.6242 - val_specificity: 0.9643 - val_acc: 0.9400
# Epoch 78/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1630 - sensitivity: 0.8178 - specificity: 0.9591 - acc: 0.9303Epoch 00078: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1609 - sensitivity: 0.8210 - specificity: 0.9598 - acc: 0.9315 - val_loss: 0.1344 - val_sensitivity: 0.6193 - val_specificity: 0.9695 - val_acc: 0.9441
# Epoch 79/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1493 - sensitivity: 0.8318 - specificity: 0.9621 - acc: 0.9342Epoch 00079: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1497 - sensitivity: 0.8293 - specificity: 0.9627 - acc: 0.9340 - val_loss: 0.1338 - val_sensitivity: 0.6416 - val_specificity: 0.9656 - val_acc: 0.9400
# Epoch 80/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1522 - sensitivity: 0.8224 - specificity: 0.9603 - acc: 0.9339Epoch 00080: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1515 - sensitivity: 0.8233 - specificity: 0.9602 - acc: 0.9340 - val_loss: 0.1480 - val_sensitivity: 0.6356 - val_specificity: 0.9543 - val_acc: 0.9319
# Epoch 81/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1393 - sensitivity: 0.8292 - specificity: 0.9661 - acc: 0.9386Epoch 00081: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1408 - sensitivity: 0.8234 - specificity: 0.9662 - acc: 0.9375 - val_loss: 0.1400 - val_sensitivity: 0.6192 - val_specificity: 0.9606 - val_acc: 0.9354
# Epoch 82/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1581 - sensitivity: 0.8147 - specificity: 0.9618 - acc: 0.9304Epoch 00082: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1573 - sensitivity: 0.8144 - specificity: 0.9617 - acc: 0.9305 - val_loss: 0.1344 - val_sensitivity: 0.5990 - val_specificity: 0.9625 - val_acc: 0.9359
# Epoch 83/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1532 - sensitivity: 0.8204 - specificity: 0.9633 - acc: 0.9291Epoch 00083: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1536 - sensitivity: 0.8193 - specificity: 0.9624 - acc: 0.9286 - val_loss: 0.1385 - val_sensitivity: 0.6150 - val_specificity: 0.9662 - val_acc: 0.9406
# Epoch 84/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1438 - sensitivity: 0.8408 - specificity: 0.9668 - acc: 0.9392Epoch 00084: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1424 - sensitivity: 0.8436 - specificity: 0.9674 - acc: 0.9403 - val_loss: 0.1299 - val_sensitivity: 0.6354 - val_specificity: 0.9699 - val_acc: 0.9429
# Epoch 85/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1552 - sensitivity: 0.8212 - specificity: 0.9604 - acc: 0.9300Epoch 00085: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1555 - sensitivity: 0.8199 - specificity: 0.9606 - acc: 0.9298 - val_loss: 0.1383 - val_sensitivity: 0.5995 - val_specificity: 0.9708 - val_acc: 0.9418
# Epoch 86/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1363 - sensitivity: 0.8443 - specificity: 0.9676 - acc: 0.9421Epoch 00086: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1351 - sensitivity: 0.8470 - specificity: 0.9678 - acc: 0.9428 - val_loss: 0.1327 - val_sensitivity: 0.6113 - val_specificity: 0.9701 - val_acc: 0.9423
# Epoch 87/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1373 - sensitivity: 0.8507 - specificity: 0.9690 - acc: 0.9439Epoch 00087: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1381 - sensitivity: 0.8480 - specificity: 0.9691 - acc: 0.9431 - val_loss: 0.1295 - val_sensitivity: 0.5964 - val_specificity: 0.9725 - val_acc: 0.9441
# Epoch 88/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1506 - sensitivity: 0.8279 - specificity: 0.9666 - acc: 0.9375Epoch 00088: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1502 - sensitivity: 0.8294 - specificity: 0.9667 - acc: 0.9379 - val_loss: 0.1341 - val_sensitivity: 0.6093 - val_specificity: 0.9688 - val_acc: 0.9423
# Epoch 89/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1357 - sensitivity: 0.8502 - specificity: 0.9628 - acc: 0.9392Epoch 00089: val_loss improved from 0.12808 to 0.12799, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.1354 - sensitivity: 0.8514 - specificity: 0.9635 - acc: 0.9399 - val_loss: 0.1280 - val_sensitivity: 0.4970 - val_specificity: 0.9803 - val_acc: 0.9464
# Epoch 90/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1406 - sensitivity: 0.8336 - specificity: 0.9651 - acc: 0.9395Epoch 00090: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1405 - sensitivity: 0.8317 - specificity: 0.9649 - acc: 0.9392 - val_loss: 0.1376 - val_sensitivity: 0.5918 - val_specificity: 0.9709 - val_acc: 0.9418
# Epoch 91/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1334 - sensitivity: 0.8421 - specificity: 0.9736 - acc: 0.9453Epoch 00091: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1322 - sensitivity: 0.8433 - specificity: 0.9736 - acc: 0.9456 - val_loss: 0.1383 - val_sensitivity: 0.6020 - val_specificity: 0.9670 - val_acc: 0.9394
# Epoch 92/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1402 - sensitivity: 0.8188 - specificity: 0.9630 - acc: 0.9329Epoch 00092: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1416 - sensitivity: 0.8172 - specificity: 0.9628 - acc: 0.9323 - val_loss: 0.1323 - val_sensitivity: 0.5972 - val_specificity: 0.9701 - val_acc: 0.9418
# Epoch 93/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1334 - sensitivity: 0.8422 - specificity: 0.9690 - acc: 0.9432Epoch 00093: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1356 - sensitivity: 0.8400 - specificity: 0.9686 - acc: 0.9421 - val_loss: 0.1326 - val_sensitivity: 0.5190 - val_specificity: 0.9790 - val_acc: 0.9447
# Epoch 94/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1400 - sensitivity: 0.8468 - specificity: 0.9682 - acc: 0.9410Epoch 00094: val_loss improved from 0.12799 to 0.12710, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight_raw.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1423 - sensitivity: 0.8414 - specificity: 0.9683 - acc: 0.9396 - val_loss: 0.1271 - val_sensitivity: 0.5105 - val_specificity: 0.9835 - val_acc: 0.9476
# Epoch 95/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1306 - sensitivity: 0.8356 - specificity: 0.9684 - acc: 0.9421Epoch 00095: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1305 - sensitivity: 0.8385 - specificity: 0.9685 - acc: 0.9428 - val_loss: 0.1363 - val_sensitivity: 0.6299 - val_specificity: 0.9707 - val_acc: 0.9441
# Epoch 96/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1313 - sensitivity: 0.8432 - specificity: 0.9716 - acc: 0.9457Epoch 00096: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1317 - sensitivity: 0.8401 - specificity: 0.9713 - acc: 0.9453 - val_loss: 0.1317 - val_sensitivity: 0.6153 - val_specificity: 0.9745 - val_acc: 0.9453
# Epoch 97/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1324 - sensitivity: 0.8308 - specificity: 0.9719 - acc: 0.9414Epoch 00097: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1329 - sensitivity: 0.8321 - specificity: 0.9715 - acc: 0.9414 - val_loss: 0.1378 - val_sensitivity: 0.5989 - val_specificity: 0.9720 - val_acc: 0.9435
# Epoch 98/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1288 - sensitivity: 0.8357 - specificity: 0.9687 - acc: 0.9424Epoch 00098: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1287 - sensitivity: 0.8386 - specificity: 0.9680 - acc: 0.9424 - val_loss: 0.1332 - val_sensitivity: 0.5710 - val_specificity: 0.9718 - val_acc: 0.9441
# Epoch 99/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1375 - sensitivity: 0.8240 - specificity: 0.9677 - acc: 0.9421Epoch 00099: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1399 - sensitivity: 0.8209 - specificity: 0.9665 - acc: 0.9403 - val_loss: 0.1316 - val_sensitivity: 0.5583 - val_specificity: 0.9756 - val_acc: 0.9458
# Epoch 100/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1238 - sensitivity: 0.8650 - specificity: 0.9671 - acc: 0.9449Epoch 00100: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1239 - sensitivity: 0.8625 - specificity: 0.9677 - acc: 0.9448 - val_loss: 0.1361 - val_sensitivity: 0.5293 - val_specificity: 0.9764 - val_acc: 0.9429
# Epoch 101/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1313 - sensitivity: 0.8568 - specificity: 0.9686 - acc: 0.9446Epoch 00101: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1313 - sensitivity: 0.8546 - specificity: 0.9692 - acc: 0.9441 - val_loss: 0.1379 - val_sensitivity: 0.4489 - val_specificity: 0.9829 - val_acc: 0.9429
# Epoch 102/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1306 - sensitivity: 0.8243 - specificity: 0.9686 - acc: 0.9414Epoch 00102: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1296 - sensitivity: 0.8255 - specificity: 0.9687 - acc: 0.9417 - val_loss: 0.1277 - val_sensitivity: 0.5183 - val_specificity: 0.9835 - val_acc: 0.9487
# Epoch 103/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1323 - sensitivity: 0.8377 - specificity: 0.9720 - acc: 0.9439Epoch 00103: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1320 - sensitivity: 0.8380 - specificity: 0.9721 - acc: 0.9442 - val_loss: 0.1322 - val_sensitivity: 0.5998 - val_specificity: 0.9745 - val_acc: 0.9458
# Epoch 104/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1283 - sensitivity: 0.8563 - specificity: 0.9721 - acc: 0.9468Epoch 00104: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1279 - sensitivity: 0.8553 - specificity: 0.9725 - acc: 0.9470 - val_loss: 0.1386 - val_sensitivity: 0.6370 - val_specificity: 0.9645 - val_acc: 0.9394
# Epoch 105/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1270 - sensitivity: 0.8433 - specificity: 0.9726 - acc: 0.9449Epoch 00105: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1281 - sensitivity: 0.8420 - specificity: 0.9731 - acc: 0.9448 - val_loss: 0.1378 - val_sensitivity: 0.5901 - val_specificity: 0.9643 - val_acc: 0.9371
# Epoch 106/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1154 - sensitivity: 0.8581 - specificity: 0.9760 - acc: 0.9529Epoch 00106: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1150 - sensitivity: 0.8588 - specificity: 0.9764 - acc: 0.9533 - val_loss: 0.1367 - val_sensitivity: 0.4998 - val_specificity: 0.9771 - val_acc: 0.9435
# Epoch 107/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1201 - sensitivity: 0.8575 - specificity: 0.9700 - acc: 0.9456Epoch 00107: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1197 - sensitivity: 0.8577 - specificity: 0.9701 - acc: 0.9459 - val_loss: 0.1356 - val_sensitivity: 0.6185 - val_specificity: 0.9734 - val_acc: 0.9441
# Epoch 108/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1148 - sensitivity: 0.8571 - specificity: 0.9721 - acc: 0.9486Epoch 00108: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1165 - sensitivity: 0.8566 - specificity: 0.9717 - acc: 0.9481 - val_loss: 0.1341 - val_sensitivity: 0.5833 - val_specificity: 0.9764 - val_acc: 0.9464
# Epoch 109/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1269 - sensitivity: 0.8488 - specificity: 0.9719 - acc: 0.9446Epoch 00109: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1268 - sensitivity: 0.8471 - specificity: 0.9719 - acc: 0.9442 - val_loss: 0.1421 - val_sensitivity: 0.6008 - val_specificity: 0.9693 - val_acc: 0.9412
# Epoch 110/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1227 - sensitivity: 0.8646 - specificity: 0.9690 - acc: 0.9478Epoch 00110: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1248 - sensitivity: 0.8620 - specificity: 0.9684 - acc: 0.9470 - val_loss: 0.1327 - val_sensitivity: 0.5746 - val_specificity: 0.9742 - val_acc: 0.9441
# Epoch 111/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1208 - sensitivity: 0.8610 - specificity: 0.9732 - acc: 0.9496Epoch 00111: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1200 - sensitivity: 0.8612 - specificity: 0.9733 - acc: 0.9498 - val_loss: 0.1352 - val_sensitivity: 0.6664 - val_specificity: 0.9680 - val_acc: 0.9435
# Epoch 112/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1227 - sensitivity: 0.8379 - specificity: 0.9734 - acc: 0.9442Epoch 00112: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1226 - sensitivity: 0.8381 - specificity: 0.9734 - acc: 0.9441 - val_loss: 0.1356 - val_sensitivity: 0.5935 - val_specificity: 0.9758 - val_acc: 0.9464
# Epoch 113/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1087 - sensitivity: 0.8725 - specificity: 0.9725 - acc: 0.9535Epoch 00113: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1085 - sensitivity: 0.8733 - specificity: 0.9725 - acc: 0.9536 - val_loss: 0.1457 - val_sensitivity: 0.6489 - val_specificity: 0.9605 - val_acc: 0.9377
# Epoch 114/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1181 - sensitivity: 0.8592 - specificity: 0.9684 - acc: 0.9461Epoch 00114: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1189 - sensitivity: 0.8617 - specificity: 0.9675 - acc: 0.9456 - val_loss: 0.1448 - val_sensitivity: 0.6105 - val_specificity: 0.9637 - val_acc: 0.9371
# Epoch 115/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1155 - sensitivity: 0.8578 - specificity: 0.9763 - acc: 0.9504Epoch 00115: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1155 - sensitivity: 0.8602 - specificity: 0.9759 - acc: 0.9505 - val_loss: 0.1435 - val_sensitivity: 0.6127 - val_specificity: 0.9682 - val_acc: 0.9429
# Epoch 116/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1219 - sensitivity: 0.8579 - specificity: 0.9717 - acc: 0.9486Epoch 00116: val_loss did not improve
# 57/57 [==============================] - 49s 866ms/step - loss: 0.1203 - sensitivity: 0.8604 - specificity: 0.9722 - acc: 0.9495 - val_loss: 0.1365 - val_sensitivity: 0.4058 - val_specificity: 0.9765 - val_acc: 0.9441
# Epoch 117/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1089 - sensitivity: 0.8844 - specificity: 0.9757 - acc: 0.9557Epoch 00117: val_loss did not improve
# 57/57 [==============================] - 50s 871ms/step - loss: 0.1087 - sensitivity: 0.8814 - specificity: 0.9758 - acc: 0.9554 - val_loss: 0.1419 - val_sensitivity: 0.6593 - val_specificity: 0.9664 - val_acc: 0.9412
# Epoch 118/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1071 - sensitivity: 0.8814 - specificity: 0.9763 - acc: 0.9567Epoch 00118: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1076 - sensitivity: 0.8817 - specificity: 0.9754 - acc: 0.9561 - val_loss: 0.1466 - val_sensitivity: 0.7071 - val_specificity: 0.9611 - val_acc: 0.9412
# Epoch 119/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1103 - sensitivity: 0.8762 - specificity: 0.9706 - acc: 0.9503Epoch 00119: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1105 - sensitivity: 0.8733 - specificity: 0.9707 - acc: 0.9501 - val_loss: 0.1439 - val_sensitivity: 0.6795 - val_specificity: 0.9644 - val_acc: 0.9418
# Epoch 120/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1131 - sensitivity: 0.8638 - specificity: 0.9761 - acc: 0.9538Epoch 00120: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1139 - sensitivity: 0.8613 - specificity: 0.9760 - acc: 0.9529 - val_loss: 0.1426 - val_sensitivity: 0.6673 - val_specificity: 0.9650 - val_acc: 0.9418
# Epoch 121/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.0987 - sensitivity: 0.9029 - specificity: 0.9733 - acc: 0.9568Epoch 00121: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.0991 - sensitivity: 0.9019 - specificity: 0.9738 - acc: 0.9568 - val_loss: 0.1408 - val_sensitivity: 0.6373 - val_specificity: 0.9682 - val_acc: 0.9423
# Epoch 122/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1033 - sensitivity: 0.8934 - specificity: 0.9755 - acc: 0.9578Epoch 00122: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1037 - sensitivity: 0.8916 - specificity: 0.9759 - acc: 0.9575 - val_loss: 0.1450 - val_sensitivity: 0.5906 - val_specificity: 0.9661 - val_acc: 0.9383
# Epoch 123/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1031 - sensitivity: 0.8809 - specificity: 0.9793 - acc: 0.9603Epoch 00123: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1029 - sensitivity: 0.8831 - specificity: 0.9796 - acc: 0.9610 - val_loss: 0.1371 - val_sensitivity: 0.5792 - val_specificity: 0.9758 - val_acc: 0.9453
# Epoch 124/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1089 - sensitivity: 0.8658 - specificity: 0.9733 - acc: 0.9507Epoch 00124: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1080 - sensitivity: 0.8682 - specificity: 0.9734 - acc: 0.9512 - val_loss: 0.1374 - val_sensitivity: 0.6035 - val_specificity: 0.9733 - val_acc: 0.9441
# CPU times: user 2h 41min 32s, sys: 24min 21s, total: 3h 5min 53s
# Wall time: 1h 43min 26s

# %% [raw]
# model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid) #gen_flow_val,  #(X_valid, Y_valid),
#                     steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
#                     #validation_steps=int(np.ceil(len(X_valid)/batch_size)),
#                     epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
#                     class_weight = class_weight)
#                     #class_weights = class_weight

# %% [markdown]
# ## IV. Visualize  TSNE

# %%
# %matplotlib inline
import numpy as np
# visualize the points' distribution of train data using features built from base_model
import matplotlib.pyplot as plt
# dimension reduction
from sklearn.manifold import TSNE 
import numpy as np

def t_sne_vis(name, base_model, x_processed_images, random_state, labels,perplexity = 30):
    """
    :param name: the name of the cnn model used to build features
    :param base_model: the model obj
    :param x_processed_images: the input images for our model
    :param random_state: for fixing the results
    :param labels: 0/1 classification labels
    :return:
    the graph of image distribution based on features extracted from the model and the t-sne features
    """
    # convert data to images
    print('Converting data points to composite image')
    X_train = x_processed_images
    print('we got %d different images of shape %dx%d ' % (len(X_train), X_train.shape[1], X_train.shape[1]))
    print('build usefull features from the selected model')
    features = base_model.predict(X_train)
    x_data1 = np.asarray(features).astype('float64')
    x_data1 = x_data1.reshape((x_data1.shape[0], -1))
    # perform t-SNE embedding
    print('performing t-sne reduction')
    vis_data = TSNE(perplexity=perplexity, random_state=random_state).fit_transform(x_data1)
    # plot the result
    fig = plt.figure(figsize=(15, 15))
    vis_x = vis_data[:, 0]
    vis_y = vis_data[:, 1]
    plt.scatter(vis_x, vis_y, c=labels, cmap=plt.cm.get_cmap("winter", 2))
    plt.colorbar(ticks=range(2))
    plt.clim(0, 1)
    plt.title(name)
    plt.grid()
    plt.show()
    fig.savefig('tsne_vis_'+name+'.png')
    return vis_data

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1)            2623489     avg_pool[0][0]
# ==================================================================================================
# Total params: 26,211,201
# Trainable params: 26,158,081
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
name = 'Resnet'
print('visualizing for %s' %name)
base_model_ = Model(input=model.input, output=model.get_layer('avg_pool').output)
tsne_feats = t_sne_vis(name, base_model_, X_valid, np.random.RandomState(42), Y_valid,perplexity=30)
# Out:
# visualizing for Resnet
# Converting data points to composite image
# we got 1717 different images of shape 299x299
# build usefull features from the selected model
# /home/dvp_tran/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("av..., inputs=Tensor("in...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# performing t-sne reduction

# %% [markdown]
# ## V. Evaluate Model

# %%
model = load_model(weights_path+"BestKerasResnet50_flat_3_loss_no_weight_raw.h5", custom_objects={'sensitivity': sensitivity,
                                                                             "specificity":specificity})
score = model.evaluate(X_valid, Y_valid, verbose=1)
print('Test loss:', score[0])
print('Test sensitivity:', score[1])
print('Test specificity:', score[2])
print('Test acc:', score[3])
# Out:
# 1717/1717 [==============================] - 10s 6ms/step
# ('Test loss:', 0.12710283647617351)
# ('Test sensitivity:', 0.52138001924347033)
# ('Test specificity:', 0.98349518239949429)
# ('Test acc:', 0.94758299359347697)

# %%
#compute metrics
pred = model.predict(X_valid)
average_precision = average_precision_score(Y_valid, pred)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.71

# %%
precision, recall, _ = precision_recall_curve(Y_valid, pred)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
# Out:
# Text(0.5,1,u'2-class Precision-Recall curve: AP=0.71')

# %%
def generate_results(y_test, y_score):
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.show()
    print('AUC: %f' % roc_auc)

# %%
generate_results
# Out:
# <function __main__.generate_results>

# %% [markdown]
# #compute log loss
# pred = model.predict(X_valid)
# log_loss(Y_valid,pred)

# %% [markdown]
# ## VI. Retrain on full dataset

# %% [raw]
# #Generate the training data
# #Create 3 bands having HH, HV and avg of both
# X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
# X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
# X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],
#                           ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)

# %% [raw]
# #parse corrupted notebook file
# t = ["#Generate the training data\n",
#     "#Create 3 bands having HH, HV and avg of both\n",
#     "X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_1\"]])\n",
#     "X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_2\"]])\n",
#     "X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],\n",
#     "                          ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)"]
# #t.remove("\n")
# t=[x.replace("\n",'') for x in t]
# for x in t:
#     print(x)
