# %% [markdown]
# # Skin Cancer Classification Challenge

# %% [markdown]
# **Summary : ** skin cancer.

# %% [markdown]
# ## Preliminaries and Imports

# %%
#general & system\n",
import os

#data processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 10, 10  #default setting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#data augmentation
from PIL import Image
from random import choice
import cv2
import numpy as np
#import keras.preprocessing.image as prep

#ML part
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing import image as kimage
from keras.models import Sequential
from keras.layers import GlobalMaxPooling2D, Dense, BatchNormalization, GlobalAveragePooling2D,Dropout,Activation,Flatten
from keras.models import Model
from keras.optimizers import SGD
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

#validation
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc,classification_report,roc_auc_score


from sklearn.metrics import precision_recall_curve
from imblearn.over_sampling import SMOTE
from sklearn.utils import resample

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## I. Load Data

# %% [markdown]
# - **Rq : ** Datasets are quite light, can be fully loaded in a laptop memory with ease.

# %%
# %%time
meta = pd.read_csv("../data/label_learn.csv", sep = ";")
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 5.8 ms

# %%
meta.head()
# Out:
#           name      label
# 0  0000000.jpg     benign
# 1  0000002.jpg  malignant
# 2  0000006.jpg     benign
# 3  0000008.jpg     benign
# 4  0000009.jpg     benign

# %%
# %%time
train_list = os.listdir("../data/resized_train2/")
len(train_list) == len(meta.name)
# Out:
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 3.73 ms

# %%
train_list.sort() == list(meta.name).sort()
# Out:
# True

# %%
# %%time
X_train = np.array([np.array(Image.open("../data/resized_train2/"+fname)) for fname in meta.name])
Y_train = [1 if x=="malignant" else 0 for x in meta.label]
Y_train = np.array(Y_train)
# Out:
# CPU times: user 12.7 s, sys: 1.51 s, total: 14.2 s
# Wall time: 14.2 s

# %%
print(X_train.shape)
print(len(Y_train))
X_train.shape[0] == len(meta.name) == len(Y_train)
# Out:
# (8581, 299, 299, 3)
# 8581
# True

# %%
#control
print(meta.name[0:5])
print(Y_train[0:5])
print(meta.label[0:5])
# Out:
# 0    0000000.jpg
# 1    0000002.jpg
# 2    0000006.jpg
# 3    0000008.jpg
# 4    0000009.jpg
# Name: name, dtype: object
# [0 1 0 0 0]
# 0       benign
# 1    malignant
# 2       benign
# 3       benign
# 4       benign
# Name: label, dtype: object

# %% [markdown]
# ## II. Data Preparation

# %% [markdown]
# - **Class weights**

# %%
class_weight_or = class_weight.compute_class_weight('balanced', np.unique(Y_train), Y_train)

# %% [markdown]
# - **Data splitting**

# %%
#data splitting
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train, Y_train, random_state=42, train_size=0.80)
# Out:
# /home/dvp_tran/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# - **Resampling**

# %%
temp = sum(Y_train)
sample_size = temp*2700/(374+254)  #1372
sample_size
# Out:
# 2325

# %%
def random_undersampling(X, Y,sample_size = sample_size, n_sample=1):
    """
    X,y : numpy arrays
    return :
    5 random ensemble of indices general_balenced_set:
        general_balenced_set[0] = the shuffeled indices that inssure the class balance
    """
    indices = np.array(range(len(Y)))
    positive_samples = indices[Y==1]
    #print(type(positive_samples))
    negative_samples = indices[Y==0]
    #print(type(negative_samples))
    general_balenced_set = []
    for k in range(n_sample):
        indices_ = np.random.choice(negative_samples, sample_size, replace=False)
        #print(len(indices_))
        # append positive and negative
        balenced_set = np.append(indices_, positive_samples)
        #print(len(balenced_set))
        # shuffle indices
        np.random.shuffle(balenced_set)
        #print(len(balenced_set))
        general_balenced_set.append(balenced_set)
    return general_balenced_set

# %%
general_balenced_set = random_undersampling(X_train,Y_train)
X_train = X_train[general_balenced_set]
Y_train = Y_train[general_balenced_set]

# %% [markdown]
# ## III. Deep Learning with Transfer Learning

# %%
weights_path = '../model/checkpoints/'

if not os.path.exists(weights_path):
    os.makedirs(weights_path)
    
epochs = 500
batch_size = 50

# %% [markdown]
# - **Using RESNET : **

# %%
#load base model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(299,299,3))
base_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
#adding top layers
    #sequentialy
add_model = Sequential()
add_model.add(GlobalAveragePooling2D(input_shape=base_model.output_shape[1:])) #Flatten/GlobalAveragePooling2D
add_model.add(Dense(1024, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(512, activation='relu'))
add_model.add(Dropout(0.25))
add_model.add(Dense(1, activation='sigmoid'))

model = Model(inputs=base_model.input, outputs=add_model(base_model.output))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1)            2623489     avg_pool[0][0]
# ==================================================================================================
# Total params: 26,211,201
# Trainable params: 26,158,081
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [raw]
# #adding top layers
#     #need to check api to add layers sequentialy
# x = base_model.output
# x = GlobalAveragePooling2D()(x) #Flatten instead?
# x = Dense(1024, activation='relu')(x)
# x = Dropout(0.25)(x)
# x = Dense(512, activation='relu')(x)
# x = Dropout(0.25)(x)
# predictions = Dense(1, activation='sigmoid')(x)
#
# model = Model(inputs=base_model.input, outputs=predictions)
# model.summary()

# %%
from keras import backend as K

def weighted_categorical_crossentropy(weights):
    """
    [w_0, w_1] : weight of 0 class and weight of 1 class
    """
    weights = K.variable(weights)

    def loss(y_true, y_pred):
        # scale predictions so that the class probas of each sample sum to 1
        #y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
        # clip to prevent NaN's and Inf's
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        # calc
        loss = y_true * K.log(y_pred) * weights[1] + (1 - y_true) * K.log(1 - y_pred) * weights[0]
        loss = -K.sum(loss, -1)
        return loss

    return loss

# %%
class_weight_or
# Out:
# array([ 0.54296381,  6.31885125])

# %%
loss1 = weighted_categorical_crossentropy(class_weight_or) #(np.array([0.8,4]))

# %%
#freeze lower layers of the model
#for layer in model.layers[:]:
    #layer.trainable = False
for layer in model.layers[0:]:
    layer.trainable = True
    

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())




#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss="binary_crossentropy", #binary_crossentropy
              metrics=[sensitivity, specificity,"accuracy"])

# %%
# %%time
#Lets define the image transormations that we wan

gen = ImageDataGenerator(horizontal_flip=True,
                         vertical_flip=True,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         zoom_range=0.2,
                         rotation_range=40)

val_datagen = ImageDataGenerator()
# Here is the function that merges our two generators
# We use the exact same generator with the same random seed for both the y and angle arrays
def gen_flow_for_one_input(X1, y):
    genX1 = gen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]

def val_datagen_(X1, y):
    genX1 = val_datagen.flow(X1, y, batch_size=batch_size, seed=42)
    while True:
        X1i = genX1.next()
        yield X1i[0], X1i[1]
#Finally create out generator
gen_flow_train = gen_flow_for_one_input(X_train, Y_train)
#gen_flow_val = gen_flow_for_one_input(X_valid, Y_valid)
gen_flow_val = val_datagen_(X_valid, Y_valid)

from keras.callbacks import EarlyStopping, ModelCheckpoint
epochs_to_wait_for_improve = 30
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=epochs_to_wait_for_improve)
checkpoint_callback = ModelCheckpoint(weights_path + 'BestKerasResnet50_flat_3_loss_no_weight_image2.h5', monitor='val_loss',
                                      verbose=1, save_best_only=True, mode='min')
#fit the model
model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid),
                    steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
                    epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
                    class_weight = class_weight_or)
# Out:
# Epoch 1/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.5942 - sensitivity: 0.2714 - specificity: 0.7684 - acc: 0.6800Epoch 00001: val_loss improved from inf to 0.35936, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 76s 1s/step - loss: 0.5921 - sensitivity: 0.2666 - specificity: 0.7725 - acc: 0.6828 - val_loss: 0.3594 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - val_acc: 0.9196
# Epoch 2/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3968 - sensitivity: 0.0851 - specificity: 0.9908 - acc: 0.8199Epoch 00002: val_loss improved from 0.35936 to 0.30845, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 902ms/step - loss: 0.3960 - sensitivity: 0.0861 - specificity: 0.9905 - acc: 0.8206 - val_loss: 0.3084 - val_sensitivity: 0.0427 - val_specificity: 0.9954 - val_acc: 0.9179
# Epoch 3/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3577 - sensitivity: 0.2810 - specificity: 0.9746 - acc: 0.8405Epoch 00003: val_loss improved from 0.30845 to 0.26479, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.3604 - sensitivity: 0.2785 - specificity: 0.9751 - acc: 0.8391 - val_loss: 0.2648 - val_sensitivity: 0.2086 - val_specificity: 0.9878 - val_acc: 0.9225
# Epoch 4/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.3196 - sensitivity: 0.3456 - specificity: 0.9721 - acc: 0.8511Epoch 00004: val_loss improved from 0.26479 to 0.23816, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.3222 - sensitivity: 0.3419 - specificity: 0.9716 - acc: 0.8487 - val_loss: 0.2382 - val_sensitivity: 0.3312 - val_specificity: 0.9815 - val_acc: 0.9301
# Epoch 5/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2990 - sensitivity: 0.4381 - specificity: 0.9624 - acc: 0.8595Epoch 00005: val_loss improved from 0.23816 to 0.22605, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.3020 - sensitivity: 0.4345 - specificity: 0.9621 - acc: 0.8578 - val_loss: 0.2260 - val_sensitivity: 0.4205 - val_specificity: 0.9666 - val_acc: 0.9243
# Epoch 6/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2804 - sensitivity: 0.5136 - specificity: 0.9625 - acc: 0.8760Epoch 00006: val_loss improved from 0.22605 to 0.20939, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2812 - sensitivity: 0.5143 - specificity: 0.9614 - acc: 0.8754 - val_loss: 0.2094 - val_sensitivity: 0.4822 - val_specificity: 0.9564 - val_acc: 0.9202
# Epoch 7/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2773 - sensitivity: 0.5554 - specificity: 0.9532 - acc: 0.8750Epoch 00007: val_loss improved from 0.20939 to 0.20386, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2782 - sensitivity: 0.5568 - specificity: 0.9535 - acc: 0.8754 - val_loss: 0.2039 - val_sensitivity: 0.5336 - val_specificity: 0.9534 - val_acc: 0.9214
# Epoch 8/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2658 - sensitivity: 0.5716 - specificity: 0.9513 - acc: 0.8766Epoch 00008: val_loss improved from 0.20386 to 0.19519, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.2676 - sensitivity: 0.5697 - specificity: 0.9504 - acc: 0.8753 - val_loss: 0.1952 - val_sensitivity: 0.5695 - val_specificity: 0.9558 - val_acc: 0.9260
# Epoch 9/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2525 - sensitivity: 0.5965 - specificity: 0.9491 - acc: 0.8821Epoch 00009: val_loss improved from 0.19519 to 0.18084, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2540 - sensitivity: 0.5935 - specificity: 0.9484 - acc: 0.8814 - val_loss: 0.1808 - val_sensitivity: 0.5621 - val_specificity: 0.9608 - val_acc: 0.9301
# Epoch 10/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2487 - sensitivity: 0.6365 - specificity: 0.9473 - acc: 0.8860Epoch 00010: val_loss improved from 0.18084 to 0.17526, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2482 - sensitivity: 0.6384 - specificity: 0.9473 - acc: 0.8863 - val_loss: 0.1753 - val_sensitivity: 0.4861 - val_specificity: 0.9623 - val_acc: 0.9243
# Epoch 11/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2355 - sensitivity: 0.6758 - specificity: 0.9491 - acc: 0.8936Epoch 00011: val_loss improved from 0.17526 to 0.17187, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 902ms/step - loss: 0.2350 - sensitivity: 0.6779 - specificity: 0.9484 - acc: 0.8937 - val_loss: 0.1719 - val_sensitivity: 0.4422 - val_specificity: 0.9667 - val_acc: 0.9266
# Epoch 12/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2319 - sensitivity: 0.6567 - specificity: 0.9490 - acc: 0.8907Epoch 00012: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2347 - sensitivity: 0.6521 - specificity: 0.9490 - acc: 0.8898 - val_loss: 0.1745 - val_sensitivity: 0.6071 - val_specificity: 0.9560 - val_acc: 0.9295
# Epoch 13/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2408 - sensitivity: 0.6694 - specificity: 0.9439 - acc: 0.8880Epoch 00013: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2403 - sensitivity: 0.6689 - specificity: 0.9445 - acc: 0.8882 - val_loss: 0.1727 - val_sensitivity: 0.5894 - val_specificity: 0.9554 - val_acc: 0.9272
# Epoch 14/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2286 - sensitivity: 0.7390 - specificity: 0.9441 - acc: 0.9024Epoch 00014: val_loss improved from 0.17187 to 0.16071, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 902ms/step - loss: 0.2289 - sensitivity: 0.7417 - specificity: 0.9442 - acc: 0.9031 - val_loss: 0.1607 - val_sensitivity: 0.4726 - val_specificity: 0.9687 - val_acc: 0.9295
# Epoch 15/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2274 - sensitivity: 0.6812 - specificity: 0.9480 - acc: 0.8946Epoch 00015: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.2279 - sensitivity: 0.6816 - specificity: 0.9472 - acc: 0.8940 - val_loss: 0.1640 - val_sensitivity: 0.5078 - val_specificity: 0.9634 - val_acc: 0.9284
# Epoch 16/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2220 - sensitivity: 0.6931 - specificity: 0.9477 - acc: 0.8975Epoch 00016: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2235 - sensitivity: 0.6880 - specificity: 0.9469 - acc: 0.8957 - val_loss: 0.1660 - val_sensitivity: 0.5464 - val_specificity: 0.9573 - val_acc: 0.9255
# Epoch 17/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2226 - sensitivity: 0.6871 - specificity: 0.9482 - acc: 0.8988Epoch 00017: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2240 - sensitivity: 0.6875 - specificity: 0.9481 - acc: 0.8985 - val_loss: 0.1640 - val_sensitivity: 0.5464 - val_specificity: 0.9586 - val_acc: 0.9266
# Epoch 18/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2206 - sensitivity: 0.7101 - specificity: 0.9431 - acc: 0.8953Epoch 00018: val_loss improved from 0.16071 to 0.15742, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2197 - sensitivity: 0.7117 - specificity: 0.9434 - acc: 0.8961 - val_loss: 0.1574 - val_sensitivity: 0.4923 - val_specificity: 0.9687 - val_acc: 0.9319
# Epoch 19/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2093 - sensitivity: 0.7394 - specificity: 0.9559 - acc: 0.9110Epoch 00019: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2079 - sensitivity: 0.7381 - specificity: 0.9567 - acc: 0.9119 - val_loss: 0.1585 - val_sensitivity: 0.5877 - val_specificity: 0.9612 - val_acc: 0.9313
# Epoch 20/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2081 - sensitivity: 0.7210 - specificity: 0.9522 - acc: 0.9092Epoch 00020: val_loss improved from 0.15742 to 0.15374, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2092 - sensitivity: 0.7193 - specificity: 0.9525 - acc: 0.9087 - val_loss: 0.1537 - val_sensitivity: 0.5395 - val_specificity: 0.9617 - val_acc: 0.9284
# Epoch 21/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2298 - sensitivity: 0.7225 - specificity: 0.9491 - acc: 0.9014Epoch 00021: val_loss improved from 0.15374 to 0.15200, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 901ms/step - loss: 0.2277 - sensitivity: 0.7274 - specificity: 0.9495 - acc: 0.9028 - val_loss: 0.1520 - val_sensitivity: 0.5446 - val_specificity: 0.9648 - val_acc: 0.9319
# Epoch 22/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2150 - sensitivity: 0.7441 - specificity: 0.9427 - acc: 0.9021Epoch 00022: val_loss improved from 0.15200 to 0.14880, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 898ms/step - loss: 0.2160 - sensitivity: 0.7433 - specificity: 0.9424 - acc: 0.9017 - val_loss: 0.1488 - val_sensitivity: 0.5142 - val_specificity: 0.9669 - val_acc: 0.9313
# Epoch 23/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2126 - sensitivity: 0.7394 - specificity: 0.9543 - acc: 0.9092Epoch 00023: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2131 - sensitivity: 0.7410 - specificity: 0.9535 - acc: 0.9091 - val_loss: 0.1501 - val_sensitivity: 0.4827 - val_specificity: 0.9681 - val_acc: 0.9313
# Epoch 24/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2110 - sensitivity: 0.7430 - specificity: 0.9499 - acc: 0.9042Epoch 00024: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2097 - sensitivity: 0.7430 - specificity: 0.9507 - acc: 0.9052 - val_loss: 0.1492 - val_sensitivity: 0.4552 - val_specificity: 0.9720 - val_acc: 0.9324
# Epoch 25/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2058 - sensitivity: 0.7483 - specificity: 0.9481 - acc: 0.9086Epoch 00025: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2045 - sensitivity: 0.7527 - specificity: 0.9485 - acc: 0.9098 - val_loss: 0.1494 - val_sensitivity: 0.4736 - val_specificity: 0.9713 - val_acc: 0.9324
# Epoch 26/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2108 - sensitivity: 0.7174 - specificity: 0.9510 - acc: 0.9060Epoch 00026: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2117 - sensitivity: 0.7199 - specificity: 0.9502 - acc: 0.9059 - val_loss: 0.1513 - val_sensitivity: 0.5268 - val_specificity: 0.9644 - val_acc: 0.9307
# Epoch 27/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2089 - sensitivity: 0.7450 - specificity: 0.9519 - acc: 0.9078Epoch 00027: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2073 - sensitivity: 0.7478 - specificity: 0.9523 - acc: 0.9087 - val_loss: 0.1541 - val_sensitivity: 0.6026 - val_specificity: 0.9591 - val_acc: 0.9313
# Epoch 28/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1922 - sensitivity: 0.7739 - specificity: 0.9510 - acc: 0.9160Epoch 00028: val_loss improved from 0.14880 to 0.14649, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.1934 - sensitivity: 0.7726 - specificity: 0.9514 - acc: 0.9161 - val_loss: 0.1465 - val_sensitivity: 0.5227 - val_specificity: 0.9649 - val_acc: 0.9301
# Epoch 29/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2132 - sensitivity: 0.7296 - specificity: 0.9501 - acc: 0.9057Epoch 00029: val_loss improved from 0.14649 to 0.14286, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.2127 - sensitivity: 0.7306 - specificity: 0.9510 - acc: 0.9063 - val_loss: 0.1429 - val_sensitivity: 0.5438 - val_specificity: 0.9674 - val_acc: 0.9342
# Epoch 30/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2026 - sensitivity: 0.7425 - specificity: 0.9541 - acc: 0.9114Epoch 00030: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.2021 - sensitivity: 0.7446 - specificity: 0.9544 - acc: 0.9119 - val_loss: 0.1442 - val_sensitivity: 0.5937 - val_specificity: 0.9612 - val_acc: 0.9330
# Epoch 31/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1871 - sensitivity: 0.7442 - specificity: 0.9535 - acc: 0.9150Epoch 00031: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1877 - sensitivity: 0.7413 - specificity: 0.9538 - acc: 0.9144 - val_loss: 0.1471 - val_sensitivity: 0.6126 - val_specificity: 0.9592 - val_acc: 0.9330
# Epoch 32/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2075 - sensitivity: 0.7665 - specificity: 0.9468 - acc: 0.9096Epoch 00032: val_loss improved from 0.14286 to 0.14251, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.2067 - sensitivity: 0.7658 - specificity: 0.9472 - acc: 0.9098 - val_loss: 0.1425 - val_sensitivity: 0.5278 - val_specificity: 0.9715 - val_acc: 0.9359
# Epoch 33/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1971 - sensitivity: 0.7529 - specificity: 0.9535 - acc: 0.9124Epoch 00033: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1970 - sensitivity: 0.7533 - specificity: 0.9543 - acc: 0.9129 - val_loss: 0.1448 - val_sensitivity: 0.5691 - val_specificity: 0.9675 - val_acc: 0.9365
# Epoch 34/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1991 - sensitivity: 0.7430 - specificity: 0.9483 - acc: 0.9088Epoch 00034: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1984 - sensitivity: 0.7454 - specificity: 0.9484 - acc: 0.9094 - val_loss: 0.1464 - val_sensitivity: 0.5132 - val_specificity: 0.9687 - val_acc: 0.9330
# Epoch 35/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1941 - sensitivity: 0.7440 - specificity: 0.9560 - acc: 0.9114Epoch 00035: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1933 - sensitivity: 0.7437 - specificity: 0.9563 - acc: 0.9115 - val_loss: 0.1471 - val_sensitivity: 0.6035 - val_specificity: 0.9613 - val_acc: 0.9336
# Epoch 36/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1864 - sensitivity: 0.7916 - specificity: 0.9535 - acc: 0.9196Epoch 00036: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1858 - sensitivity: 0.7900 - specificity: 0.9543 - acc: 0.9200 - val_loss: 0.1481 - val_sensitivity: 0.6035 - val_specificity: 0.9620 - val_acc: 0.9342
# Epoch 37/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1986 - sensitivity: 0.7439 - specificity: 0.9532 - acc: 0.9088Epoch 00037: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1981 - sensitivity: 0.7455 - specificity: 0.9528 - acc: 0.9090 - val_loss: 0.1471 - val_sensitivity: 0.6021 - val_specificity: 0.9626 - val_acc: 0.9348
# Epoch 38/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1994 - sensitivity: 0.7321 - specificity: 0.9551 - acc: 0.9103Epoch 00038: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1992 - sensitivity: 0.7334 - specificity: 0.9546 - acc: 0.9101 - val_loss: 0.1462 - val_sensitivity: 0.5904 - val_specificity: 0.9651 - val_acc: 0.9359
# Epoch 39/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1975 - sensitivity: 0.7639 - specificity: 0.9478 - acc: 0.9107Epoch 00039: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1985 - sensitivity: 0.7645 - specificity: 0.9470 - acc: 0.9102 - val_loss: 0.1469 - val_sensitivity: 0.5885 - val_specificity: 0.9625 - val_acc: 0.9330
# Epoch 40/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1853 - sensitivity: 0.7558 - specificity: 0.9586 - acc: 0.9164Epoch 00040: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1855 - sensitivity: 0.7542 - specificity: 0.9585 - acc: 0.9161 - val_loss: 0.1447 - val_sensitivity: 0.5639 - val_specificity: 0.9676 - val_acc: 0.9359
# Epoch 41/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1929 - sensitivity: 0.7416 - specificity: 0.9528 - acc: 0.9157Epoch 00041: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1923 - sensitivity: 0.7438 - specificity: 0.9520 - acc: 0.9154 - val_loss: 0.1425 - val_sensitivity: 0.5610 - val_specificity: 0.9675 - val_acc: 0.9359
# Epoch 42/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.2014 - sensitivity: 0.7443 - specificity: 0.9526 - acc: 0.9089Epoch 00042: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.2012 - sensitivity: 0.7449 - specificity: 0.9530 - acc: 0.9094 - val_loss: 0.1439 - val_sensitivity: 0.5540 - val_specificity: 0.9689 - val_acc: 0.9359
# Epoch 43/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1882 - sensitivity: 0.8022 - specificity: 0.9502 - acc: 0.9179Epoch 00043: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1874 - sensitivity: 0.7986 - specificity: 0.9511 - acc: 0.9179 - val_loss: 0.1465 - val_sensitivity: 0.6045 - val_specificity: 0.9620 - val_acc: 0.9342
# Epoch 44/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1709 - sensitivity: 0.7915 - specificity: 0.9616 - acc: 0.9267Epoch 00044: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1724 - sensitivity: 0.7889 - specificity: 0.9623 - acc: 0.9262 - val_loss: 0.1476 - val_sensitivity: 0.6208 - val_specificity: 0.9620 - val_acc: 0.9359
# Epoch 45/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1860 - sensitivity: 0.7750 - specificity: 0.9521 - acc: 0.9164Epoch 00045: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1871 - sensitivity: 0.7763 - specificity: 0.9509 - acc: 0.9158 - val_loss: 0.1466 - val_sensitivity: 0.6037 - val_specificity: 0.9657 - val_acc: 0.9377
# Epoch 46/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1780 - sensitivity: 0.7765 - specificity: 0.9623 - acc: 0.9253Epoch 00046: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1767 - sensitivity: 0.7803 - specificity: 0.9622 - acc: 0.9259 - val_loss: 0.1451 - val_sensitivity: 0.6103 - val_specificity: 0.9632 - val_acc: 0.9359
# Epoch 47/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1858 - sensitivity: 0.7795 - specificity: 0.9563 - acc: 0.9202Epoch 00047: val_loss improved from 0.14251 to 0.14041, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1855 - sensitivity: 0.7787 - specificity: 0.9566 - acc: 0.9202 - val_loss: 0.1404 - val_sensitivity: 0.5996 - val_specificity: 0.9643 - val_acc: 0.9359
# Epoch 48/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1810 - sensitivity: 0.7677 - specificity: 0.9595 - acc: 0.9217Epoch 00048: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1800 - sensitivity: 0.7701 - specificity: 0.9597 - acc: 0.9224 - val_loss: 0.1431 - val_sensitivity: 0.6176 - val_specificity: 0.9613 - val_acc: 0.9348
# Epoch 49/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1777 - sensitivity: 0.7757 - specificity: 0.9595 - acc: 0.9246Epoch 00049: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1775 - sensitivity: 0.7759 - specificity: 0.9589 - acc: 0.9242 - val_loss: 0.1512 - val_sensitivity: 0.6533 - val_specificity: 0.9595 - val_acc: 0.9365
# Epoch 50/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1937 - sensitivity: 0.7507 - specificity: 0.9565 - acc: 0.9123Epoch 00050: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1925 - sensitivity: 0.7507 - specificity: 0.9564 - acc: 0.9125 - val_loss: 0.1447 - val_sensitivity: 0.6267 - val_specificity: 0.9600 - val_acc: 0.9348
# Epoch 51/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1816 - sensitivity: 0.8048 - specificity: 0.9563 - acc: 0.9239Epoch 00051: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1802 - sensitivity: 0.8060 - specificity: 0.9571 - acc: 0.9249 - val_loss: 0.1415 - val_sensitivity: 0.5862 - val_specificity: 0.9683 - val_acc: 0.9377
# Epoch 52/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1832 - sensitivity: 0.7779 - specificity: 0.9584 - acc: 0.9207Epoch 00052: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1822 - sensitivity: 0.7774 - specificity: 0.9583 - acc: 0.9207 - val_loss: 0.1415 - val_sensitivity: 0.5607 - val_specificity: 0.9701 - val_acc: 0.9377
# Epoch 53/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1690 - sensitivity: 0.8091 - specificity: 0.9584 - acc: 0.9281Epoch 00053: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1702 - sensitivity: 0.8092 - specificity: 0.9587 - acc: 0.9283 - val_loss: 0.1438 - val_sensitivity: 0.5906 - val_specificity: 0.9657 - val_acc: 0.9359
# Epoch 54/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1802 - sensitivity: 0.7611 - specificity: 0.9567 - acc: 0.9171Epoch 00054: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1797 - sensitivity: 0.7583 - specificity: 0.9570 - acc: 0.9168 - val_loss: 0.1441 - val_sensitivity: 0.6095 - val_specificity: 0.9638 - val_acc: 0.9359
# Epoch 55/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1702 - sensitivity: 0.7973 - specificity: 0.9589 - acc: 0.9229Epoch 00055: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1691 - sensitivity: 0.7969 - specificity: 0.9596 - acc: 0.9235 - val_loss: 0.1428 - val_sensitivity: 0.5760 - val_specificity: 0.9676 - val_acc: 0.9371
# Epoch 56/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1746 - sensitivity: 0.7906 - specificity: 0.9597 - acc: 0.9254Epoch 00056: val_loss improved from 0.14041 to 0.13856, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.1742 - sensitivity: 0.7943 - specificity: 0.9588 - acc: 0.9252 - val_loss: 0.1386 - val_sensitivity: 0.5454 - val_specificity: 0.9733 - val_acc: 0.9394
# Epoch 57/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1735 - sensitivity: 0.7934 - specificity: 0.9612 - acc: 0.9242Epoch 00057: val_loss improved from 0.13856 to 0.13806, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 899ms/step - loss: 0.1722 - sensitivity: 0.7934 - specificity: 0.9615 - acc: 0.9248 - val_loss: 0.1381 - val_sensitivity: 0.5396 - val_specificity: 0.9726 - val_acc: 0.9383
# Epoch 58/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1624 - sensitivity: 0.7871 - specificity: 0.9676 - acc: 0.9332Epoch 00058: val_loss did not improve
# 57/57 [==============================] - 49s 868ms/step - loss: 0.1637 - sensitivity: 0.7864 - specificity: 0.9682 - acc: 0.9333 - val_loss: 0.1388 - val_sensitivity: 0.4009 - val_specificity: 0.9718 - val_acc: 0.9400
# Epoch 59/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1792 - sensitivity: 0.7676 - specificity: 0.9565 - acc: 0.9175Epoch 00059: val_loss did not improve
# 57/57 [==============================] - 50s 871ms/step - loss: 0.1771 - sensitivity: 0.7717 - specificity: 0.9573 - acc: 0.9189 - val_loss: 0.1444 - val_sensitivity: 0.6129 - val_specificity: 0.9638 - val_acc: 0.9365
# Epoch 60/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1767 - sensitivity: 0.7858 - specificity: 0.9604 - acc: 0.9238Epoch 00060: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1756 - sensitivity: 0.7877 - specificity: 0.9611 - acc: 0.9248 - val_loss: 0.1468 - val_sensitivity: 0.6161 - val_specificity: 0.9612 - val_acc: 0.9348
# Epoch 61/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1680 - sensitivity: 0.8079 - specificity: 0.9589 - acc: 0.9267Epoch 00061: val_loss improved from 0.13806 to 0.13786, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 902ms/step - loss: 0.1693 - sensitivity: 0.8050 - specificity: 0.9591 - acc: 0.9259 - val_loss: 0.1379 - val_sensitivity: 0.6001 - val_specificity: 0.9726 - val_acc: 0.9435
# Epoch 62/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1593 - sensitivity: 0.7965 - specificity: 0.9620 - acc: 0.9304Epoch 00062: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1580 - sensitivity: 0.8001 - specificity: 0.9622 - acc: 0.9312 - val_loss: 0.1428 - val_sensitivity: 0.6220 - val_specificity: 0.9650 - val_acc: 0.9388
# Epoch 63/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1648 - sensitivity: 0.7791 - specificity: 0.9647 - acc: 0.9275Epoch 00063: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1642 - sensitivity: 0.7830 - specificity: 0.9645 - acc: 0.9280 - val_loss: 0.1424 - val_sensitivity: 0.6191 - val_specificity: 0.9638 - val_acc: 0.9371
# Epoch 64/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1609 - sensitivity: 0.8053 - specificity: 0.9625 - acc: 0.9296Epoch 00064: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1610 - sensitivity: 0.8049 - specificity: 0.9627 - acc: 0.9297 - val_loss: 0.1400 - val_sensitivity: 0.6011 - val_specificity: 0.9694 - val_acc: 0.9406
# Epoch 65/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1555 - sensitivity: 0.8195 - specificity: 0.9643 - acc: 0.9332Epoch 00065: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1564 - sensitivity: 0.8176 - specificity: 0.9637 - acc: 0.9326 - val_loss: 0.1434 - val_sensitivity: 0.6084 - val_specificity: 0.9650 - val_acc: 0.9371
# Epoch 66/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1675 - sensitivity: 0.7909 - specificity: 0.9664 - acc: 0.9300Epoch 00066: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1675 - sensitivity: 0.7914 - specificity: 0.9661 - acc: 0.9298 - val_loss: 0.1423 - val_sensitivity: 0.5797 - val_specificity: 0.9669 - val_acc: 0.9365
# Epoch 67/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1534 - sensitivity: 0.8125 - specificity: 0.9666 - acc: 0.9342Epoch 00067: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1526 - sensitivity: 0.8157 - specificity: 0.9667 - acc: 0.9350 - val_loss: 0.1409 - val_sensitivity: 0.5979 - val_specificity: 0.9689 - val_acc: 0.9394
# Epoch 68/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1735 - sensitivity: 0.8065 - specificity: 0.9629 - acc: 0.9270Epoch 00068: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1722 - sensitivity: 0.8030 - specificity: 0.9635 - acc: 0.9276 - val_loss: 0.1455 - val_sensitivity: 0.6113 - val_specificity: 0.9657 - val_acc: 0.9383
# Epoch 69/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1586 - sensitivity: 0.8114 - specificity: 0.9630 - acc: 0.9317Epoch 00069: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1582 - sensitivity: 0.8147 - specificity: 0.9628 - acc: 0.9322 - val_loss: 0.1387 - val_sensitivity: 0.5865 - val_specificity: 0.9725 - val_acc: 0.9423
# Epoch 70/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1669 - sensitivity: 0.7772 - specificity: 0.9610 - acc: 0.9214Epoch 00070: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1677 - sensitivity: 0.7752 - specificity: 0.9608 - acc: 0.9210 - val_loss: 0.1422 - val_sensitivity: 0.5989 - val_specificity: 0.9693 - val_acc: 0.9400
# Epoch 71/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1590 - sensitivity: 0.8142 - specificity: 0.9589 - acc: 0.9292Epoch 00071: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1599 - sensitivity: 0.8130 - specificity: 0.9584 - acc: 0.9287 - val_loss: 0.1427 - val_sensitivity: 0.5858 - val_specificity: 0.9687 - val_acc: 0.9383
# Epoch 72/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1713 - sensitivity: 0.7836 - specificity: 0.9665 - acc: 0.9285Epoch 00072: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1694 - sensitivity: 0.7875 - specificity: 0.9667 - acc: 0.9294 - val_loss: 0.1454 - val_sensitivity: 0.6089 - val_specificity: 0.9644 - val_acc: 0.9371
# Epoch 73/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1573 - sensitivity: 0.8032 - specificity: 0.9659 - acc: 0.9309Epoch 00073: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1601 - sensitivity: 0.8001 - specificity: 0.9644 - acc: 0.9294 - val_loss: 0.1568 - val_sensitivity: 0.6589 - val_specificity: 0.9536 - val_acc: 0.9319
# Epoch 74/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1602 - sensitivity: 0.8079 - specificity: 0.9653 - acc: 0.9325Epoch 00074: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1601 - sensitivity: 0.8090 - specificity: 0.9647 - acc: 0.9323 - val_loss: 0.1495 - val_sensitivity: 0.6220 - val_specificity: 0.9611 - val_acc: 0.9354
# Epoch 75/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1524 - sensitivity: 0.8216 - specificity: 0.9640 - acc: 0.9346Epoch 00075: val_loss did not improve
# 57/57 [==============================] - 49s 864ms/step - loss: 0.1547 - sensitivity: 0.8204 - specificity: 0.9630 - acc: 0.9336 - val_loss: 0.1431 - val_sensitivity: 0.6098 - val_specificity: 0.9636 - val_acc: 0.9365
# Epoch 76/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1450 - sensitivity: 0.8028 - specificity: 0.9688 - acc: 0.9346Epoch 00076: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1468 - sensitivity: 0.7993 - specificity: 0.9684 - acc: 0.9336 - val_loss: 0.1460 - val_sensitivity: 0.6258 - val_specificity: 0.9612 - val_acc: 0.9359
# Epoch 77/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1592 - sensitivity: 0.8059 - specificity: 0.9654 - acc: 0.9296Epoch 00077: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1581 - sensitivity: 0.8058 - specificity: 0.9660 - acc: 0.9301 - val_loss: 0.1395 - val_sensitivity: 0.5986 - val_specificity: 0.9706 - val_acc: 0.9412
# Epoch 78/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1632 - sensitivity: 0.8047 - specificity: 0.9591 - acc: 0.9274Epoch 00078: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1641 - sensitivity: 0.8055 - specificity: 0.9584 - acc: 0.9269 - val_loss: 0.1392 - val_sensitivity: 0.6081 - val_specificity: 0.9675 - val_acc: 0.9394
# Epoch 79/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1473 - sensitivity: 0.8119 - specificity: 0.9662 - acc: 0.9359Epoch 00079: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1475 - sensitivity: 0.8137 - specificity: 0.9664 - acc: 0.9364 - val_loss: 0.1478 - val_sensitivity: 0.6302 - val_specificity: 0.9606 - val_acc: 0.9354
# Epoch 80/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1535 - sensitivity: 0.7841 - specificity: 0.9683 - acc: 0.9314Epoch 00080: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1527 - sensitivity: 0.7879 - specificity: 0.9688 - acc: 0.9326 - val_loss: 0.1436 - val_sensitivity: 0.6288 - val_specificity: 0.9630 - val_acc: 0.9377
# Epoch 81/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1523 - sensitivity: 0.8159 - specificity: 0.9653 - acc: 0.9336Epoch 00081: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1506 - sensitivity: 0.8191 - specificity: 0.9659 - acc: 0.9347 - val_loss: 0.1434 - val_sensitivity: 0.6183 - val_specificity: 0.9651 - val_acc: 0.9383
# Epoch 82/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1608 - sensitivity: 0.7975 - specificity: 0.9656 - acc: 0.9303Epoch 00082: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1614 - sensitivity: 0.7964 - specificity: 0.9653 - acc: 0.9297 - val_loss: 0.1433 - val_sensitivity: 0.6067 - val_specificity: 0.9694 - val_acc: 0.9412
# Epoch 83/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1456 - sensitivity: 0.8370 - specificity: 0.9670 - acc: 0.9386Epoch 00083: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1471 - sensitivity: 0.8336 - specificity: 0.9671 - acc: 0.9375 - val_loss: 0.1424 - val_sensitivity: 0.6064 - val_specificity: 0.9669 - val_acc: 0.9388
# Epoch 84/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1498 - sensitivity: 0.8175 - specificity: 0.9588 - acc: 0.9287Epoch 00084: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1485 - sensitivity: 0.8209 - specificity: 0.9596 - acc: 0.9300 - val_loss: 0.1420 - val_sensitivity: 0.5928 - val_specificity: 0.9688 - val_acc: 0.9388
# Epoch 85/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1449 - sensitivity: 0.8357 - specificity: 0.9695 - acc: 0.9392Epoch 00085: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1446 - sensitivity: 0.8327 - specificity: 0.9696 - acc: 0.9389 - val_loss: 0.1452 - val_sensitivity: 0.6125 - val_specificity: 0.9637 - val_acc: 0.9365
# Epoch 86/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1513 - sensitivity: 0.8295 - specificity: 0.9671 - acc: 0.9378Epoch 00086: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1506 - sensitivity: 0.8306 - specificity: 0.9672 - acc: 0.9382 - val_loss: 0.1450 - val_sensitivity: 0.5873 - val_specificity: 0.9649 - val_acc: 0.9359
# Epoch 87/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1453 - sensitivity: 0.8252 - specificity: 0.9676 - acc: 0.9375Epoch 00087: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1448 - sensitivity: 0.8232 - specificity: 0.9682 - acc: 0.9379 - val_loss: 0.1426 - val_sensitivity: 0.5651 - val_specificity: 0.9718 - val_acc: 0.9400
# Epoch 88/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1523 - sensitivity: 0.8098 - specificity: 0.9674 - acc: 0.9356Epoch 00088: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1528 - sensitivity: 0.8066 - specificity: 0.9676 - acc: 0.9354 - val_loss: 0.1557 - val_sensitivity: 0.6523 - val_specificity: 0.9549 - val_acc: 0.9324
# Epoch 89/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1395 - sensitivity: 0.8359 - specificity: 0.9674 - acc: 0.9403Epoch 00089: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1391 - sensitivity: 0.8387 - specificity: 0.9671 - acc: 0.9407 - val_loss: 0.1501 - val_sensitivity: 0.6423 - val_specificity: 0.9618 - val_acc: 0.9377
# Epoch 90/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1461 - sensitivity: 0.8159 - specificity: 0.9617 - acc: 0.9328Epoch 00090: val_loss improved from 0.13786 to 0.13471, saving model to ../model/checkpoints/BestKerasResnet50_flat_3_loss_no_weight.h5
# 57/57 [==============================] - 51s 900ms/step - loss: 0.1459 - sensitivity: 0.8159 - specificity: 0.9624 - acc: 0.9333 - val_loss: 0.1347 - val_sensitivity: 0.5824 - val_specificity: 0.9713 - val_acc: 0.9406
# Epoch 91/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1366 - sensitivity: 0.8353 - specificity: 0.9693 - acc: 0.9414Epoch 00091: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1363 - sensitivity: 0.8360 - specificity: 0.9699 - acc: 0.9421 - val_loss: 0.1381 - val_sensitivity: 0.6135 - val_specificity: 0.9699 - val_acc: 0.9423
# Epoch 92/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1451 - sensitivity: 0.8280 - specificity: 0.9660 - acc: 0.9356Epoch 00092: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1447 - sensitivity: 0.8286 - specificity: 0.9657 - acc: 0.9357 - val_loss: 0.1401 - val_sensitivity: 0.5611 - val_specificity: 0.9745 - val_acc: 0.9423
# Epoch 93/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1422 - sensitivity: 0.8464 - specificity: 0.9689 - acc: 0.9428Epoch 00093: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1408 - sensitivity: 0.8465 - specificity: 0.9694 - acc: 0.9435 - val_loss: 0.1399 - val_sensitivity: 0.5996 - val_specificity: 0.9726 - val_acc: 0.9429
# Epoch 94/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1296 - sensitivity: 0.8395 - specificity: 0.9731 - acc: 0.9453Epoch 00094: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1303 - sensitivity: 0.8365 - specificity: 0.9728 - acc: 0.9445 - val_loss: 0.1483 - val_sensitivity: 0.6426 - val_specificity: 0.9639 - val_acc: 0.9394
# Epoch 95/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1462 - sensitivity: 0.8340 - specificity: 0.9703 - acc: 0.9410Epoch 00095: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1477 - sensitivity: 0.8317 - specificity: 0.9704 - acc: 0.9406 - val_loss: 0.1617 - val_sensitivity: 0.6698 - val_specificity: 0.9524 - val_acc: 0.9313
# Epoch 96/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1347 - sensitivity: 0.8302 - specificity: 0.9724 - acc: 0.9432Epoch 00096: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1343 - sensitivity: 0.8310 - specificity: 0.9724 - acc: 0.9435 - val_loss: 0.1596 - val_sensitivity: 0.6804 - val_specificity: 0.9524 - val_acc: 0.9324
# Epoch 97/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1376 - sensitivity: 0.8427 - specificity: 0.9699 - acc: 0.9443Epoch 00097: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1375 - sensitivity: 0.8439 - specificity: 0.9700 - acc: 0.9445 - val_loss: 0.1395 - val_sensitivity: 0.5782 - val_specificity: 0.9746 - val_acc: 0.9435
# Epoch 98/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1243 - sensitivity: 0.8585 - specificity: 0.9722 - acc: 0.9482Epoch 00098: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1258 - sensitivity: 0.8590 - specificity: 0.9710 - acc: 0.9474 - val_loss: 0.1540 - val_sensitivity: 0.6596 - val_specificity: 0.9607 - val_acc: 0.9383
# Epoch 99/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1324 - sensitivity: 0.8197 - specificity: 0.9728 - acc: 0.9432Epoch 00099: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1326 - sensitivity: 0.8174 - specificity: 0.9733 - acc: 0.9428 - val_loss: 0.1529 - val_sensitivity: 0.6373 - val_specificity: 0.9611 - val_acc: 0.9365
# Epoch 100/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1431 - sensitivity: 0.8519 - specificity: 0.9647 - acc: 0.9406Epoch 00100: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1426 - sensitivity: 0.8546 - specificity: 0.9641 - acc: 0.9406 - val_loss: 0.1414 - val_sensitivity: 0.6045 - val_specificity: 0.9707 - val_acc: 0.9418
# Epoch 101/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1395 - sensitivity: 0.8262 - specificity: 0.9742 - acc: 0.9417Epoch 00101: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1390 - sensitivity: 0.8293 - specificity: 0.9738 - acc: 0.9421 - val_loss: 0.1443 - val_sensitivity: 0.6411 - val_specificity: 0.9668 - val_acc: 0.9418
# Epoch 102/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1335 - sensitivity: 0.8418 - specificity: 0.9676 - acc: 0.9407Epoch 00102: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1323 - sensitivity: 0.8429 - specificity: 0.9677 - acc: 0.9410 - val_loss: 0.1373 - val_sensitivity: 0.5506 - val_specificity: 0.9790 - val_acc: 0.9464
# Epoch 103/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1388 - sensitivity: 0.8390 - specificity: 0.9657 - acc: 0.9382Epoch 00103: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1381 - sensitivity: 0.8379 - specificity: 0.9659 - acc: 0.9382 - val_loss: 0.1427 - val_sensitivity: 0.6028 - val_specificity: 0.9706 - val_acc: 0.9418
# Epoch 104/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1269 - sensitivity: 0.8388 - specificity: 0.9744 - acc: 0.9454Epoch 00104: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1270 - sensitivity: 0.8415 - specificity: 0.9744 - acc: 0.9460 - val_loss: 0.1641 - val_sensitivity: 0.6712 - val_specificity: 0.9556 - val_acc: 0.9336
# Epoch 105/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1204 - sensitivity: 0.8709 - specificity: 0.9733 - acc: 0.9528Epoch 00105: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1190 - sensitivity: 0.8731 - specificity: 0.9738 - acc: 0.9536 - val_loss: 0.1565 - val_sensitivity: 0.6484 - val_specificity: 0.9619 - val_acc: 0.9371
# Epoch 106/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1204 - sensitivity: 0.8437 - specificity: 0.9730 - acc: 0.9446Epoch 00106: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1208 - sensitivity: 0.8433 - specificity: 0.9731 - acc: 0.9445 - val_loss: 0.1563 - val_sensitivity: 0.6576 - val_specificity: 0.9626 - val_acc: 0.9388
# Epoch 107/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1293 - sensitivity: 0.8473 - specificity: 0.9717 - acc: 0.9450Epoch 00107: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1296 - sensitivity: 0.8456 - specificity: 0.9711 - acc: 0.9445 - val_loss: 0.1447 - val_sensitivity: 0.5955 - val_specificity: 0.9714 - val_acc: 0.9423
# Epoch 108/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1231 - sensitivity: 0.8586 - specificity: 0.9720 - acc: 0.9489Epoch 00108: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1227 - sensitivity: 0.8594 - specificity: 0.9725 - acc: 0.9495 - val_loss: 0.1487 - val_sensitivity: 0.6353 - val_specificity: 0.9688 - val_acc: 0.9423
# Epoch 109/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1241 - sensitivity: 0.8500 - specificity: 0.9753 - acc: 0.9475Epoch 00109: val_loss did not improve
# 57/57 [==============================] - 49s 861ms/step - loss: 0.1230 - sensitivity: 0.8526 - specificity: 0.9753 - acc: 0.9481 - val_loss: 0.1447 - val_sensitivity: 0.6411 - val_specificity: 0.9662 - val_acc: 0.9406
# Epoch 110/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1216 - sensitivity: 0.8572 - specificity: 0.9712 - acc: 0.9479Epoch 00110: val_loss did not improve
# 57/57 [==============================] - 49s 861ms/step - loss: 0.1235 - sensitivity: 0.8558 - specificity: 0.9700 - acc: 0.9467 - val_loss: 0.1499 - val_sensitivity: 0.6363 - val_specificity: 0.9658 - val_acc: 0.9400
# Epoch 111/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1342 - sensitivity: 0.8273 - specificity: 0.9728 - acc: 0.9405Epoch 00111: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1334 - sensitivity: 0.8285 - specificity: 0.9729 - acc: 0.9409 - val_loss: 0.1614 - val_sensitivity: 0.6722 - val_specificity: 0.9600 - val_acc: 0.9377
# Epoch 112/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1224 - sensitivity: 0.8522 - specificity: 0.9685 - acc: 0.9450Epoch 00112: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1230 - sensitivity: 0.8508 - specificity: 0.9690 - acc: 0.9452 - val_loss: 0.1559 - val_sensitivity: 0.6635 - val_specificity: 0.9593 - val_acc: 0.9365
# Epoch 113/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1164 - sensitivity: 0.8313 - specificity: 0.9723 - acc: 0.9471Epoch 00113: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1156 - sensitivity: 0.8320 - specificity: 0.9729 - acc: 0.9476 - val_loss: 0.1629 - val_sensitivity: 0.6659 - val_specificity: 0.9582 - val_acc: 0.9359
# Epoch 114/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1178 - sensitivity: 0.8397 - specificity: 0.9717 - acc: 0.9453Epoch 00114: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1193 - sensitivity: 0.8396 - specificity: 0.9710 - acc: 0.9448 - val_loss: 0.1702 - val_sensitivity: 0.6778 - val_specificity: 0.9545 - val_acc: 0.9336
# Epoch 115/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1245 - sensitivity: 0.8617 - specificity: 0.9706 - acc: 0.9471Epoch 00115: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1237 - sensitivity: 0.8641 - specificity: 0.9707 - acc: 0.9477 - val_loss: 0.1536 - val_sensitivity: 0.6615 - val_specificity: 0.9651 - val_acc: 0.9412
# Epoch 116/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1122 - sensitivity: 0.8686 - specificity: 0.9787 - acc: 0.9561Epoch 00116: val_loss did not improve
# 57/57 [==============================] - 49s 868ms/step - loss: 0.1124 - sensitivity: 0.8709 - specificity: 0.9777 - acc: 0.9557 - val_loss: 0.1681 - val_sensitivity: 0.4959 - val_specificity: 0.9543 - val_acc: 0.9336
# Epoch 117/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1267 - sensitivity: 0.8395 - specificity: 0.9743 - acc: 0.9468Epoch 00117: val_loss did not improve
# 57/57 [==============================] - 50s 871ms/step - loss: 0.1253 - sensitivity: 0.8423 - specificity: 0.9747 - acc: 0.9477 - val_loss: 0.1562 - val_sensitivity: 0.6673 - val_specificity: 0.9632 - val_acc: 0.9400
# Epoch 118/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1176 - sensitivity: 0.8535 - specificity: 0.9769 - acc: 0.9493Epoch 00118: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1181 - sensitivity: 0.8561 - specificity: 0.9765 - acc: 0.9495 - val_loss: 0.1474 - val_sensitivity: 0.6450 - val_specificity: 0.9694 - val_acc: 0.9435
# Epoch 119/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1208 - sensitivity: 0.8569 - specificity: 0.9709 - acc: 0.9471Epoch 00119: val_loss did not improve
# 57/57 [==============================] - 49s 862ms/step - loss: 0.1208 - sensitivity: 0.8568 - specificity: 0.9714 - acc: 0.9473 - val_loss: 0.1486 - val_sensitivity: 0.6224 - val_specificity: 0.9700 - val_acc: 0.9429
# Epoch 120/500
# 56/57 [============================>.] - ETA: 0s - loss: 0.1187 - sensitivity: 0.8560 - specificity: 0.9746 - acc: 0.9500Epoch 00120: val_loss did not improve
# 57/57 [==============================] - 49s 863ms/step - loss: 0.1185 - sensitivity: 0.8568 - specificity: 0.9746 - acc: 0.9501 - val_loss: 0.1477 - val_sensitivity: 0.6266 - val_specificity: 0.9751 - val_acc: 0.9482
# CPU times: user 2h 37min 9s, sys: 23min 8s, total: 3h 17s
# Wall time: 1h 39min 54s

# %% [raw]
# model.fit_generator(gen_flow_train, validation_data=(X_valid, Y_valid) #gen_flow_val,  #(X_valid, Y_valid),
#                     steps_per_epoch=int(np.ceil(len(X_train)/batch_size)),
#                     #validation_steps=int(np.ceil(len(X_valid)/batch_size)),
#                     epochs=500, verbose=1, callbacks=[early_stopping_callback, checkpoint_callback],
#                     class_weight = class_weight)
#                     #class_weights = class_weight

# %% [markdown]
# ## IV. Visualize  TSNE

# %%
# %matplotlib inline
import numpy as np
# visualize the points' distribution of train data using features built from base_model
import matplotlib.pyplot as plt
# dimension reduction
from sklearn.manifold import TSNE 
import numpy as np

def t_sne_vis(name, base_model, x_processed_images, random_state, labels,perplexity = 30):
    """
    :param name: the name of the cnn model used to build features
    :param base_model: the model obj
    :param x_processed_images: the input images for our model
    :param random_state: for fixing the results
    :param labels: 0/1 classification labels
    :return:
    the graph of image distribution based on features extracted from the model and the t-sne features
    """
    # convert data to images
    print('Converting data points to composite image')
    X_train = x_processed_images
    print('we got %d different images of shape %dx%d ' % (len(X_train), X_train.shape[1], X_train.shape[1]))
    print('build usefull features from the selected model')
    features = base_model.predict(X_train)
    x_data1 = np.asarray(features).astype('float64')
    x_data1 = x_data1.reshape((x_data1.shape[0], -1))
    # perform t-SNE embedding
    print('performing t-sne reduction')
    vis_data = TSNE(perplexity=perplexity, random_state=random_state).fit_transform(x_data1)
    # plot the result
    fig = plt.figure(figsize=(15, 15))
    vis_x = vis_data[:, 0]
    vis_y = vis_data[:, 1]
    plt.scatter(vis_x, vis_y, c=labels, cmap=plt.cm.get_cmap("winter", 2))
    plt.colorbar(ticks=range(2))
    plt.clim(0, 1)
    plt.title(name)
    plt.grid()
    plt.show()
    fig.savefig('tsne_vis_'+name+'.png')
    return vis_data

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 150, 150, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 74, 74, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 74, 74, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 74, 74, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 74, 74, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 74, 74, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 74, 74, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 74, 74, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 74, 74, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 74, 74, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 74, 74, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 74, 74, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 74, 74, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 74, 74, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 74, 74, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 74, 74, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 74, 74, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 74, 74, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 37, 37, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 37, 37, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 37, 37, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 37, 37, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 37, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 37, 37, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 37, 37, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 37, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 37, 37, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 37, 37, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 37, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 37, 37, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 37, 37, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 37, 37, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 37, 37, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 37, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 37, 37, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 37, 37, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 37, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 37, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 19, 19, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 19, 19, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 19, 19, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 19, 19, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 19, 19, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 19, 19, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 19, 19, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 19, 19, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 19, 19, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 19, 19, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 19, 19, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 19, 19, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 19, 19, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 19, 19, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 19, 19, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 19, 19, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 10, 10, 512)  524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 10, 10, 512)  0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 10, 10, 2048) 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 10, 10, 2048) 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 10, 2048) 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 10, 10, 2048) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 10, 10, 512)  0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 10, 2048) 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 10, 10, 2048) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 10, 10, 512)  1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 10, 10, 512)  2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 10, 10, 512)  2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 10, 10, 512)  0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 10, 10, 2048) 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 10, 10, 2048) 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 10, 2048) 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 10, 10, 2048) 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 1)            2623489     avg_pool[0][0]
# ==================================================================================================
# Total params: 26,211,201
# Trainable params: 26,158,081
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
name = 'Resnet'
print('visualizing for %s' %name)
base_model_ = Model(input=model.input, output=model.get_layer('avg_pool').output)
tsne_feats = t_sne_vis(name, base_model_, X_valid, np.random.RandomState(42), Y_valid,perplexity=30)
# Out:
# visualizing for Resnet
# Converting data points to composite image
# we got 1717 different images of shape 299x299
# build usefull features from the selected model
# /home/dvp_tran/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("av..., inputs=Tensor("in...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# performing t-sne reduction

# %% [markdown]
# ## V. Evaluate Model

# %%
model = load_model(weights_path+"BestKerasResnet50_flat_3_loss_no_weight_image2.h5", custom_objects={'sensitivity': sensitivity,
                                                                             "specificity":specificity})
score = model.evaluate(X_valid, Y_valid, verbose=1)
print('Test loss:', score[0])
print('Test sensitivity:', score[1])
print('Test specificity:', score[2])
print('Test acc:', score[3])
# Out:
# 1717/1717 [==============================] - 10s 6ms/step
# ('Test loss:', 0.1347053585336454)
# ('Test sensitivity:', 0.56442298004636948)
# ('Test specificity:', 0.97131006399697872)
# ('Test acc:', 0.94059405940594054)

# %%
#compute metrics
pred = model.predict(X_valid)
average_precision = average_precision_score(Y_valid, pred)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.68

# %%
precision, recall, _ = precision_recall_curve(Y_valid, pred)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
# Out:
# Text(0.5,1,u'2-class Precision-Recall curve: AP=0.68')

# %%
def generate_results(y_test, y_score):
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.show()
    print('AUC: %f' % roc_auc)

# %%
generate_results
# Out:
# <function __main__.generate_results>

# %% [markdown]
# #compute log loss
# pred = model.predict(X_valid)
# log_loss(Y_valid,pred)

# %% [markdown]
# ## VI. Retrain on full dataset

# %% [raw]
# #Generate the training data
# #Create 3 bands having HH, HV and avg of both
# X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
# X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
# X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],
#                           ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)

# %% [raw]
# #parse corrupted notebook file
# t = ["#Generate the training data\n",
#     "#Create 3 bands having HH, HV and avg of both\n",
#     "X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_1\"]])\n",
#     "X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train[\"band_2\"]])\n",
#     "X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],\n",
#     "                          ((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)"]
# #t.remove("\n")
# t=[x.replace("\n",'') for x in t]
# for x in t:
#     print(x)
